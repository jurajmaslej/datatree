# %% [markdown]
# # Klasifikácia bankových prevodov

# %% [markdown]
# ## Obsah
# 1. Príprava a načítanie dát
# 2. Vytvorené štruktúry
# 3. Idei pre klasifikáciu platieb<br>
#     3.1. Grafová štruktúra<br>
#     3.2. Použité riešenie<br>
#     3.3. Klasifikácia ďalších kategórii<br>
# 4. Rozhodovanie na základe sumy a periodicity platieb<br>
#     4.1. Idea<br>
#     4.2. Implementácia<br>
#     4.3. Nevýhody<br>
# 5. Filtrácia platieb na základe periodicity<br>
#     5.1. Idea<br>
#     5.1.1 Hľadanie termínov mzdy<br>
#     5.1.2 Selekcia na základe výšky platby<br>
#     5.2. Implementácia<br>
# 6. Trendy v dátach - 2 výšky platieb <br>
# 7. Klasterizácia<br>
#     7.1. Navrhovaný algoritmus<br>
#     7.1.1 Inicializácia centier<br>
#     7.1.2 Výpočet chyby<br>
#     7.2. Problémy riešenia<br>
#     7.3 Implementácia<br>
#     7.4.Vyhodnotenie klasterizácie<br>
# 8. Grafy<br>
#     8.1. Príjem z jedného účtu v porovnaní s pravdepodobnosťou, že sa jedná o mzdu.<br>
#     8.2. Výška platby vs. pravdepodobnosť, že na účet prichádza mzda<br>
#     8.3 Percentuálne rozdelenie výšky platieb<br>
#     8.4. Pravdepodobnosť, že platba je mzdou vs. výška platby<br>
# 9. Protiúčty
# 10. Záver
#
# Pozn: odporúčame spúšťať ukážky kódu v poradí v akom sú v notebook-u, sú na sebe závislé.
# Program v notebook-u a súboroch na gite sa môže líšiť.

# %% [markdown]
# ### 1. Príprava a načítanie dát
#
# Dáta pozostávajú z účtu odosielateľa platby, príjemcu, dátumu a sumy.
# Dáta sme načítavali z txt súboru. Pôvodne sme chceli využiť Panda DataFrame, no jeho využitie neprinášalo žiadne výhody. Načítavanie do numpy array sa ukázalo ako príliš pomalé, kvôli použitiu vstack operácie pre želaný formát dát. Preto sme sa nakoniec rozhodli pre použitie základných python štruktúr, ktoré sa ukázali ako najrýchlejší spôsob načítania. Zvažovali sme použitie databázy, no pre danú veľkosť dát bol postačujúci python.

# %% [markdown]
# ### 2. Vytvorené štruktúry
#
# V prvej verzii sme vytvorili slovník s kľúčom ako kombinácia odosielateľa a príjmateľa platby,
# obsahujúci pole objektov triedy Payments. Táto trieda obsahuje odoslanú sumu a dátum odoslania.
# Neskôr sme zistili, že táto štruktúra nie je vyhovujúca, resp. práca s ňou nie je efektívna, preto sme vytvorili triedu Connections. Jej objekty sú v slovníku s rovnakými kľúčami ako Payments, no pre zistenie celkovej sumy nie je potrebné iterovať cez pole objektov.

# %%
import numpy as np
import datetime
"""
load dataset
"""

class Loader:
	
	
	class Payment:
		def __init__(self, date, amount):
			self.date = date
			self.amount = amount
			self.is_salary = 0	#percentage
			self.k_means_error = 0
			self.sender_weight = 0
			
	class Connection:
		def __init__(self):
			self.payments = []
			self.is_salary = 0
			self.one_cl_err = 0
			self.two_cl_err = 0
			self.err_rate = 0
			self.cluster_err_perc = 0
			self.cluster_perc = 0
			self.cluster_dst = 0	#for low and heigh cluster center
			self.cluster_dst_perc = 0
			self.date_amount = []
			self.amounts = []
			self.salaries = []		# for payments that we think are salaries
			self.salary_perc = 0	# percentage that sequence is salary according to payment_process.py
		def add_payment(self, paym):
			self.payments.append(paym)
	def adjust_sender_weights(self, sender, receiver):
		if sender + receiver not in self.sender_weights_check:
			if sender not in self.sender_weights.keys():
				self.sender_weights[sender] = 1
			else:
				self.sender_weights[sender] += 1
		else:
			self.sender_weights_check.add(sender + receiver)
            
	def __init__(self, fname):
		counter = 0
		self.data = []
		self.payments = dict()
		self.payments_list = dict()
		self.keyset = set()
		self.amounts = list()
		self.sender_weights = dict()
		self.sender_weights_check = set()
		with open(fname) as f:
			for line in f:
				if counter % 100000 == 0:
					print("data proccessed " + str(counter))   # just to see python did not get stuck
				counter += 1
				l = list(line.strip().split('\t'))
				timest =  [int(x) for x in l[0].split('-')]	#split datestring on '-'
				l[0] = datetime.datetime(timest[0], timest[1], timest[2])	# needs 3 integers as argument to make datetime object
				l[2] = int(l[2])	#sum as integer
				self.data.append(l)	#tried dataframe, numpy array, simple list seems to be the fastest
				key_payments = l[1] + '#' + l[3]
                
				self.adjust_sender_weights(l[1], l[3])
                
				if key_payments in self.keyset:		#much faster than asking for keys()
					self.payments[key_payments].append(self.Payment(l[0], l[2]))
					
					self.payments_list[key_payments].add_payment(self.Payment(l[0], l[2]))		#with object Connection
				else:
					self.payments[key_payments] = []
					self.payments[key_payments].append(self.Payment(l[0], l[2]))
					
					self.payments_list[key_payments] = self.Connection()
					self.payments_list[key_payments].add_payment(self.Payment(l[0], l[2]))
					
				self.payments_list[key_payments].date_amount.append([l[0], l[2]])
				self.payments_list[key_payments].amounts.append(l[2])	#for graph easy access to amounts
				self.keyset.add(key_payments)
				
				self.amounts.append(l[2])
		
		
l = Loader('data_for_applicants.txt')
# Out:
# data proccessed 0
# data proccessed 100000
# data proccessed 200000
# data proccessed 300000
# data proccessed 400000

# %% [markdown]
# ### 3. Idei pre klasifikáciu platieb
#
# #### 3.1 Grafová štruktúra
# Prvotný nápad bol vytvoriť grafovú štruktúru, kde by účty boli vrcholy a platby hrany. Tento prístup by vyžadoval prehľadávanie grafovými algoritmami. Pri skúmaní use-case-ov pre fyzické osoby sme nenarazili na masívne výhody tohto prístupu pre identifikáciu miezd. Výhodami by bola možna práca s tranzitívnosťou údajov, teda možná identifikácia reťazcov platieb. Táto grafová štruktúra by bola vyvinutá ako ďalší krok po terajšom riešení.
#
# #### 3.2 Použité riešenie
#
# Pre fyzické osoby sme mali predpoklad, že mzda bude prichádzať z jedného účtu, teda aj bez reťazcov platieb neprídeme o veľa informácie. Implementovali sme slovník, ktorý obsahuje objekt triedy udržiavajúcej detaily o platbách medzi účtami, v priebehu výpočtu nové dáta a nakoniec aj výsledok vo forme pravdepodobnosti. Pre vyššiu presnosť riešenia sme sa snažili vyhýbať pevným ohraničeniam, teda výsledky uvádzame v percentách. Pre určenie mzdy sme ale použili niekoľko logických ohraničení ako výšku platby a jej periodicitu.
#
# #### 3.3 Klasifikácia ďalších kategórii
#
# Jednoduché kategórie, ako kategorizáciu podľa výšky platieb sme neimplementovali, pretože sme to považovali za triviálne. Platby ako predaj tovaru medzi fyzickými osobami by sme vyhľadávali opačným postupom ako mzdy, teda platby ktoré nemajú žiadnu periodicitu a variancia ich sumy je vysoká. Ak ma fyzická osoba druhý príjem z 2. zamestnania, mohla by ho odhaliť ďalej navrhnutá a implementovaná klasterizácia.

# %% [markdown]
# ### 4. Rozhodovanie na základe sumy a periodicity platieb - prvý prístup
#
# #### 4.1. Idea
#    Aby bola platba klasifkovaná ako výplata, zvažujeme v tomto prístupe periodicitu platby a varianciu vo výške platieb. Pre každý prvok v slovníku payments, teda dvojicu účtov, kde z účtu A odchádzajú platby na účet B, vypočítame rozdiel v dátume platieb.Čím je priemer týchto rozdielov vzdialenejší od počtu dní v mesiaci, tým väčšia pravdepodobnosť, že dané platby neboli výplatami. Variancu vo vyplácaných sumách získame ako štandardnú odchýlku vydelenú priemerom platieb. Čím väčšia variancia, tým nižšia pravdepodobnosť, že ide o výplaty.
# Ak sa chyba v časoch platieb a suma platieb pohybuje v stanovených medziach, chyby zaznamenáme. V ďalšej metóde následne pre dvojice účtov kde máme zaznamenú chybu, prevedieme chybu na pravdepodobnosť, že sa jedná o výplaty
#
# #### 4.2. Nevýhody
#    Hlavným problémom tohto prístupu, je vyhodnotenie buď všetkých platieb medzi 2 účtami ako mzdy. Alebo kvôli niekoľkým platbam nevyhovujúcej sumy, alebo v inom dátume, vyhodnotenie, že pre žiadnu platbu sa nejedná o mzdu. Medzi dvomi účtami sa môžu medzi mzdami vyskytnúť rôzne transakcie, toto tento prístup neberie do úvahy.
# Tento problém sme odstránili v nasledujúcom prístupe.
#
# #### 4.3. Implementácia

# %%
from __future__ import division
import numpy as np
import datetime
import warnings

class Payment_process:
	
	
	def __init__(self, loaded):
		self.payments = loaded.payments
		self.keyset = loaded.keyset
		self.connections = loaded.payments_list
		warnings.filterwarnings("ignore")
		
	def sort_payments(self):
		for key, value in self.payments.items():
			self.payments[key].sort(key=lambda x: x.date)
			
	def sort_connections(self, data):
		return sorted(data, key = lambda data:data[0])	#sort by date
			
	def normalize_data(self, data):
		data -= np.mean(data, keepdims = True)
		data = [int(i) for i in data]
		data /= np.std(data, keepdims = True)
		return data
	
	def scale_data(self, data):
		return (data - np.min(data))/np.ptp(data)

	def scale_data_from_dict(self, data, divide=None, scale=None):
		min_d = float(np.min([i for i in data.values()]))
		ptp_d = np.ptp(list(data.values()))	# range of values
		for k,v in data.items():
			data_k_fl = float(data[k])
			data[k] = (data_k_fl - min_d)/ptp_d
			if divide:
				data[k] = data_k_fl/divide
			if scale:
				data[k] = data_k_fl*scale
		return data
	

	def process(self):
		counter = 0
		all_err_dates = dict()
		all_err_income = dict()
		all_err = dict()
		for key, p in self.payments.items():
			if len(p) > 4:	# at leat N salaries
				delta_dates = []
				income_list = [p[0].amount,]
				for pay_ind in range(0, len(p) - 1):
					delta = p[pay_ind + 1].date - p[pay_ind].date
					delta_dates.append(delta.days)
					income_list.append(p[pay_ind + 1].amount)
				dates_norm = self.normalize_data(delta_dates)
				err_income = np.std(income_list)/np.mean(income_list)
				err_dates = abs(np.mean(delta_dates) - 30.411)	#avg num off days in month
				if err_dates < 5 and 7700 < np.median(income_list) < 115000:		# max error of 5 days, otherwise not a salary, salary sum must be reasonable
					all_err_dates[key] = err_dates
					all_err_income[key] = err_income
					all_err[key] = (err_income*5 + err_dates/4)		#weighting of errors
				else:
					# not considered income
					pass
		return all_err_dates, all_err_income, all_err
	
	def process_errors(self, all_err_dates, all_err_income, all_err):
		all_err_sc = self.scale_data_from_dict(all_err)
		for k,v in all_err_sc.items():
			prob = (1 - v*4)*100
			if 0 <prob <100:
				print('probability of being a salary : ' + str(prob) + '%')
				print('having these payments : ')
				for i in self.payments[k]:
					print(i.amount, end = ', ')
				print('\n')
				self.connections[k].is_salary = prob
        
pp = Payment_process(l)
pp.sort_payments()
dates_errs, income_errs, all_err = pp.process()
pp.process_errors(dates_errs, income_errs, all_err)
# Out:
# probability of being a salary : 96.73973399386988%
# having these payments :
# 9966, 9964, 9964, 9964, 9960, 9965,
#
# probability of being a salary : 96.72460362194178%
# having these payments :
# 10830, 10839, 10835, 10837, 10832, 10835,
#
# probability of being a salary : 98.45925219638248%
# having these payments :
# 18322, 18314, 18320, 18314, 18319, 18320,
#
# probability of being a salary : 98.45935427567547%
# having these payments :
# 16448, 16448, 16451, 16451, 16450, 16443,
#
# probability of being a salary : 94.498704466975%
# having these payments :
# 8046, 8096, 8043, 8101, 8105, 8097,
#
# probability of being a salary : 98.27690342093625%
# having these payments :
# 13086, 13087, 13087, 13086, 13088, 13091,
#
# probability of being a salary : 97.75365007482085%
# having these payments :
# 10792, 10790, 10743, 10796, 10707, 10798,
#
# probability of being a salary : 49.758427543215866%
# having these payments :
# 15395, 15401, 18304, 16062, 16062, 16061, 16062,
#
# probability of being a salary : 78.5925805198748%
# having these payments :
# 15351, 19908, 15422, 15363, 17005, 14925,
#
# probability of being a salary : 98.2343316915967%
# having these payments :
# 14107, 14101, 14102, 14050, 14105, 14075,
#
# probability of being a salary : 94.7087230275864%
# having these payments :
# 10576, 10555, 10515, 10575, 10569, 10571,
#
# probability of being a salary : 98.43302268248112%
# having these payments :
# 15950, 15966, 15964, 15959, 15961, 15962,
#
# probability of being a salary : 98.26966841348991%
# having these payments :
# 20523, 20529, 20520, 20528, 20521, 20521,
#
# probability of being a salary : 98.14723375278479%
# having these payments :
# 9054, 9101, 9102, 9103, 9102, 9104,
#
# probability of being a salary : 89.19172625274929%
# having these payments :
# 11091, 9903, 9974, 10957, 10623, 9654,
#
# probability of being a salary : 98.28466785822721%
# having these payments :
# 28262, 28263, 28259, 28267, 28264, 28262,
#
# probability of being a salary : 98.45429604879068%
# having these payments :
# 14262, 14262, 14264, 14268, 14269, 14267,
#
# probability of being a salary : 98.47036412431352%
# having these payments :
# 14435, 14436, 14433, 14435, 14435, 14438,
#
# probability of being a salary : 85.34912449195598%
# having these payments :
# 19849, 19866, 19835, 24066, 19837, 19838,
#
# probability of being a salary : 97.52385907163071%
# having these payments :
# 9330, 9323, 9329, 9321, 9211, 9306,
#
# probability of being a salary : 94.83545835782239%
# having these payments :
# 15261, 15207, 15255, 15262, 15256, 15261,
#
# probability of being a salary : 94.97994098380343%
# having these payments :
# 9871, 9871, 9860, 9873, 9870, 9872,
#
# probability of being a salary : 68.58339562439413%
# having these payments :
# 26722, 25491, 26980, 34381, 23167, 20410,
#
# probability of being a salary : 97.81144403461045%
# having these payments :
# 8991, 8928, 8960, 8942, 8894, 8995,
#
# probability of being a salary : 97.4878776924223%
# having these payments :
# 10301, 10291, 10228, 10289, 10164, 10280,
#
# probability of being a salary : 88.23454817298786%
# having these payments :
# 14795, 14836, 15018, 14877, 16946, 15130,
#
# probability of being a salary : 95.6201236836945%
# having these payments :
# 22068, 22068, 22066, 22315, 22319, 22315,
#
# probability of being a salary : 96.12181187619386%
# having these payments :
# 9624, 9624, 9622, 9627, 9612, 9525,
#
# probability of being a salary : 98.47165423999712%
# having these payments :
# 27415, 27411, 27408, 27413, 27413, 27408,
#
# probability of being a salary : 95.03237716315614%
# having these payments :
# 21643, 21638, 21638, 21640, 21646, 21643,
#
# probability of being a salary : 94.9702222760136%
# having these payments :
# 22077, 22104, 22104, 22110, 22106, 22106,
#
# probability of being a salary : 97.7137622134827%
# having these payments :
# 7994, 8022, 8020, 8021, 8023, 7923,
#
# probability of being a salary : 98.3102223769017%
# having these payments :
# 18503, 18449, 18503, 18496, 18499, 18499,
#
# probability of being a salary : 98.0417054894968%
# having these payments :
# 18710, 18635, 18708, 18712, 18712, 18709,
#
# probability of being a salary : 98.26080022741594%
# having these payments :
# 14422, 14424, 14430, 14423, 14429, 14429,
#
# probability of being a salary : 94.70753939886303%
# having these payments :
# 21747, 22019, 22302, 21606, 22294, 22163,
#
# probability of being a salary : 94.74671723827869%
# having these payments :
# 10468, 10466, 10469, 10418, 10470, 10469,
#
# probability of being a salary : 58.14639488032699%
# having these payments :
# 15133, 15370, 13386, 23948, 13587, 13509,
#
# probability of being a salary : 97.71972319824616%
# having these payments :
# 28660, 29051, 28785, 28729, 28834, 28695,
#
# probability of being a salary : 98.32125781040476%
# having these payments :
# 8479, 8479, 8459, 8475, 8484, 8482,
#
# probability of being a salary : 95.83819698167694%
# having these payments :
# 17555, 17559, 17563, 17711, 17713, 17712,
#
# probability of being a salary : 95.69644100378902%
# having these payments :
# 14951, 14853, 14953, 15061, 15054, 15062,
#
# probability of being a salary : 97.97053553993138%
# having these payments :
# 8176, 8218, 8204, 8172, 8223, 8157,
#
# probability of being a salary : 98.08697303471915%
# having these payments :
# 39923, 39919, 39920, 40110, 40108, 40105,
#
# probability of being a salary : 94.45953334870391%
# having these payments :
# 11972, 12080, 12081, 12075, 12020, 12009,
#
# probability of being a salary : 95.03263447196389%
# having these payments :
# 15824, 15825, 15819, 15823, 15820, 15822,
#
# probability of being a salary : 11.82230311525262%
# having these payments :
# 19125, 19133, 19129, 19131, 19125, 5186, 19710,
#
# probability of being a salary : 15.686528575201475%
# having these payments :
# 8553, 1416, 15595, 8241, 8559, 8559,
#
# probability of being a salary : 98.05595125438755%
# having these payments :
# 10586, 10589, 10513, 10587, 10580, 10572,
#
# probability of being a salary : 71.35933498107238%
# having these payments :
# 19626, 19696, 19629, 28615, 24244, 19626,
#
# probability of being a salary : 98.3407613457692%
# having these payments :
# 12023, 12048, 12055, 12048, 12050, 12049,
#
# probability of being a salary : 89.75767061767114%
# having these payments :
# 56407, 49772, 55542, 55540, 55539, 55534,
#
# probability of being a salary : 94.80724105136238%
# having these payments :
# 12917, 12921, 12918, 12868, 12914, 12919,
#
# probability of being a salary : 95.02326725903542%
# having these payments :
# 12802, 12804, 12797, 12799, 12801, 12798,
#
# probability of being a salary : 98.45882597320885%
# having these payments :
# 17184, 17180, 17183, 17180, 17186, 17188,
#
# probability of being a salary : 98.04792142970062%
# having these payments :
# 9419, 9415, 9355, 9416, 9422, 9424,
#
# probability of being a salary : 94.82418467812954%
# having these payments :
# 15660, 15712, 15710, 15707, 15673, 15713,
#
# probability of being a salary : 98.46816837743295%
# having these payments :
# 15465, 15465, 15469, 15468, 15464, 15467,
#
# probability of being a salary : 98.45029606145148%
# having these payments :
# 14032, 14041, 14038, 14040, 14041, 14038,
#
# probability of being a salary : 81.63996048684443%
# having these payments :
# 23430, 23090, 24867, 29926, 23782, 23229,
#
# probability of being a salary : 96.11402359435597%
# having these payments :
# 14813, 14756, 14816, 14868, 14864, 14866,
#
# probability of being a salary : 98.27077267959521%
# having these payments :
# 14498, 14493, 14498, 14493, 14496, 14499,
#
# probability of being a salary : 94.74379061874329%
# having these payments :
# 19909, 19906, 19906, 19809, 19902, 19906,
#
# probability of being a salary : 95.70578996887896%
# having these payments :
# 30470, 30469, 30462, 30780, 30777, 30783,
#
# probability of being a salary : 97.83892237206486%
# having these payments :
# 8484, 8406, 8437, 8489, 8483, 8490,
#
# probability of being a salary : 98.46469529512981%
# having these payments :
# 17803, 17807, 17804, 17801, 17808, 17803,
#
# probability of being a salary : 47.151058654550035%
# having these payments :
# 21964, 35159, 43461, 20967, 23236, 23276,
#
# probability of being a salary : 95.72857039056778%
# having these payments :
# 12950, 12950, 12883, 13048, 13052, 13047,
#
# probability of being a salary : 94.78900814280708%
# having these payments :
# 23537, 23569, 23568, 23709, 24303, 23541,
#
# probability of being a salary : 98.13927965289797%
# having these payments :
# 13112, 13106, 13110, 13111, 13107, 13038,
#
# probability of being a salary : 80.0456689715789%
# having these payments :
# 17627, 17631, 22464, 17659, 17580, 17711,
#
# probability of being a salary : 96.49365162304561%
# having these payments :
# 8681, 8672, 8676, 8680, 8680, 8641,
#
# probability of being a salary : 97.93981273031388%
# having these payments :
# 9094, 9150, 9146, 9144, 9143, 9141,
#
# probability of being a salary : 37.0547971373364%
# having these payments :
# 28056, 28184, 28158, 19972, 27880, 28102, 33198,
#
# probability of being a salary : 97.75691861352321%
# having these payments :
# 9882, 9784, 9783, 9882, 9812, 9805,
#
# probability of being a salary : 71.70575196033596%
# having these payments :
# 10715, 8864, 13294, 12745, 11908, 12164,
#
# probability of being a salary : 73.9405284723297%
# having these payments :
# 17567, 17261, 17744, 12827, 17974, 13415,
#
# probability of being a salary : 77.49177516033882%
# having these payments :
# 13491, 13325, 13489, 17847, 15113, 16181,
#
# probability of being a salary : 98.05036305021208%
# having these payments :
# 11161, 11174, 11130, 11098, 11175, 11171,
#
# probability of being a salary : 95.0286324683154%
# having these payments :
# 17016, 17023, 17021, 17024, 17022, 17019,
#
# probability of being a salary : 94.66004292788983%
# having these payments :
# 15144, 15147, 15144, 15149, 15052, 15143,
#
# probability of being a salary : 94.83155733922895%
# having these payments :
# 13848, 13961, 13888, 13745, 14198, 14130,
#
# probability of being a salary : 98.46250974695651%
# having these payments :
# 19239, 19244, 19239, 19240, 19236, 19244,
#
# probability of being a salary : 53.15036928060635%
# having these payments :
# 37261, 37391, 71325, 38283, 43791, 43663,
#
# probability of being a salary : 95.030599940792%
# having these payments :
# 22243, 22237, 22240, 22234, 22243, 22238,
#
# probability of being a salary : 94.79526448766426%
# having these payments :
# 14426, 14428, 14426, 14368, 14425, 14428,
#
# probability of being a salary : 86.39065178144214%
# having these payments :
# 19555, 19530, 19554, 23246, 19343, 19537,
#
# probability of being a salary : 97.93419060889225%
# having these payments :
# 9589, 9580, 9586, 9588, 9582, 9531,
#
# probability of being a salary : 59.44902964372327%
# having these payments :
# 37376, 35141, 60637, 34736, 38312, 40499,
#
# probability of being a salary : 88.00832401705595%
# having these payments :
# 18666, 16572, 17305, 15823, 17620, 17299,
#
# probability of being a salary : 96.3402869974688%
# having these payments :
# 12664, 12702, 12684, 12741, 12745, 12744,
#
# probability of being a salary : 97.72541074797778%
# having these payments :
# 22821, 22819, 22815, 23021, 23021, 23024,
#
# probability of being a salary : 70.66690626340849%
# having these payments :
# 10436, 10651, 10658, 15316, 10928, 10643,
#
# probability of being a salary : 97.93079389123976%
# having these payments :
# 43490, 43491, 43497, 43777, 43774, 43777,
#
# probability of being a salary : 98.27288865438787%
# having these payments :
# 14731, 14734, 14733, 14732, 14730, 14727,
#
# probability of being a salary : 95.14527278607528%
# having these payments :
# 9497, 9502, 9243, 9567, 9658, 9821,
#
# probability of being a salary : 93.5222574233278%
# having these payments :
# 21008, 21467, 21182, 21274, 21631, 19767,
#
# probability of being a salary : 96.72448828463249%
# having these payments :
# 15724, 15719, 15724, 15722, 15724, 15712,
#
# probability of being a salary : 98.27934476895797%
# having these payments :
# 13420, 13420, 13414, 13396, 13415, 13375,
#
# probability of being a salary : 96.22326714560016%
# having these payments :
# 10685, 10688, 10683, 10594, 10687, 10684,
#
# probability of being a salary : 93.72595062343483%
# having these payments :
# 10655, 10320, 10652, 10251, 10656, 10657,
#
# probability of being a salary : 27.362465645333234%
# having these payments :
# 8532, 8534, 8459, 8532, 8530, 8533, 19131,
#
# probability of being a salary : 88.00222727670675%
# having these payments :
# 13298, 13323, 13368, 13294, 15193, 13340,
#
# probability of being a salary : 95.02932032428639%
# having these payments :
# 14497, 14491, 14495, 14498, 14496, 14496,
#
# probability of being a salary : 93.14964703379256%
# having these payments :
# 14851, 14828, 15232, 14489, 15442, 14099,
#
# probability of being a salary : 98.19079684073351%
# having these payments :
# 12896, 12903, 12841, 12903, 12897, 12903,
#
# probability of being a salary : 84.29335647831702%
# having these payments :
# 26468, 24835, 25209, 24802, 30165, 25162,
#
# probability of being a salary : 96.68552072724252%
# having these payments :
# 11974, 11984, 11992, 11986, 11989, 11991,
#
# probability of being a salary : 52.3182841088174%
# having these payments :
# 10991, 10903, 10790, 8561, 5654, 5652,
#
# probability of being a salary : 97.97959359538966%
# having these payments :
# 14718, 14724, 14719, 14816, 14785, 14815,
#
# probability of being a salary : 98.4755501860714%
# having these payments :
# 30271, 30269, 30265, 30267, 30265, 30269,
#
# probability of being a salary : 66.95950300319645%
# having these payments :
# 23884, 16132, 16716, 15759, 16109, 15154,
#
# probability of being a salary : 98.25173279227513%
# having these payments :
# 18887, 18890, 18880, 18820, 18848, 18887,
#
# probability of being a salary : 48.6177369628989%
# having these payments :
# 22930, 32130, 48709, 24941, 25023, 27377,
#
# probability of being a salary : 56.19491939394556%
# having these payments :
# 16433, 16653, 17617, 23209, 30025, 17300,
#
# probability of being a salary : 81.2997642743268%
# having these payments :
# 24077, 23937, 24019, 23730, 28793, 28857,
#
# probability of being a salary : 78.30292181110902%
# having these payments :
# 24774, 25354, 24779, 32444, 24864, 24774,
#
# probability of being a salary : 94.63346006621032%
# having these payments :
# 13090, 13095, 13090, 13095, 13009, 13049,
#
# probability of being a salary : 92.95446694883928%
# having these payments :
# 10460, 9827, 9609, 10089, 10046, 9555,
#
# probability of being a salary : 96.56101243821534%
# having these payments :
# 20445, 20445, 20448, 20446, 20450, 20452,
#
# probability of being a salary : 96.60092165023086%
# having these payments :
# 16604, 16601, 16604, 16585, 16600, 16558,
#
# probability of being a salary : 91.55407529730336%
# having these payments :
# 36980, 35391, 35962, 32339, 35393, 34871,
#
# probability of being a salary : 88.04134830822937%
# having these payments :
# 34576, 30267, 37395, 37221, 36820, 35110,
#
# probability of being a salary : 94.29750136441054%
# having these payments :
# 17224, 18034, 17867, 17871, 17022, 17016,
#
# probability of being a salary : 98.16041614631872%
# having these payments :
# 14216, 14145, 14223, 14217, 14217, 14214,
#
# probability of being a salary : 93.19456865613577%
# having these payments :
# 21133, 21720, 21350, 21398, 21750, 21721,
#
# probability of being a salary : 94.82498375259469%
# having these payments :
# 12147, 12153, 12106, 12147, 12149, 12151,
#
# probability of being a salary : 93.07034469614457%
# having these payments :
# 19948, 19922, 19922, 19674, 20060, 21026,
#
# probability of being a salary : 98.03308214577724%
# having these payments :
# 19972, 19974, 19978, 20078, 20078, 20086,
#
# probability of being a salary : 94.8002880286237%
# having these payments :
# 14832, 14773, 14829, 14827, 14793, 14823,
#
# probability of being a salary : 98.01290691640621%
# having these payments :
# 36562, 36563, 36564, 36763, 36767, 36768,
#
# probability of being a salary : 97.57502143036221%
# having these payments :
# 9032, 9032, 8931, 9031, 9029, 8928,
#
# probability of being a salary : 96.32847199085836%
# having these payments :
# 27412, 27411, 27328, 27444, 27380, 27447,
#
# probability of being a salary : 89.4389143291333%
# having these payments :
# 48441, 46842, 46842, 46832, 49107, 52470,
#
# probability of being a salary : 98.46199278409095%
# having these payments :
# 9865, 9865, 9867, 9864, 9868, 9864,
#
# probability of being a salary : 95.03999543850074%
# having these payments :
# 21492, 21492, 21493, 21495, 21489, 21490,
#
# probability of being a salary : 98.44778208052132%
# having these payments :
# 13393, 13387, 13393, 13389, 13394, 13386,
#
# probability of being a salary : 4.193087059922085%
# having these payments :
# 8908, 1919, 9332, 9338, 9322, 9318, 9332,
#
# probability of being a salary : 96.10903816260826%
# having these payments :
# 29045, 29048, 29044, 29214, 29183, 29218,
#
# probability of being a salary : 85.01532436172258%
# having these payments :
# 25134, 25228, 27528, 25430, 25131, 29982,
#
# probability of being a salary : 98.10556860876292%
# having these payments :
# 12392, 12315, 12391, 12387, 12388, 12386,
#
# probability of being a salary : 82.98874139002513%
# having these payments :
# 27165, 27162, 27169, 27163, 32105, 32037,
#
# probability of being a salary : 97.97025915857314%
# having these payments :
# 12836, 12835, 12830, 12835, 12731, 12837,
#
# probability of being a salary : 89.23381824944275%
# having these payments :
# 17265, 19403, 17451, 17391, 19320, 17283,
#
# probability of being a salary : 98.4045466700478%
# having these payments :
# 11205, 11219, 11219, 11216, 11214, 11222,
#
# probability of being a salary : 93.3339472484593%
# having these payments :
# 9711, 10404, 10500, 9872, 9903, 9826,
#
# probability of being a salary : 98.42820948412032%
# having these payments :
# 10261, 10259, 10259, 10251, 10258, 10253,
#
# probability of being a salary : 98.32393634847031%
# having these payments :
# 12361, 12356, 12352, 12327, 12361, 12358,
#
# probability of being a salary : 96.15794751677302%
# having these payments :
# 10342, 10246, 10340, 10291, 10342, 10343,
#
# probability of being a salary : 98.34690324551767%
# having these payments :
# 12227, 12228, 12230, 12203, 12231, 12232,
#
# probability of being a salary : 47.690936416637584%
# having these payments :
# 5822, 14878, 14406, 14878, 14882,
#
# probability of being a salary : 80.59205585193537%
# having these payments :
# 19541, 20173, 17794, 18750, 20217, 24465,
#
# probability of being a salary : 96.56327481907232%
# having these payments :
# 15038, 15038, 15035, 15040, 15037, 15040,
#
# probability of being a salary : 98.04153416820402%
# having these payments :
# 10972, 10964, 10955, 10891, 10973, 10965,
#
# probability of being a salary : 98.13530544691994%
# having these payments :
# 13424, 13415, 13417, 13393, 13360, 13355,
#
# probability of being a salary : 44.99560448389253%
# having these payments :
# 17645, 17652, 13690, 5295, 14238, 18587,
#
# probability of being a salary : 98.48219767913994%
# having these payments :
# 54947, 54947, 54942, 54943, 54945, 54944,
#
# probability of being a salary : 98.03772425008768%
# having these payments :
# 9768, 9766, 9701, 9768, 9772, 9773,
#
# probability of being a salary : 89.53784399766165%
# having these payments :
# 14302, 16471, 15052, 15586, 15521, 15473,
#
# probability of being a salary : 94.90984660674135%
# having these payments :
# 12279, 12279, 12277, 12249, 12269, 12271,
#
# probability of being a salary : 96.675091491839%
# having these payments :
# 19991, 20020, 20015, 20022, 20000, 20016,
#
# probability of being a salary : 90.23461004520036%
# having these payments :
# 20419, 20418, 20419, 22150, 19933, 19864,
#
# probability of being a salary : 61.96457886398945%
# having these payments :
# 29117, 29243, 29223, 48757, 35928, 33558,
#
# probability of being a salary : 97.90369231850391%
# having these payments :
# 9232, 9227, 9285, 9285, 9279, 9207,
#
# probability of being a salary : 98.2751183382086%
# having these payments :
# 14575, 14613, 14616, 14575, 14610, 14614,
#
# probability of being a salary : 97.78600011457101%
# having these payments :
# 8565, 8566, 8520, 8567, 8473, 8516,
#
# probability of being a salary : 98.47141139810816%
# having these payments :
# 9855, 9852, 9854, 9854, 9853, 9853,
#
# probability of being a salary : 96.49285119042831%
# having these payments :
# 20037, 20036, 20036, 20030, 20008, 20038,
#
# probability of being a salary : 98.24154193452739%
# having these payments :
# 26095, 26099, 26003, 26100, 26043, 26100,
#
# probability of being a salary : 94.89575088418867%
# having these payments :
# 19953, 20006, 20005, 19996, 20003, 20001,
#
# probability of being a salary : 98.27662740125527%
# having these payments :
# 8482, 8512, 8513, 8507, 8508, 8507,
#
# probability of being a salary : 98.37458634836239%
# having these payments :
# 20370, 20367, 20367, 20332, 20367, 20369,
#
# probability of being a salary : 95.8211731475258%
# having these payments :
# 13556, 13181, 13646, 13219, 13572, 13648,
#
# probability of being a salary : 98.4592126186139%
# having these payments :
# 17745, 17753, 17747, 17752, 17746, 17748,
#
# probability of being a salary : 98.47121745433694%
# having these payments :
# 15995, 15994, 15997, 15997, 15994, 15998,
#
# probability of being a salary : 97.22472655480448%
# having these payments :
# 12514, 12224, 12455, 12322, 12793, 12729,
#
# probability of being a salary : 98.43326258089658%
# having these payments :
# 18132, 18140, 18137, 18137, 18122, 18134,
#
# probability of being a salary : 63.475822868423506%
# having these payments :
# 45543, 34914, 36892, 28889, 46862, 49894,
#
# probability of being a salary : 96.01499286154895%
# having these payments :
# 15841, 15846, 15838, 15942, 15948, 15950,
#
# probability of being a salary : 71.87617768649162%
# having these payments :
# 16331, 16691, 25038, 17208, 17856, 17167,
#
# probability of being a salary : 66.18318087116096%
# having these payments :
# 25511, 16549, 16548, 16548, 18471, 16551,
#
# probability of being a salary : 98.42942292133334%
# having these payments :
# 12409, 12405, 12412, 12417, 12417, 12412,
#
# probability of being a salary : 80.63173357366826%
# having these payments :
# 19991, 19431, 19429, 17679, 21255, 24425,
#
# probability of being a salary : 83.07200331071694%
# having these payments :
# 20629, 20064, 20100, 24653, 20101, 20100,
#
# probability of being a salary : 45.86866011517364%
# having these payments :
# 37279, 20081, 37096, 19832, 19813, 23840,
#
# probability of being a salary : 96.52779415151593%
# having these payments :
# 11023, 11013, 11020, 11017, 11021, 11023,
#
# probability of being a salary : 57.470734417119765%
# having these payments :
# 22979, 22714, 39666, 22657, 22373, 22753,
#
# probability of being a salary : 84.64293408686049%
# having these payments :
# 28596, 26507, 26409, 28755, 31479, 31404,
#
# probability of being a salary : 98.41540039162368%
# having these payments :
# 11356, 11362, 11359, 11364, 11357, 11349,
#
# probability of being a salary : 98.0774712253781%
# having these payments :
# 9923, 9990, 9984, 9989, 9982, 9988,
#
# probability of being a salary : 92.73519772685196%
# having these payments :
# 23648, 23484, 23647, 23593, 21998, 22024,
#
# probability of being a salary : 98.32919066607006%
# having these payments :
# 15882, 15879, 15879, 15908, 15910, 15910,
#
# probability of being a salary : 98.4621118826316%
# having these payments :
# 18161, 18160, 18158, 18159, 18165, 18165,
#
# probability of being a salary : 98.46163031975443%
# having these payments :
# 11645, 11644, 11644, 11641, 11645, 11647,
#
# probability of being a salary : 96.0156037525247%
# having these payments :
# 25073, 25077, 25075, 25241, 25240, 25243,
#
# probability of being a salary : 20.78579206839167%
# having these payments :
# 9510, 9512, 4308, 9509, 10183, 10191, 10151,
#
# probability of being a salary : 97.85728990472056%
# having these payments :
# 10121, 10125, 10123, 10121, 10123, 10023,
#
# probability of being a salary : 56.70248919094982%
# having these payments :
# 32073, 34915, 59212, 35026, 34586, 34698,
#
# probability of being a salary : 95.51182002106783%
# having these payments :
# 22322, 22324, 22317, 22563, 22614, 22620,
#
# probability of being a salary : 98.46993656259257%
# having these payments :
# 24816, 24816, 24815, 24823, 24817, 24817,
#
# probability of being a salary : 94.62664311224138%
# having these payments :
# 12035, 12016, 12030, 11968, 11969, 12040,
#
# probability of being a salary : 98.2215364847625%
# having these payments :
# 15226, 15163, 15205, 15228, 15227, 15227,
#
# probability of being a salary : 98.45878405580763%
# having these payments :
# 17458, 17457, 17464, 17464, 17464, 17463,
#
# probability of being a salary : 98.4487618528759%
# having these payments :
# 14419, 14416, 14417, 14417, 14424, 14424,
#
# probability of being a salary : 98.08327061247672%
# having these payments :
# 13181, 13177, 13178, 13181, 13173, 13095,
#
# probability of being a salary : 28.444567556254675%
# having these payments :
# 2755, 8183, 13274, 12403, 11973,
#
# probability of being a salary : 98.44666179484737%
# having these payments :
# 12875, 12883, 12883, 12882, 12884, 12879,
#
# probability of being a salary : 94.69729259805635%
# having these payments :
# 11839, 11841, 11840, 11842, 11839, 11774,
#
# probability of being a salary : 38.81581241347968%
# having these payments :
# 39768, 44207, 33413, 27391, 16383, 20512,
#
# probability of being a salary : 98.45311261040719%
# having these payments :
# 9141, 9143, 9145, 9143, 9147, 9144,
#
# probability of being a salary : 95.0159332246257%
# having these payments :
# 11365, 11360, 11364, 11368, 11361, 11364,
#
# probability of being a salary : 81.41988103878393%
# having these payments :
# 10394, 11667, 12594, 12457, 11070, 9832,
#
# probability of being a salary : 46.70220765583317%
# having these payments :
# 73518, 65351, 122675, 118131, 62798, 65351,
#
# probability of being a salary : 98.39750542150952%
# having these payments :
# 11510, 11513, 11506, 11495, 11512, 11510,
#
# probability of being a salary : 89.61515037935644%
# having these payments :
# 8719, 8756, 8663, 9186, 8695, 8698,
#
# probability of being a salary : 94.61029311709015%
# having these payments :
# 13577, 13490, 13579, 13520, 13578, 13575,
#
# probability of being a salary : 82.82400679257445%
# having these payments :
# 11591, 12766, 15531, 12179, 12242, 12341,
#
# probability of being a salary : 96.47686267692906%
# having these payments :
# 9502, 9505, 9507, 9504, 9503, 9489,
#
# probability of being a salary : 87.14278087751121%
# having these payments :
# 14090, 15660, 16594, 16072, 16834, 16137,
#
# probability of being a salary : 94.73463068063901%
# having these payments :
# 22710, 22787, 22788, 22688, 22790, 22788,
#
# probability of being a salary : 98.46377624994508%
# having these payments :
# 9701, 9704, 9701, 9703, 9701, 9704,
#
# probability of being a salary : 95.8181182974873%
# having these payments :
# 26922, 26922, 26919, 27158, 27165, 27163,
#
# probability of being a salary : 98.47399953441165%
# having these payments :
# 12999, 13001, 13001, 13002, 13000, 13002,
#
# probability of being a salary : 97.6993962653272%
# having these payments :
# 25307, 25312, 25309, 25542, 25543, 25544,
#
# probability of being a salary : 85.33045985589413%
# having these payments :
# 19826, 19405, 19131, 18465, 16240, 17499,
#
# probability of being a salary : 97.97328965937487%
# having these payments :
# 10806, 10799, 10805, 10802, 10716, 10801,
#
# probability of being a salary : 95.71689853297435%
# having these payments :
# 16569, 16566, 16569, 16740, 16732, 16736,
#
# probability of being a salary : 97.7096996594808%
# having these payments :
# 8700, 8704, 8702, 8597, 8698, 8653,
#
# probability of being a salary : 77.89272046961264%
# having these payments :
# 17801, 13764, 14570, 12406, 13313, 13675,
#
# probability of being a salary : 98.03597263055165%
# having these payments :
# 9767, 9766, 9768, 9795, 9719, 9797,
#
# probability of being a salary : 90.53169663434949%
# having these payments :
# 14842, 14368, 14841, 14364, 14838, 14844,
#
# probability of being a salary : 96.38597199068441%
# having these payments :
# 12551, 12559, 12516, 12550, 12553, 12556,
#
# probability of being a salary : 96.06914867043852%
# having these payments :
# 9225, 9221, 9221, 9227, 9229, 9151,
#
# probability of being a salary : 98.01163071859179%
# having these payments :
# 8209, 8266, 8267, 8275, 8270, 8272,
#
# probability of being a salary : 97.6829539182915%
# having these payments :
# 8024, 7970, 7924, 8024, 8020, 8017,
#
# probability of being a salary : 96.72581436551319%
# having these payments :
# 10329, 10324, 10332, 10325, 10327, 10325,
#
# probability of being a salary : 96.31193055936315%
# having these payments :
# 12375, 12421, 12424, 12423, 12388, 12421,
#
# probability of being a salary : 95.02374322184791%
# having these payments :
# 12739, 12745, 12739, 12740, 12738, 12742,
#
# probability of being a salary : 94.33616786718805%
# having these payments :
# 8231, 8230, 8226, 8136, 8225, 8229,
#
# probability of being a salary : 94.26351711166005%
# having these payments :
# 7995, 8004, 8004, 8002, 8007, 7904,
#
# probability of being a salary : 98.13108172893375%
# having these payments :
# 9060, 9054, 9025, 9013, 9060, 9058,
#
# probability of being a salary : 94.66901010538153%
# having these payments :
# 9222, 9190, 9216, 9223, 9215, 9166,
#
# probability of being a salary : 96.50950101517914%
# having these payments :
# 10918, 10924, 10918, 10924, 10876, 10916,
#
# probability of being a salary : 81.28244342631893%
# having these payments :
# 12809, 12721, 13180, 15940, 14909, 12967,
#
# probability of being a salary : 75.11105624174887%
# having these payments :
# 32620, 27443, 27882, 27502, 36419, 36310,
#
# probability of being a salary : 95.73057318850428%
# having these payments :
# 8862, 8857, 9152, 8862, 9147, 9150,
#
# probability of being a salary : 98.45984876117342%
# having these payments :
# 11854, 11857, 11859, 11858, 11854, 11855,
#
# probability of being a salary : 98.08486314486831%
# having these payments :
# 10221, 10225, 10220, 10158, 10224, 10221,
#
# probability of being a salary : 97.89670937591943%
# having these payments :
# 10521, 10516, 10517, 10421, 10517, 10519,
#
# probability of being a salary : 84.82630626940124%
# having these payments :
# 14554, 14323, 15207, 14766, 17077, 15089,
#
# probability of being a salary : 98.4001115789865%
# having these payments :
# 8687, 8682, 8680, 8681, 8687, 8674,
#
# probability of being a salary : 97.54801865237022%
# having these payments :
# 7806, 7807, 7706, 7775, 7801, 7714,
#
# probability of being a salary : 96.37942841408983%
# having these payments :
# 10278, 10309, 10309, 10311, 10311, 10313,
#
# probability of being a salary : 95.0287138200132%
# having these payments :
# 14487, 14483, 14482, 14488, 14483, 14486,
#
# probability of being a salary : 86.89734325265242%
# having these payments :
# 9196, 9102, 9190, 11121, 9192, 9194,
#
# probability of being a salary : 98.0867113064969%
# having these payments :
# 12487, 12478, 12480, 12486, 12483, 12405,
#
# probability of being a salary : 98.41944202620483%
# having these payments :
# 11338, 11326, 11340, 11335, 11338, 11335,
#
# probability of being a salary : 98.37028933566741%
# having these payments :
# 10395, 10378, 10394, 10399, 10395, 10399,
#
# probability of being a salary : 97.78327516285563%
# having these payments :
# 8339, 8333, 8337, 8244, 8337, 8331,
#
# probability of being a salary : 98.3132195638388%
# having these payments :
# 12662, 12625, 12658, 12658, 12660, 12659,
#
# probability of being a salary : 79.36392063788989%
# having these payments :
# 30756, 22724, 23542, 23061, 23105, 22435,
#
# probability of being a salary : 23.846737390455143%
# having these payments :
# 1145, 17062, 17386, 17029, 18816, 17976,
#
# probability of being a salary : 96.62072751028914%
# having these payments :
# 9985, 9912, 9997, 9999, 10000,
#
# probability of being a salary : 37.0298476169595%
# having these payments :
# 7134, 7135, 5783, 8390, 8382, 8321, 8386,
#
# probability of being a salary : 71.11951648246007%
# having these payments :
# 20974, 21130, 21831, 21808, 24664, 30944,
#
# probability of being a salary : 90.05055862842441%
# having these payments :
# 9418, 9681, 9684, 9317, 10489, 9575,
#
# probability of being a salary : 98.05183353315917%
# having these payments :
# 12856, 12901, 12909, 12906, 12900, 12909,
#
# probability of being a salary : 62.848227313805296%
# having these payments :
# 7574, 14980, 15535, 15041, 15539, 15540,
#
# probability of being a salary : 87.62768502494303%
# having these payments :
# 8086, 8085, 8082, 8083, 7202, 7205,
#
# probability of being a salary : 91.574984113261%
# having these payments :
# 15033, 16541, 17131, 16306, 16567, 15898,
#
# probability of being a salary : 81.61396116025426%
# having these payments :
# 20505, 20376, 21304, 26240, 20686, 20461,
#
# probability of being a salary : 98.44954820169946%
# having these payments :
# 13948, 13947, 13947, 13941, 13940, 13946,
#
# probability of being a salary : 97.44487071820427%
# having these payments :
# 28625, 28755, 28757, 28624, 28890, 28434,
#
# probability of being a salary : 98.45018625135214%
# having these payments :
# 16203, 16208, 16202, 16206, 16198, 16208,
#
# probability of being a salary : 88.02918653193387%
# having these payments :
# 12539, 14217, 13541, 12913, 12988, 13006,
#
# probability of being a salary : 91.30857568249809%
# having these payments :
# 20343, 20898, 19325, 19285, 18702, 18699,
#
# probability of being a salary : 97.45516522745773%
# having these payments :
# 11370, 11285, 11321, 11323, 11479, 11276,
#
# probability of being a salary : 54.61297398020335%
# having these payments :
# 16073, 23849, 15728, 10033, 16243, 16116,
#
# probability of being a salary : 83.04228254597703%
# having these payments :
# 34851, 34787, 34259, 34074, 41645, 39347,
#
# probability of being a salary : 97.99902845183107%
# having these payments :
# 10593, 10600, 10594, 10516, 10596, 10600,
#
# probability of being a salary : 98.10106150078308%
# having these payments :
# 11503, 11500, 11434, 11501, 11508, 11504,
#
# probability of being a salary : 98.45951259200689%
# having these payments :
# 10058, 10060, 10061, 10058, 10062, 10062,
#
# probability of being a salary : 94.30695997373559%
# having these payments :
# 10097, 10088, 10191, 10188, 10168, 10192,
#
# probability of being a salary : 94.63941326317365%
# having these payments :
# 12752, 12839, 12835, 12834, 12839, 12826,
#
# probability of being a salary : 83.0037034965647%
# having these payments :
# 31177, 31173, 39065, 31129, 31179, 31326,
#
# probability of being a salary : 94.59454581718599%
# having these payments :
# 8673, 8670, 8669, 8667, 8672, 8608,
#
# probability of being a salary : 74.56824750707716%
# having these payments :
# 12173, 12513, 14793, 11125, 11248,
#
# probability of being a salary : 1.7677392782786683%
# having these payments :
# 8080, 8077, 20590, 11533, 11534, 11533, 11538,
#
# probability of being a salary : 85.5246052729735%
# having these payments :
# 16964, 16282, 16173, 18737, 16958, 18260,
#
# probability of being a salary : 71.99978502351736%
# having these payments :
# 12729, 12380, 12573, 17914, 12742, 13257,
#
# probability of being a salary : 83.69634138426021%
# having these payments :
# 29577, 26624, 29071, 27177, 34402, 30549,
#
# probability of being a salary : 88.98740842409829%
# having these payments :
# 15333, 15255, 15227, 17678, 15369, 15659,
#
# probability of being a salary : 97.91151593815592%
# having these payments :
# 10700, 10734, 10735, 10738, 10641, 10743,
#
# probability of being a salary : 98.26272274936673%
# having these payments :
# 14534, 14490, 14530, 14531, 14494, 14534,
#
# probability of being a salary : 97.85444577853524%
# having these payments :
# 14163, 14165, 14167, 14108, 14163, 14072,
#
# probability of being a salary : 96.74636058158424%
# having these payments :
# 15762, 15766, 15764, 15760, 15765, 15760,
#
# probability of being a salary : 94.86638413751592%
# having these payments :
# 10731, 10705, 10735, 10739, 10740, 10733,
#
# probability of being a salary : 81.63714367465579%
# having these payments :
# 14937, 14851, 15001, 15209, 11614, 15102,
#
# probability of being a salary : 82.61347159743194%
# having these payments :
# 20666, 24839, 25028, 24992, 25036, 27580,
#
# probability of being a salary : 82.8482964635956%
# having these payments :
# 13040, 14330, 14253, 10788, 12617, 12863,
#
# probability of being a salary : 97.93306419156796%
# having these payments :
# 9085, 9082, 9081, 9084, 9081, 9004,
#
# probability of being a salary : 98.10535699533628%
# having these payments :
# 9935, 9975, 9974, 9976, 9977, 9923,
#
# probability of being a salary : 98.46343474473369%
# having these payments :
# 17247, 17247, 17249, 17249, 17247, 17254,
#
# probability of being a salary : 98.2657133647653%
# having these payments :
# 22409, 22407, 22402, 22406, 22329, 22409,
#
# probability of being a salary : 85.15697656701184%
# having these payments :
# 24384, 24371, 27025, 27385, 28717, 24268,
#
# probability of being a salary : 98.45881344753619%
# having these payments :
# 16469, 16470, 16468, 16464, 16462, 16467,
#
# probability of being a salary : 98.26225111262517%
# having these payments :
# 16195, 16191, 16191, 16196, 16199, 16200,
#
# probability of being a salary : 95.77314937952404%
# having these payments :
# 15571, 15572, 15574, 15729, 15728, 15699,
#
# probability of being a salary : 98.22540453052905%
# having these payments :
# 11688, 11690, 11694, 11680, 11694, 11694,
#
# probability of being a salary : 98.28047632757637%
# having these payments :
# 13649, 13631, 13647, 13653, 13650, 13606,
#
# probability of being a salary : 95.45729674449613%
# having these payments :
# 11399, 10992, 11400, 11019, 11404, 11401,
#
# probability of being a salary : 64.47836259021543%
# having these payments :
# 25072, 37114, 25575, 25429, 39990, 28659,
#
# probability of being a salary : 97.61725727183786%
# having these payments :
# 8470, 8390, 8392, 8484, 8486, 8485,
#
# probability of being a salary : 52.90469349777668%
# having these payments :
# 14906, 19036, 29509, 15018, 20354, 17331,
#
# probability of being a salary : 96.72823337263162%
# having these payments :
# 9485, 9488, 9481, 9485, 9484, 9488,
#
# probability of being a salary : 93.41036196107791%
# having these payments :
# 17287, 16561, 16514, 17103, 16557, 16561,
#
# probability of being a salary : 98.2903504691475%
# having these payments :
# 12351, 12351, 12346, 12312, 12352, 12349,
#
# probability of being a salary : 96.54156280534069%
# having these payments :
# 10132, 10132, 10139, 10136, 10135, 10136,
#
# probability of being a salary : 98.23476908133046%
# having these payments :
# 12169, 12172, 12167, 12122, 12166, 12174,
#
# probability of being a salary : 83.75340465441656%
# having these payments :
# 26804, 30183, 28193, 25800, 32033, 30619,
#
# probability of being a salary : 94.83307687324557%
# having these payments :
# 10040, 10036, 10039, 10038, 10035, 10003,
#
# probability of being a salary : 44.557423032702495%
# having these payments :
# 16143, 10862, 13989, 13996, 13992, 13988, 13991,
#
# probability of being a salary : 96.74902733644535%
# having these payments :
# 26032, 25636, 25561, 26033, 25309, 25832,
#
# probability of being a salary : 99.99665428782217%
# having these payments :
# 18901, 18897, 18901, 18902, 18901, 18904,
#
# probability of being a salary : 94.81237888916257%
# having these payments :
# 10584, 10581, 10550, 10578, 10579, 10548,
#
# probability of being a salary : 28.031988616809645%
# having these payments :
# 45357, 111290, 41850, 51557, 80848, 46976,
#
# probability of being a salary : 96.28037091048654%
# having these payments :
# 10396, 10400, 10397, 10394, 10391, 10347,
#
# probability of being a salary : 71.76654277187914%
# having these payments :
# 38381, 33106, 31282, 41630, 48408, 34171,
#
# probability of being a salary : 45.27909222477502%
# having these payments :
# 11020, 11051, 11397, 11230, 5130, 5173,
#
# probability of being a salary : 90.76266631573247%
# having these payments :
# 9880, 9836, 9886, 9783, 9886, 9886,
#
# probability of being a salary : 92.15565116389953%
# having these payments :
# 13998, 14845, 14423, 14014, 14714, 13819,
#
# probability of being a salary : 94.45070697860444%
# having these payments :
# 9440, 9449, 9448, 9448, 9449, 9358,
#
# probability of being a salary : 98.21882174627274%
# having these payments :
# 14009, 14006, 14003, 13948, 14011, 14003,
#
# probability of being a salary : 94.89288683090662%
# having these payments :
# 24897, 24899, 24896, 24835, 24900, 24899,
#
# probability of being a salary : 78.65087920159314%
# having these payments :
# 24656, 23184, 23198, 23349, 30153, 27858,
#
# probability of being a salary : 96.07337182810815%
# having these payments :
# 18703, 18744, 18724, 18677, 18698, 18906,
#
# probability of being a salary : 97.78797598082014%
# having these payments :
# 20275, 20270, 20271, 20363, 20454, 20460,
#
# probability of being a salary : 96.45246747359387%
# having these payments :
# 15886, 15965, 15966, 15963, 15963, 15970,
#
# probability of being a salary : 98.2616781422237%
# having these payments :
# 11602, 11607, 11609, 11603, 11606, 11608,
#
# probability of being a salary : 38.04391592967995%
# having these payments :
# 17900, 39502, 19256, 17488, 26901, 18352,
#
# probability of being a salary : 94.64839893166948%
# having these payments :
# 9726, 9663, 9729, 9720, 9724, 9723,
#
# probability of being a salary : 96.0019214122772%
# having these payments :
# 8033, 8029, 8030, 8029, 7934, 8031,
#
# probability of being a salary : 96.46205087018076%
# having these payments :
# 9483, 9481, 9486, 9484, 9478, 9437,
#
# probability of being a salary : 95.00435756110406%
# having these payments :
# 8073, 8078, 8075, 8072, 8071, 8076,
#
# probability of being a salary : 96.50228310725286%
# having these payments :
# 13244, 13249, 13247, 13191, 13245, 13248,
#
# probability of being a salary : 88.58886193420668%
# having these payments :
# 17491, 15974, 19746, 17440, 17091, 16748,
#
# probability of being a salary : 98.07181460830401%
# having these payments :
# 10958, 10964, 10960, 10957, 10961, 10889,
#
# probability of being a salary : 97.96001357203369%
# having these payments :
# 11031, 11117, 11053, 11111, 11112, 11112,
#
# probability of being a salary : 96.06398366810444%
# having these payments :
# 12382, 12375, 12383, 12303, 12378, 12298,
#
# probability of being a salary : 98.00617562381278%
# having these payments :
# 13156, 13164, 13161, 13062, 13163, 13160,
#
# probability of being a salary : 51.886586726528364%
# having these payments :
# 13362, 13377, 14960, 18923, 13345, 25618,
#
# probability of being a salary : 95.7245367154907%
# having these payments :
# 19664, 19761, 19765, 19917, 19916, 19918,
#
# probability of being a salary : 31.54094993777229%
# having these payments :
# 9490, 9485, 9491, 9493, 9486, 11323, 13996,
#
# probability of being a salary : 94.56111926105794%
# having these payments :
# 9810, 9811, 9808, 9733, 9810, 9803,
#
# probability of being a salary : 97.80258729152945%
# having these payments :
# 8757, 8856, 8852, 8824, 8853, 8851,
#
# probability of being a salary : 96.60749592297663%
# having these payments :
# 12022, 12015, 12020, 11989, 12022, 12016,
#
# probability of being a salary : 96.51460089543136%
# having these payments :
# 13320, 13319, 13326, 13327, 13326, 13312,
#
# probability of being a salary : 98.3014213482109%
# having these payments :
# 12668, 12663, 12629, 12668, 12664, 12665,
#
# probability of being a salary : 97.99638931790588%
# having these payments :
# 11995, 11993, 11995, 11995, 11901, 11967,
#
# probability of being a salary : 77.27058118434948%
# having these payments :
# 11825, 14482, 11434, 10357, 11791, 12014,
#
# probability of being a salary : 95.57224160548054%
# having these payments :
# 21245, 21249, 21242, 21493, 21498, 21500,
#
# probability of being a salary : 98.43576902796126%
# having these payments :
# 9921, 9917, 9912, 9915, 9920, 9916,
#
# probability of being a salary : 95.02739339097049%
# having these payments :
# 12512, 12513, 12513, 12516, 12514, 12518,
#
# probability of being a salary : 98.24584801511503%
# having these payments :
# 14397, 14450, 14448, 14448, 14456, 14426,
#
# probability of being a salary : 98.46114818514287%
# having these payments :
# 14558, 14560, 14557, 14560, 14555, 14562,
#
# probability of being a salary : 56.16962325619325%
# having these payments :
# 33913, 37365, 64442, 36764, 41442, 37349,
#
# probability of being a salary : 97.97432590987228%
# having these payments :
# 8383, 8383, 8384, 8388, 8326, 8338,
#
# probability of being a salary : 94.99917554381712%
# having these payments :
# 8913, 8917, 8919, 8912, 8919, 8913,
#
# probability of being a salary : 98.01066483867238%
# having these payments :
# 9574, 9567, 9498, 9568, 9570, 9566,
#
# probability of being a salary : 95.19092320683326%
# having these payments :
# 12674, 12679, 12678, 12873, 12887, 12892,
#
# probability of being a salary : 37.24503145751957%
# having these payments :
# 41225, 19372, 19015, 19018, 21959, 19218,
#
# probability of being a salary : 94.83036876751498%
# having these payments :
# 9170, 9151, 9166, 9142, 9172, 9175,
#
# probability of being a salary : 98.04053291284937%
# having these payments :
# 10077, 10144, 10095, 10087, 10144, 10105,
#
# probability of being a salary : 94.2760879538465%
# having these payments :
# 8340, 8267, 8250, 8341, 8340, 8287,
#
# probability of being a salary : 88.22903739673293%
# having these payments :
# 9358, 9359, 9362, 9267, 9358, 10323,
#
# probability of being a salary : 70.03518682657642%
# having these payments :
# 15948, 16063, 16070, 24337, 17471, 17610,
#
# probability of being a salary : 98.45062642058868%
# having these payments :
# 13681, 13683, 13676, 13685, 13678, 13680,
#
# probability of being a salary : 94.06782641485646%
# having these payments :
# 13234, 12787, 13231, 12807, 13234, 13238,
#
# probability of being a salary : 32.24831860471134%
# having these payments :
# 7812, 7811, 7816, 7770, 7723, 6902, 11004,
#
# probability of being a salary : 98.45066288789384%
# having these payments :
# 15130, 15137, 15130, 15133, 15129, 15137,
#
# probability of being a salary : 88.32400943045904%
# having these payments :
# 12029, 12294, 12284, 13673, 11791, 12124,
#
# probability of being a salary : 98.35221365295409%
# having these payments :
# 8762, 8770, 8763, 8750, 8770, 8768,
#
# probability of being a salary : 98.09013122332544%
# having these payments :
# 16951, 16944, 16950, 16953, 16946, 16894,
#
# probability of being a salary : 86.96377960131719%
# having these payments :
# 16184, 17481, 17781, 16054, 18948, 17675,
#
# probability of being a salary : 96.4277144344336%
# having these payments :
# 15802, 15892, 15883, 15885, 15849, 15885,
#
# probability of being a salary : 98.31000347388841%
# having these payments :
# 7783, 7761, 7784, 7780, 7777, 7784,
#
# probability of being a salary : 98.4476044826939%
# having these payments :
# 11674, 11669, 11676, 11678, 11675, 11675,
#
# probability of being a salary : 96.16686259498817%
# having these payments :
# 25108, 25213, 23723, 24588, 24073, 24126,
#
# probability of being a salary : 96.00739258333483%
# having these payments :
# 7963, 7964, 7907, 7874, 7957, 7966,
#
# probability of being a salary : 98.01177613495496%
# having these payments :
# 15547, 15468, 15441, 15544, 15541, 15545,
#
# probability of being a salary : 94.48247370303832%
# having these payments :
# 38395, 38377, 38497, 38359, 40296, 40379,
#
# probability of being a salary : 27.04533332385106%
# having these payments :
# 19361, 47607, 19835, 19173, 29667, 18992,
#
# probability of being a salary : 78.57539748090716%
# having these payments :
# 25451, 25527, 25573, 25519, 32736, 30318,
#
# probability of being a salary : 95.01717011001917%
# having these payments :
# 13996, 13993, 13998, 13997, 13992, 13989,
#
# probability of being a salary : 45.85024567120743%
# having these payments :
# 22656, 20634, 40353, 21983, 20199, 20198,
#
# probability of being a salary : 78.08582184522173%
# having these payments :
# 15479, 11268, 11734, 12465, 12608, 11943,
#
# probability of being a salary : 97.93114338212696%
# having these payments :
# 10595, 10676, 10688, 10692, 10686, 10692,
#
# probability of being a salary : 94.54408190209082%
# having these payments :
# 9197, 9194, 9197, 9122, 9197, 9191,
#
# probability of being a salary : 96.07064386917169%
# having these payments :
# 15613, 15699, 15512, 15856, 15933, 16185,
#
# probability of being a salary : 98.35603177763059%
# having these payments :
# 37909, 37909, 37916, 37974, 37966, 37968,
#
# probability of being a salary : 44.19220137066729%
# having these payments :
# 21632, 42614, 22813, 21964, 36830, 21472,
#
# probability of being a salary : 97.59201336506689%
# having these payments :
# 8003, 7916, 7997, 8037, 8010, 8044,
#
# probability of being a salary : 96.50187775968412%
# having these payments :
# 8066, 8072, 8069, 8060, 8070, 8067,
#
# probability of being a salary : 96.16147091791778%
# having these payments :
# 11952, 11955, 11952, 11958, 11950, 11875,
#
# ...
# having these payments :
# 14333, 14117, 14288, 13992, 16521, 19242,
#
# probability of being a salary : 79.38810164928724%
# having these payments :
# 40599, 51104, 39017, 40458, 40793,
#
# probability of being a salary : 88.5810302273846%
# having these payments :
# 38708, 40593, 36037, 36833, 37228, 35157,
#
# probability of being a salary : 87.72017277588814%
# having these payments :
# 11991, 13295, 13093, 12336, 13356, 13434,
#
# probability of being a salary : 41.99099459630704%
# having these payments :
# 19645, 21133, 19672, 43664, 23094, 22815,
#
# probability of being a salary : 77.21941822747735%
# having these payments :
# 16476, 23468, 22876, 18453, 18873, 20158,
#
# probability of being a salary : 94.04866544009013%
# having these payments :
# 19567, 19622, 19741, 19526, 19600, 20433,
#
# probability of being a salary : 89.03995120430272%
# having these payments :
# 9780, 10798, 11234, 10492, 10184,
#
# probability of being a salary : 86.54376422983114%
# having these payments :
# 28940, 30407, 29271, 28183, 27801, 26856,
#
# probability of being a salary : 89.98225491754597%
# having these payments :
# 16974, 16471, 14635, 15253, 16248, 16338,
#
# probability of being a salary : 89.10348427682746%
# having these payments :
# 12964, 14309, 13801, 12703, 13424, 12108,
#
# probability of being a salary : 74.52628199081217%
# having these payments :
# 11977, 10197, 15172, 10570, 11271, 11200,
#
# probability of being a salary : 75.40426778265808%
# having these payments :
# 19697, 22089, 17080, 19661, 26145, 20164,
#
# probability of being a salary : 82.52396979608494%
# having these payments :
# 12446, 11047, 11075, 9470, 11076,
#
# probability of being a salary : 83.58947050994264%
# having these payments :
# 17742, 14888, 18672, 16928, 18960, 17876,
#
# probability of being a salary : 86.26089926909353%
# having these payments :
# 17558, 14819, 18072, 16473, 17160, 17034,
#
# probability of being a salary : 88.11890648580251%
# having these payments :
# 13377, 13872, 14912, 13912, 15442,
#
# probability of being a salary : 91.25032759925747%
# having these payments :
# 17760, 17520, 19070, 18562, 18237, 19045,
#
# probability of being a salary : 89.34816316398904%
# having these payments :
# 22965, 21118, 20969, 21742, 20369, 20377,
#
# probability of being a salary : 20.289049540203997%
# having these payments :
# 11794, 11685, 29675, 11391, 13264, 11566,
#
# probability of being a salary : 86.1847195269074%
# having these payments :
# 18507, 18272, 17072, 17606, 20677, 18079,
#
# probability of being a salary : 92.34652382239614%
# having these payments :
# 14607, 14378, 14632, 14659, 15711, 13979,
#
# probability of being a salary : 87.19089797743548%
# having these payments :
# 14814, 14453, 13936, 12802, 13311, 14959,
#
# probability of being a salary : 84.20489560214625%
# having these payments :
# 9261, 9903, 11253, 9328, 9329, 9334,
#
# probability of being a salary : 73.24809233858123%
# having these payments :
# 12481, 13498, 14235, 18511, 13686, 13325,
#
# probability of being a salary : 92.75795404921554%
# having these payments :
# 11667, 11652, 12217, 11508, 12191, 12010,
#
# probability of being a salary : 47.38192127993281%
# having these payments :
# 31582, 17928, 19121, 18574, 17680, 13187,
#
# probability of being a salary : 59.38019346407663%
# having these payments :
# 15081, 9502, 9427, 15873, 15877, 15954,
#
# probability of being a salary : 87.88045007151987%
# having these payments :
# 17396, 18288, 18223, 17570, 20314, 18213,
#
# probability of being a salary : 96.75915528158117%
# having these payments :
# 14450, 14451, 14448, 14449, 14450, 14451,
#
# probability of being a salary : 90.97140409973763%
# having these payments :
# 13511, 14486, 14188, 14557, 14177, 14174,
#
# probability of being a salary : 98.47376726314297%
# having these payments :
# 19571, 19573, 19569, 19571, 19569, 19573,
#
# probability of being a salary : 99.42999703049855%
# having these payments :
# 7941, 7925, 7898, 7943, 7894, 7972,
#
# probability of being a salary : 89.25575404265362%
# having these payments :
# 16297, 17408, 17216, 19083, 17846, 16418,
#
# probability of being a salary : 83.45716202177428%
# having these payments :
# 16253, 17964, 17698, 17034, 16688, 16386,
#
# probability of being a salary : 78.74250806358201%
# having these payments :
# 12878, 13143, 13322, 17377, 13416, 12919,
#
# probability of being a salary : 77.79678968322152%
# having these payments :
# 14642, 18109, 14366, 14099, 18419, 16709,
#
# probability of being a salary : 71.65400630784103%
# having these payments :
# 14293, 12258, 10969, 14596, 15685, 11878,
#
# probability of being a salary : 58.11077023478981%
# having these payments :
# 68447, 66190, 37151, 61835, 46862, 40272,
#
# probability of being a salary : 69.67469073150372%
# having these payments :
# 16323, 16754, 17352, 21674, 18579, 17634,
#
# probability of being a salary : 97.67750449362472%
# having these payments :
# 9398, 9407, 9399, 9405, 9284, 9404,
#
# probability of being a salary : 88.05270265707134%
# having these payments :
# 20406, 17743, 20481, 20639, 20456, 20301,
#
# probability of being a salary : 75.05079280657284%
# having these payments :
# 8489, 8559, 8645, 12015, 8848, 8724,
#
# probability of being a salary : 84.27896239161822%
# having these payments :
# 21470, 21783, 21719, 25504, 20963, 20880,
#
# probability of being a salary : 86.58258031610303%
# having these payments :
# 18037, 16998, 19217, 16009, 17270, 15680,
#
# probability of being a salary : 64.53601206989204%
# having these payments :
# 29376, 23337, 23626, 36995, 22563, 22972,
#
# probability of being a salary : 71.92719191862756%
# having these payments :
# 28924, 28124, 30402, 36594, 28366, 27167,
#
# probability of being a salary : 63.832464660911995%
# having these payments :
# 27702, 17547, 16946, 16547, 18320, 17846,
#
# probability of being a salary : 91.6722095839032%
# having these payments :
# 14188, 15927, 15081, 14265, 15028, 15249,
#
# probability of being a salary : 85.50652602560866%
# having these payments :
# 21081, 20961, 20968, 20965, 20301, 20320,
#
# probability of being a salary : 66.02462301586772%
# having these payments :
# 5042, 8512, 8535, 8533, 8530,
#
# probability of being a salary : 85.02931392962168%
# having these payments :
# 16945, 18582, 18836, 17793, 21413, 17447,
#
# probability of being a salary : 19.561752970329493%
# having these payments :
# 45812, 45810, 94646, 45870, 29748, 27359,
#
# probability of being a salary : 64.06541534965544%
# having these payments :
# 13029, 19229, 13032, 19026, 13008, 13082,
#
# probability of being a salary : 78.52326900885699%
# having these payments :
# 38451, 47525, 37169, 39139, 51991, 41916,
#
# probability of being a salary : 98.05866632516522%
# having these payments :
# 23837, 23781, 23756, 23695, 23784, 23658,
#
# probability of being a salary : 62.88803393794944%
# having these payments :
# 95503, 93590, 107577, 165453, 114359, 116086,
#
# probability of being a salary : 30.444567997736428%
# having these payments :
# 16383, 16789, 15645, 19476, 3789, 9835,
#
# probability of being a salary : 96.33457869188457%
# having these payments :
# 10908, 10956, 10982, 10935, 10909, 10966,
#
# probability of being a salary : 61.48877698711315%
# having these payments :
# 12154, 16598, 16510, 19993, 23930, 20950,
#
# probability of being a salary : 44.44634314399401%
# having these payments :
# 19666, 19601, 11412, 12825, 27754, 15511,
#
# probability of being a salary : 77.84399992902603%
# having these payments :
# 14325, 15217, 17288, 15670, 15004, 19085,
#
# probability of being a salary : 72.45177841287726%
# having these payments :
# 55658, 49194, 57592, 46857, 49104, 47512,
#
# probability of being a salary : 89.5734145946953%
# having these payments :
# 23279, 21973, 23155, 23307, 23221, 23306,
#
# probability of being a salary : 87.08249587133622%
# having these payments :
# 15220, 15325, 15245, 15279, 17658, 15360,
#
# probability of being a salary : 95.0415936021939%
# having these payments :
# 33561, 33557, 33562, 33555, 33555, 33559,
#
# probability of being a salary : 80.61333429281416%
# having these payments :
# 18152, 14189, 14167, 14114, 13908, 14018,
#
# probability of being a salary : 92.66008435772926%
# having these payments :
# 10236, 11298, 10631, 10297, 10572, 10341,
#
# probability of being a salary : 97.09934114277397%
# having these payments :
# 28366, 28990, 28996, 28990, 28997, 28993,
#
# probability of being a salary : 68.65223858602016%
# having these payments :
# 20552, 17275, 13735, 14960, 18221, 14505,
#
# probability of being a salary : 49.846523245521745%
# having these payments :
# 23686, 44161, 24742, 24586, 24595, 25081,
#
# probability of being a salary : 85.00604564703342%
# having these payments :
# 15200, 14671, 17653, 18116, 17425, 15990,
#
# probability of being a salary : 71.28019548134337%
# having these payments :
# 29975, 18879, 22381, 23975, 22852, 19493,
#
# probability of being a salary : 80.29058349165255%
# having these payments :
# 10805, 10660, 8870, 11643, 12669, 10844,
#
# probability of being a salary : 43.70088952187984%
# having these payments :
# 7478, 9285, 18408, 18277, 19771, 16855,
#
# probability of being a salary : 96.23478767716135%
# having these payments :
# 25302, 25433, 25435, 25293, 25234, 25261,
#
# probability of being a salary : 35.20064167028588%
# having these payments :
# 16459, 27526, 11070, 19297, 27520, 13818,
#
# probability of being a salary : 83.71911313834424%
# having these payments :
# 18039, 14744, 17171, 16968, 16377, 14113,
#
# probability of being a salary : 86.55140222268301%
# having these payments :
# 18648, 20706, 20745, 21548, 20894, 19266,
#
# probability of being a salary : 56.5518766768208%
# having these payments :
# 27264, 47199, 28215, 27997, 29666, 28575,
#
# probability of being a salary : 76.07870699543652%
# having these payments :
# 25684, 25739, 25796, 25658, 35330, 25876,
#
# probability of being a salary : 95.78825680962701%
# having these payments :
# 12086, 12023, 12127, 12037, 12086, 11911,
#
# probability of being a salary : 4.6389727903411%
# having these payments :
# 16143, 15986, 33010, 15739, 18279, 16504, 14810,
#
# probability of being a salary : 87.8020403098324%
# having these payments :
# 23622, 23055, 23470, 22350, 23823, 19768,
#
# probability of being a salary : 55.588293650334876%
# having these payments :
# 12867, 13429, 14419, 24710, 18606, 17294,
#
# probability of being a salary : 83.74658772453802%
# having these payments :
# 37996, 38997, 45313, 45054, 38457, 39197,
#
# probability of being a salary : 61.59447697672772%
# having these payments :
# 21195, 14455, 15365, 23199, 14703, 14720,
#
# probability of being a salary : 68.12858238132537%
# having these payments :
# 17021, 18106, 17959, 25363, 18063, 18357,
#
# probability of being a salary : 64.8427248485216%
# having these payments :
# 10193, 15561, 10053, 10068, 13263, 10033,
#
# probability of being a salary : 65.22108015754546%
# having these payments :
# 14194, 13955, 20957, 12774, 14652, 13240,
#
# probability of being a salary : 93.75698765433526%
# having these payments :
# 14907, 14872, 14862, 14983, 15553, 14871,
#
# probability of being a salary : 78.31563394071607%
# having these payments :
# 20827, 17457, 20465, 16597, 15815, 15676,
#
# probability of being a salary : 65.8032281981364%
# having these payments :
# 10610, 10311, 10820, 16384, 10494, 10495,
#
# probability of being a salary : 88.89185197753447%
# having these payments :
# 16297, 16391, 16506, 16357, 16521, 16405,
#
# probability of being a salary : 96.33217879675642%
# having these payments :
# 19687, 19719, 19656, 20350, 19680, 19681,
#
# probability of being a salary : 46.07262192619564%
# having these payments :
# 19220, 21365, 20286, 39564, 19563, 19666,
#
# probability of being a salary : 66.13583116703097%
# having these payments :
# 20880, 16516, 13709, 13427, 17559, 12972,
#
# probability of being a salary : 86.11880103945751%
# having these payments :
# 13180, 14427, 14808, 15951, 14916, 15804,
#
# probability of being a salary : 87.54362457424462%
# having these payments :
# 13276, 13198, 13276, 15177, 13274, 13273,
#
# probability of being a salary : 28.07373617326353%
# having these payments :
# 21376, 27435, 21476, 55167, 22346, 24315,
#
# probability of being a salary : 90.55284259941423%
# having these payments :
# 26471, 26810, 25774, 26163, 25091, 27202,
#
# probability of being a salary : 87.92248056277896%
# having these payments :
# 12828, 13085, 14587, 13878, 15360, 13853,
#
# probability of being a salary : 63.402242080265346%
# having these payments :
# 7496, 12604, 14238, 14461, 14228,
#
# probability of being a salary : 80.49202948706424%
# having these payments :
# 18970, 19806, 18107, 22908, 18872, 17044,
#
# probability of being a salary : 60.73780764001933%
# having these payments :
# 14033, 16296, 18253, 17988, 24748, 24638,
#
# probability of being a salary : 84.30185060870107%
# having these payments :
# 12539, 11051, 11049, 9898, 10497, 11046,
#
# probability of being a salary : 57.967593329837264%
# having these payments :
# 24373, 25508, 42507, 24320, 25642, 29173,
#
# probability of being a salary : 74.58955667208109%
# having these payments :
# 8541, 12452, 12687, 12257, 14022, 12264,
#
# probability of being a salary : 94.31957361759031%
# having these payments :
# 14306, 15004, 14833, 14214, 14925, 15178,
#
# probability of being a salary : 61.36289985237091%
# having these payments :
# 8487, 9586, 9376, 9441, 9567, 4896,
#
# probability of being a salary : 59.73909556264214%
# having these payments :
# 13976, 17918, 11613, 8764, 10848, 14019,
#
# probability of being a salary : 87.35847278156469%
# having these payments :
# 14226, 16567, 15877, 15853, 17067, 17464,
#
# probability of being a salary : 83.56843593187469%
# having these payments :
# 17184, 17366, 17712, 21171, 17543, 17817,
#
# probability of being a salary : 77.02506506570987%
# having these payments :
# 20008, 27415, 22535, 26097, 28089, 26641,
#
# probability of being a salary : 69.58727081564294%
# having these payments :
# 12096, 16966, 12211, 11707, 17008, 12393,
#
# probability of being a salary : 85.78336631523793%
# having these payments :
# 9157, 9126, 10731, 9160, 9088, 9071,
#
# probability of being a salary : 52.37612196512769%
# having these payments :
# 25998, 13457, 13736, 17340, 13703, 17475,
#
# probability of being a salary : 63.89232001391291%
# having these payments :
# 16745, 17355, 17285, 8922, 16391, 16344,
#
# probability of being a salary : 11.456574469322733%
# having these payments :
# 12440, 13812, 13814, 2831, 13813, 2851,
#
# probability of being a salary : 16.605138799231277%
# having these payments :
# 19000, 19045, 18186, 41984, 14524, 14528,
#
# probability of being a salary : 89.96112121012365%
# having these payments :
# 14420, 14583, 14543, 16613, 14920, 14926,
#
# probability of being a salary : 93.72611105832854%
# having these payments :
# 12209, 12266, 12492, 12320, 12816, 12285,
#
# probability of being a salary : 90.14665610076625%
# having these payments :
# 10618, 10967, 11104, 9961, 11143, 10664,
#
# probability of being a salary : 86.43799582847961%
# having these payments :
# 16136, 16995, 17292, 16668, 18125, 19343,
#
# probability of being a salary : 23.52002757785173%
# having these payments :
# 279, 8334, 8327, 8335, 8328, 8331, 8270,
#
# probability of being a salary : 12.383670951565506%
# having these payments :
# 8285, 9153, 8056, 2849, 7641, 7778,
#
# probability of being a salary : 87.92575000704073%
# having these payments :
# 20707, 19738, 20598, 18626, 22537,
#
# probability of being a salary : 12.398204575911054%
# having these payments :
# 13804, 9142, 15106, 2851, 14211,
#
# probability of being a salary : 1.7835473216167963%
# having these payments :
# 15339, 27526, 5503, 14532, 9967,
#
# probability of being a salary : 57.58748280515395%
# having these payments :
# 16535, 16553, 22041, 13815, 22027,
#
# probability of being a salary : 31.152975944645288%
# having these payments :
# 13398, 14383, 14688, 13095, 2547,
#
# probability of being a salary : 85.48973259848927%
# having these payments :
# 22615, 21663, 25448, 22611, 22635,
#
# probability of being a salary : 95.85084765239526%
# having these payments :
# 8018, 7770, 7979, 7683, 7763,
#
# probability of being a salary : 82.76682294678726%
# having these payments :
# 16555, 16554, 16558, 13817, 16470,
#
# probability of being a salary : 87.36807773165903%
# having these payments :
# 24077, 21107, 22164, 20979, 20649,

# %% [markdown]
# ### 5. Filtrácia platieb na základe periodicity
#
# Po uvedomení si nevýhod predošlého prístupu sme sa rozhodli navrhnúť nový. Jeho hlavným cieľom je odstrániť nevýhody prvého.
#
# #### 5.1. Idea
#
# Mzdy budú silne viazané na periodicitu cca 1 mesiaca, medzi nimi môžu nastať iné platby. Tie ale pravdepodobne nebudú nastávať s mesačnou periodicitou. Kedže ide o kreditné platby, nebudú obsahovať mesačné poplatky, ako napríklad za intertnet/televíziu. Pôvodná idea bolo nájsť sekvencie opakujúcich sa platieb a ich periódu opakovania. Kvôli krátkosti času sme použili zjednodušené riešenie. Nevýhodou je napríklad neodfiltrovanie príjmov napríklad z prenájmu nehnuteľnosti. Riešením tohto prípadu by bola požiadavka aspoň minimálnej variancie v dátach. Predpokladáme, že nájom je platený mesačne v identickej výške, zatiaľ čo mzda bude mať aspoň malú varianciu.
#
# 5.1.1. Hľadanie termínov mzdy
#
# Nájdeme priemer z dní v mesiaci v ktorých prichádzajú platby na účet, predpokladáme, že mzdy kvôli podobným dátumom budú mať najvyššiu váhu a priemer im bude blízky. Tento predpoklad sa nám potvrdil. Následné vypočítame odchýlku platieb od priemeru a štandardnú varianciu dátumov platieb.
# Na základe týchto parametrov sa rozhodneme či platbu (nie celý sled platieb ako pri predošlom prístupe), zaradíme do ďalšieho vyhodnocovania. Čím menšia celková odchýlka od priemeru a menšia variancia, tým je väčšia pravdepodobnosť, že sa jedná o mzdu. Pre väčšiu selektívnosť v tejto fáze taktiež zohľadnujeme výšku platby, ktorá musí byť vo vopred stanovených hraniciach. Takisto variancia dátumov nesmie prekročiť stanovenú hranicu. Po prekročení tejto hranice variancie sú dátumy v slede platieb takmer náhodné a nie je v nich mesačná periodicita ani s vysokou toleranciou posunu mzdy o niekoľko dní.
#
# 5.1.2. Selekcia na základe výšky platby
#
# Pre platby označené v bode 5.1.1. ako možné mzdy, sme postupovali ďalej. Ako vzorec pre výpočet, či sa jedná o mzdu, sme štandardnú odchýlku platieb vydelili jej priemerom. Tento údaj sme nasledne previedli na percentá, ktoré vyjadrujú istotu, že sa jedná o mzdu.
#
# #### 5.2 Implementácia

# %%
class Payment_process:
	
	def __init__(self, loaded):
		self.payments = loaded.payments
		self.keyset = loaded.keyset
		self.connections = loaded.payments_list
		
	def sort_payments(self):
		for key, value in self.payments.items():
			self.payments[key].sort(key=lambda x: x.date)
			
	def sort_connections(self, data):
		return sorted(data, key = lambda data:data[0])	#sort by date
			
	def normalize_data(self, data):
		data -= np.mean(data, keepdims = True)
		data = [int(i) for i in data]
		data /= np.std(data, keepdims = True)
		return data
	
	def scale_data(self, data):
		return (data - np.min(data))/np.ptp(data)
	
	def scale_data_from_dict(self, data, divide=None, scale=None):
		min_d = float(np.min([i for i in data.values()]))
		ptp_d = np.ptp(list(data.values()))	# range of values
		for k,v in data.items():
			data_k_fl = float(data[k])
			data[k] = (data_k_fl - min_d)/ptp_d
			if divide:
				data[k] = data_k_fl/divide
			if scale:
				data[k] = data_k_fl*scale
		return data

	def process_weights(self):
		for k,v in self.connections.items():
			for payment in v.payments:
				key_for_weights = k[:k.find('#')]
				payment.sender_weight = self.weights[key_for_weights]

	def process3(self):
		for k, v in self.connections.items():
			if len(v.date_amount) >= 2:
				#data = self.sort_connections(v.date_amount)
				dates = [d[0].day for d in v.date_amount]
				dates_mean = np.median(dates)
				dates_std = np.std(dates)
				for date_amount, payment in zip(v.date_amount, v.payments):
					date = date_amount[0]
					amount = date_amount[1]
					diff = abs(date.day - dates_mean)
					if (diff > 8 or dates_std > 7) or not (7700 < amount < 116000) or not (25 < dates_mean < 35) or payment.sender_weight not in range(8,500):
						# probably random dates or case for clustering
						# probably not salary
						pass
					else:
						v.salaries.append([date, amount])
			if len(v.salaries) > 0:
				v.salaries = np.array(v.salaries)
		self.process3_amounts()
		
	def process3_amounts(self):
		for k, v in self.connections.items():
			if len(v.salaries) >= 3:	#must have at least 3 payments to be 'salary'
				err_income = np.std(v.salaries[:,1])/np.median(v.salaries[:,1])
				if err_income < 1:
					v.salary_perc = (1 - err_income)*100
					print('probability of being a salary : ' + str(v.salary_perc) + '%')
					print('having these payments : ')
					for date, am in v.date_amount:
						print(str(date) + ' sum:' + str(am))
					print('\n')
				else:
					pass	#too big differences in salary, eg. one month comes 'year' of salary according to other months
			v.salaries = list(v.salaries)
pp = Payment_process(l)
pp.process3()
print('run successfull')
# Out:
# probability of being a salary : 99.54908412931535%
# having these payments :
# 2014-09-26 00:00:00 sum:9306
# 2014-08-26 00:00:00 sum:9211
# 2014-07-25 00:00:00 sum:9321
# 2014-06-26 00:00:00 sum:9329
# 2014-05-26 00:00:00 sum:9323
# 2014-04-28 00:00:00 sum:9330
#
#
# probability of being a salary : 99.52839427394001%
# having these payments :
# 2014-09-26 00:00:00 sum:10280
# 2014-08-26 00:00:00 sum:10164
# 2014-07-25 00:00:00 sum:10289
# 2014-06-26 00:00:00 sum:10228
# 2014-05-26 00:00:00 sum:10291
# 2014-04-28 00:00:00 sum:10301
#
#
# probability of being a salary : 96.13418894614661%
# having these payments :
# 2014-09-26 00:00:00 sum:9412
# 2014-08-28 00:00:00 sum:9344
# 2014-07-29 00:00:00 sum:8614
#
#
# probability of being a salary : 61.327509512382306%
# having these payments :
# 2014-09-26 00:00:00 sum:8069
# 2014-08-26 00:00:00 sum:15852
# 2014-06-26 00:00:00 sum:8026
# 2014-05-26 00:00:00 sum:8026
# 2014-04-28 00:00:00 sum:8083
#
#
# probability of being a salary : 99.59290093779818%
# having these payments :
# 2014-09-22 00:00:00 sum:9886
# 2014-08-15 00:00:00 sum:9886
# 2014-07-28 00:00:00 sum:9783
# 2014-06-30 00:00:00 sum:9886
# 2014-05-28 00:00:00 sum:9836
# 2014-04-28 00:00:00 sum:9880
#
#
# probability of being a salary : 99.21098936500013%
# having these payments :
# 2014-09-26 00:00:00 sum:10255
# 2014-08-26 00:00:00 sum:10045
# 2014-07-25 00:00:00 sum:10267
# 2014-06-26 00:00:00 sum:10275
# 2014-05-26 00:00:00 sum:10267
# 2014-04-28 00:00:00 sum:10214
#
#
# probability of being a salary : 80.30308229885053%
# having these payments :
# 2014-09-26 00:00:00 sum:36746
# 2014-08-25 00:00:00 sum:31126
# 2014-07-29 00:00:00 sum:25637
# 2014-06-26 00:00:00 sum:20879
# 2014-05-27 00:00:00 sum:27240
# 2014-04-29 00:00:00 sum:36497
#
#
# probability of being a salary : 87.48147257695283%
# having these payments :
# 2014-09-26 00:00:00 sum:22037
# 2014-08-27 00:00:00 sum:22003
# 2014-07-29 00:00:00 sum:16177
#
#
# probability of being a salary : 39.83270861146483%
# having these payments :
# 2014-08-19 00:00:00 sum:24422
# 2014-07-28 00:00:00 sum:23218
# 2014-06-27 00:00:00 sum:23474
# 2014-06-27 00:00:00 sum:123496
# 2014-05-28 00:00:00 sum:54679
# 2014-04-29 00:00:00 sum:20389
#
#
# probability of being a salary : 52.98244347488441%
# having these payments :
# 2014-06-26 00:00:00 sum:82362
# 2014-05-26 00:00:00 sum:41235
# 2014-04-23 00:00:00 sum:41234
#
#
# probability of being a salary : 91.19190679075786%
# having these payments :
# 2014-06-27 00:00:00 sum:22045
# 2014-05-28 00:00:00 sum:22042
# 2014-04-30 00:00:00 sum:17925
#
#
# probability of being a salary : 99.97206535654145%
# having these payments :
# 2014-06-27 00:00:00 sum:13813
# 2014-05-27 00:00:00 sum:13811
# 2014-04-29 00:00:00 sum:13820
#
#
# probability of being a salary : 75.13349813977297%
# having these payments :
# 2014-06-26 00:00:00 sum:42198
# 2014-05-28 00:00:00 sum:38735
# 2014-05-26 00:00:00 sum:18036
# 2014-04-29 00:00:00 sum:36667
#
#
# probability of being a salary : 94.1795348369133%
# having these payments :
# 2014-09-30 00:00:00 sum:10723
# 2014-07-30 00:00:00 sum:10009
# 2014-06-25 00:00:00 sum:9296
# 2014-05-19 00:00:00 sum:10014
# 2014-04-30 00:00:00 sum:6741
#
#
# probability of being a salary : 96.0275975430103%
# having these payments :
# 2014-09-29 00:00:00 sum:26053
# 2014-08-27 00:00:00 sum:26156
# 2014-07-31 00:00:00 sum:24092
# 2014-05-28 00:00:00 sum:24320
# 2014-04-29 00:00:00 sum:24020
#
#
# probability of being a salary : 99.55523543764855%
# having these payments :
# 2014-09-26 00:00:00 sum:9804
# 2014-08-26 00:00:00 sum:9703
# 2014-07-25 00:00:00 sum:9815
# 2014-06-26 00:00:00 sum:9825
# 2014-05-26 00:00:00 sum:9827
# 2014-04-28 00:00:00 sum:9821
#
#
# probability of being a salary : 99.57350502130437%
# having these payments :
# 2014-09-26 00:00:00 sum:10576
# 2014-08-26 00:00:00 sum:10535
# 2014-07-25 00:00:00 sum:10637
# 2014-06-26 00:00:00 sum:10572
# 2014-05-26 00:00:00 sum:10669
# 2014-04-28 00:00:00 sum:10624
#
#
# probability of being a salary : 79.30575522739902%
# having these payments :
# 2014-09-26 00:00:00 sum:21220
# 2014-08-21 00:00:00 sum:23074
# 2014-07-29 00:00:00 sum:32401
# 2014-06-26 00:00:00 sum:25158
# 2014-05-19 00:00:00 sum:23496
# 2014-04-25 00:00:00 sum:16287
#
#
# probability of being a salary : 97.77381234555759%
# having these payments :
# 2014-09-26 00:00:00 sum:10583
# 2014-08-27 00:00:00 sum:11112
# 2014-07-28 00:00:00 sum:10641
#
#
# probability of being a salary : 88.24505945880868%
# having these payments :
# 2014-09-26 00:00:00 sum:11021
# 2014-07-23 00:00:00 sum:13810
# 2014-06-30 00:00:00 sum:11076
#
#
# probability of being a salary : 97.28864472299057%
# having these payments :
# 2014-08-27 00:00:00 sum:19029
# 2014-07-30 00:00:00 sum:19021
# 2014-06-25 00:00:00 sum:17931
#
#
# probability of being a salary : 66.75504177116342%
# having these payments :
# 2014-07-31 00:00:00 sum:23838
# 2014-07-31 00:00:00 sum:24044
# 2014-07-31 00:00:00 sum:47800
# 2014-07-31 00:00:00 sum:47670
# 2014-07-31 00:00:00 sum:47746
# 2014-07-31 00:00:00 sum:47886
# 2014-06-24 00:00:00 sum:23807
# 2014-06-24 00:00:00 sum:24047
# 2014-05-20 00:00:00 sum:47748
# 2014-04-15 00:00:00 sum:47747
#
#
# probability of being a salary : 85.50354620935683%
# having these payments :
# 2014-06-26 00:00:00 sum:33136
# 2014-06-26 00:00:00 sum:48361
# 2014-05-21 00:00:00 sum:48365
# 2014-04-28 00:00:00 sum:50774
#
#
# probability of being a salary : 99.22420889722858%
# having these payments :
# 2014-06-30 00:00:00 sum:24396
# 2014-05-29 00:00:00 sum:24004
# 2014-04-30 00:00:00 sum:23998
#
#
# probability of being a salary : 99.85682421310962%
# having these payments :
# 2014-09-30 00:00:00 sum:12756
# 2014-08-28 00:00:00 sum:12741
# 2014-07-31 00:00:00 sum:12785
#
#
# probability of being a salary : 99.54054948961605%
# having these payments :
# 2014-09-26 00:00:00 sum:9364
# 2014-08-26 00:00:00 sum:9257
# 2014-07-25 00:00:00 sum:9372
# 2014-06-26 00:00:00 sum:9377
# 2014-05-26 00:00:00 sum:9344
# 2014-04-28 00:00:00 sum:9382
#
#
# probability of being a salary : 99.52768199611232%
# having these payments :
# 2014-09-26 00:00:00 sum:8360
# 2014-08-26 00:00:00 sum:8273
# 2014-07-25 00:00:00 sum:8378
# 2014-06-26 00:00:00 sum:8384
# 2014-05-26 00:00:00 sum:8380
# 2014-04-28 00:00:00 sum:8383
#
#
# probability of being a salary : 70.69185569035767%
# having these payments :
# 2014-09-26 00:00:00 sum:15037
# 2014-09-26 00:00:00 sum:30796
# 2014-08-26 00:00:00 sum:8331
# 2014-08-26 00:00:00 sum:22563
# 2014-07-22 00:00:00 sum:27897
# 2014-07-17 00:00:00 sum:2804
# 2014-06-26 00:00:00 sum:33148
# 2014-05-27 00:00:00 sum:30872
# 2014-04-28 00:00:00 sum:33142
#
#
# probability of being a salary : 97.8312898687044%
# having these payments :
# 2014-09-29 00:00:00 sum:12515
# 2014-08-27 00:00:00 sum:12298
# 2014-07-30 00:00:00 sum:12037
# 2014-06-27 00:00:00 sum:12696
# 2014-05-28 00:00:00 sum:12153
# 2014-04-29 00:00:00 sum:11936
#
#
# probability of being a salary : 99.52551763293584%
# having these payments :
# 2014-09-26 00:00:00 sum:11847
# 2014-08-26 00:00:00 sum:11721
# 2014-07-25 00:00:00 sum:11783
# 2014-06-26 00:00:00 sum:11865
# 2014-05-26 00:00:00 sum:11869
# 2014-04-28 00:00:00 sum:11874
#
#
# probability of being a salary : 99.48606771315262%
# having these payments :
# 2014-09-26 00:00:00 sum:10735
# 2014-08-26 00:00:00 sum:10616
# 2014-07-25 00:00:00 sum:10741
# 2014-06-17 00:00:00 sum:35927
# 2014-06-26 00:00:00 sum:10752
# 2014-05-26 00:00:00 sum:5490
# 2014-04-28 00:00:00 sum:5395
#
#
# probability of being a salary : 99.52287118130064%
# having these payments :
# 2014-09-26 00:00:00 sum:11631
# 2014-08-26 00:00:00 sum:11505
# 2014-07-25 00:00:00 sum:11561
# 2014-06-26 00:00:00 sum:11647
# 2014-05-26 00:00:00 sum:11647
# 2014-04-28 00:00:00 sum:11654
#
#
# probability of being a salary : 99.57271032555647%
# having these payments :
# 2014-09-26 00:00:00 sum:9895
# 2014-08-26 00:00:00 sum:9790
# 2014-07-25 00:00:00 sum:9905
# 2014-06-26 00:00:00 sum:9871
# 2014-05-26 00:00:00 sum:9918
# 2014-04-28 00:00:00 sum:9896
#
#
# probability of being a salary : 99.40093019679773%
# having these payments :
# 2014-09-26 00:00:00 sum:8164
# 2014-08-26 00:00:00 sum:8051
# 2014-07-25 00:00:00 sum:8175
# 2014-06-26 00:00:00 sum:8110
# 2014-05-26 00:00:00 sum:8182
# 2014-04-28 00:00:00 sum:8186
#
#
# probability of being a salary : 99.64152735280865%
# having these payments :
# 2014-08-26 00:00:00 sum:9952
# 2014-08-26 00:00:00 sum:9865
# 2014-08-26 00:00:00 sum:9910
#
#
# probability of being a salary : 69.80809069058228%
# having these payments :
# 2014-06-27 00:00:00 sum:27530
# 2014-05-29 00:00:00 sum:27516
# 2014-04-29 00:00:00 sum:27521
# 2014-04-29 00:00:00 sum:8335
#
#
# probability of being a salary : 74.96836998466227%
# having these payments :
# 2014-06-26 00:00:00 sum:105511
# 2014-06-17 00:00:00 sum:24778
# 2014-05-28 00:00:00 sum:68915
# 2014-04-23 00:00:00 sum:1791
# 2014-04-28 00:00:00 sum:68917
#
#
# probability of being a salary : 84.76948250075536%
# having these payments :
# 2014-06-27 00:00:00 sum:20666
# 2014-05-28 00:00:00 sum:28894
# 2014-04-28 00:00:00 sum:30811
#
#
# probability of being a salary : 99.44156967621508%
# having these payments :
# 2014-09-26 00:00:00 sum:7868
# 2014-08-26 00:00:00 sum:7828
# 2014-07-25 00:00:00 sum:7940
# 2014-06-26 00:00:00 sum:7946
# 2014-05-26 00:00:00 sum:7911
# 2014-04-28 00:00:00 sum:7944
#
#
# probability of being a salary : 91.3300611461742%
# having these payments :
# 2014-09-29 00:00:00 sum:13815
# 2014-09-27 00:00:00 sum:11077
# 2014-08-27 00:00:00 sum:11077
# 2014-07-27 00:00:00 sum:11074
# 2014-06-27 00:00:00 sum:11055
# 2014-05-27 00:00:00 sum:11071
# 2014-04-27 00:00:00 sum:11074
#
#
# probability of being a salary : 99.51690636802229%
# having these payments :
# 2014-09-26 00:00:00 sum:11521
# 2014-08-26 00:00:00 sum:11391
# 2014-07-25 00:00:00 sum:11460
# 2014-06-26 00:00:00 sum:11539
# 2014-05-26 00:00:00 sum:11534
# 2014-04-28 00:00:00 sum:11545
#
#
# probability of being a salary : 98.3090636767903%
# having these payments :
# 2014-09-29 00:00:00 sum:9967
# 2014-08-27 00:00:00 sum:9929
# 2014-07-30 00:00:00 sum:9870
# 2014-06-27 00:00:00 sum:9958
# 2014-05-28 00:00:00 sum:9892
# 2014-04-29 00:00:00 sum:10365
#
#
# probability of being a salary : 95.84546208793768%
# having these payments :
# 2014-09-26 00:00:00 sum:9014
# 2014-08-26 00:00:00 sum:8756
# 2014-07-23 00:00:00 sum:8575
# 2014-06-27 00:00:00 sum:9691
# 2014-05-27 00:00:00 sum:8911
# 2014-04-29 00:00:00 sum:8674
#
#
# probability of being a salary : 99.65976705426239%
# having these payments :
# 2014-09-26 00:00:00 sum:7765
# 2014-08-26 00:00:00 sum:7675
# 2014-07-25 00:00:00 sum:7679
# 2014-06-26 00:00:00 sum:7776
# 2014-05-26 00:00:00 sum:7773
# 2014-04-28 00:00:00 sum:7711
#
#
# probability of being a salary : 99.14115725126503%
# having these payments :
# 2014-09-30 00:00:00 sum:32442
# 2014-08-29 00:00:00 sum:31863
# 2014-07-31 00:00:00 sum:31860
#
#
# probability of being a salary : 99.5415612327524%
# having these payments :
# 2014-09-26 00:00:00 sum:15381
# 2014-08-26 00:00:00 sum:15214
# 2014-07-25 00:00:00 sum:15400
# 2014-06-26 00:00:00 sum:15408
# 2014-05-26 00:00:00 sum:15409
# 2014-04-28 00:00:00 sum:15410
#
#
# probability of being a salary : 88.33507340375643%
# having these payments :
# 2014-08-26 00:00:00 sum:13814
# 2014-08-31 00:00:00 sum:222
# 2014-07-28 00:00:00 sum:11069
# 2014-06-26 00:00:00 sum:139
# 2014-05-28 00:00:00 sum:11077
#
#
# probability of being a salary : 98.9334324763051%
# having these payments :
# 2014-06-30 00:00:00 sum:9704
# 2014-05-29 00:00:00 sum:9457
# 2014-04-30 00:00:00 sum:9550
#
#
# probability of being a salary : 89.96370499666222%
# having these payments :
# 2014-06-30 00:00:00 sum:59878
# 2014-05-29 00:00:00 sum:74338
# 2014-04-30 00:00:00 sum:62567
#
#
# probability of being a salary : 99.99244194593236%
# having these payments :
# 2014-06-27 00:00:00 sum:10803
# 2014-05-30 00:00:00 sum:10804
# 2014-04-28 00:00:00 sum:10802
#
#
# probability of being a salary : 84.71917293453443%
# having these payments :
# 2014-06-26 00:00:00 sum:39888
# 2014-05-29 00:00:00 sum:26843
# 2014-04-28 00:00:00 sum:35427
#
#
# probability of being a salary : 75.01315580608157%
# having these payments :
# 2014-06-26 00:00:00 sum:16528
# 2014-05-23 00:00:00 sum:19696
# 2014-04-28 00:00:00 sum:9792
#
#
# probability of being a salary : 99.54768325161257%
# having these payments :
# 2014-09-26 00:00:00 sum:13484
# 2014-08-26 00:00:00 sum:13335
# 2014-07-25 00:00:00 sum:13496
# 2014-06-26 00:00:00 sum:13511
# 2014-05-26 00:00:00 sum:13508
# 2014-04-28 00:00:00 sum:13481
#
#
# probability of being a salary : 99.53240337313416%
# having these payments :
# 2014-09-26 00:00:00 sum:9020
# 2014-08-26 00:00:00 sum:8923
# 2014-07-25 00:00:00 sum:9015
# 2014-06-26 00:00:00 sum:9046
# 2014-05-26 00:00:00 sum:9039
# 2014-04-28 00:00:00 sum:9041
#
#
# probability of being a salary : 99.067009215089%
# having these payments :
# 2014-09-29 00:00:00 sum:17923
# 2014-06-30 00:00:00 sum:18292
# 2014-05-27 00:00:00 sum:18277
#
#
# probability of being a salary : 99.48741218849916%
# having these payments :
# 2014-09-26 00:00:00 sum:9248
# 2014-08-26 00:00:00 sum:9224
# 2014-07-25 00:00:00 sum:9333
# 2014-06-26 00:00:00 sum:9335
# 2014-05-26 00:00:00 sum:9335
# 2014-04-28 00:00:00 sum:9342
#
#
# probability of being a salary : 99.4714277694487%
# having these payments :
# 2014-09-26 00:00:00 sum:7948
# 2014-08-26 00:00:00 sum:7864
# 2014-07-25 00:00:00 sum:7955
# 2014-06-26 00:00:00 sum:7965
# 2014-05-26 00:00:00 sum:7961
# 2014-04-28 00:00:00 sum:7874
#
#
# probability of being a salary : 99.92341604763551%
# having these payments :
# 2014-09-26 00:00:00 sum:7735
# 2014-08-26 00:00:00 sum:7654
# 2014-07-25 00:00:00 sum:7743
# 2014-06-26 00:00:00 sum:7753
# 2014-05-26 00:00:00 sum:7747
# 2014-04-28 00:00:00 sum:7747
#
#
# probability of being a salary : 99.5381368253535%
# having these payments :
# 2014-09-26 00:00:00 sum:13492
# 2014-08-26 00:00:00 sum:13350
# 2014-07-25 00:00:00 sum:13513
# 2014-06-26 00:00:00 sum:13527
# 2014-05-26 00:00:00 sum:13522
# 2014-04-28 00:00:00 sum:13520
#
#
# probability of being a salary : 99.51934155929439%
# having these payments :
# 2014-09-26 00:00:00 sum:8551
# 2014-08-26 00:00:00 sum:8459
# 2014-07-25 00:00:00 sum:8568
# 2014-06-26 00:00:00 sum:8577
# 2014-05-26 00:00:00 sum:8569
# 2014-04-28 00:00:00 sum:8572
#
#
# probability of being a salary : 93.5299197952793%
# having these payments :
# 2014-09-26 00:00:00 sum:9436
# 2014-08-26 00:00:00 sum:9337
# 2014-07-25 00:00:00 sum:7783
# 2014-06-26 00:00:00 sum:9403
# 2014-05-26 00:00:00 sum:9449
# 2014-04-28 00:00:00 sum:9450
#
#
# probability of being a salary : 76.33514262422186%
# having these payments :
# 2014-08-28 00:00:00 sum:22041
# 2014-08-28 00:00:00 sum:41231
# 2014-08-28 00:00:00 sum:43974
#
#
# probability of being a salary : 38.6214506703185%
# having these payments :
# 2014-06-27 00:00:00 sum:35649
# 2014-05-28 00:00:00 sum:81637
# 2014-04-29 00:00:00 sum:34804
#
#
# probability of being a salary : 53.787707384881614%
# having these payments :
# 2014-06-30 00:00:00 sum:62706
# 2014-05-29 00:00:00 sum:31667
# 2014-04-30 00:00:00 sum:31658
#
#
# probability of being a salary : 99.99312753251502%
# having these payments :
# 2014-06-26 00:00:00 sum:53569
# 2014-05-26 00:00:00 sum:53573
# 2014-04-25 00:00:00 sum:53578
#
#
# probability of being a salary : 58.071822748202884%
# having these payments :
# 2014-06-27 00:00:00 sum:65234
# 2014-05-28 00:00:00 sum:34324
# 2014-04-29 00:00:00 sum:34599
#
#
# probability of being a salary : 74.80986702929194%
# having these payments :
# 2014-09-26 00:00:00 sum:8641
# 2014-08-26 00:00:00 sum:8545
# 2014-07-25 00:00:00 sum:8655
# 2014-06-26 00:00:00 sum:8661
# 2014-05-26 00:00:00 sum:14075
#
#
# probability of being a salary : 99.56084508734489%
# having these payments :
# 2014-09-26 00:00:00 sum:8361
# 2014-08-26 00:00:00 sum:8274
# 2014-07-25 00:00:00 sum:8371
# 2014-06-26 00:00:00 sum:8376
# 2014-05-26 00:00:00 sum:8360
# 2014-04-28 00:00:00 sum:8383
#
#
# probability of being a salary : 93.0064890780133%
# having these payments :
# 2014-09-30 00:00:00 sum:8609
# 2014-08-30 00:00:00 sum:9153
# 2014-07-30 00:00:00 sum:8332
# 2014-06-28 00:00:00 sum:10223
# 2014-05-30 00:00:00 sum:8742
# 2014-04-30 00:00:00 sum:8745
#
#
# probability of being a salary : 99.54379387798014%
# having these payments :
# 2014-09-26 00:00:00 sum:11943
# 2014-08-26 00:00:00 sum:11814
# 2014-07-25 00:00:00 sum:11963
# 2014-06-26 00:00:00 sum:11969
# 2014-05-26 00:00:00 sum:11970
# 2014-04-28 00:00:00 sum:11937
#
#
# probability of being a salary : 99.26421462482539%
# having these payments :
# 2014-09-26 00:00:00 sum:9685
# 2014-08-26 00:00:00 sum:9502
# 2014-07-25 00:00:00 sum:9691
# 2014-06-26 00:00:00 sum:9705
# 2014-05-26 00:00:00 sum:9633
# 2014-04-28 00:00:00 sum:9699
#
#
# probability of being a salary : 99.57643587360346%
# having these payments :
# 2014-09-26 00:00:00 sum:9689
# 2014-08-26 00:00:00 sum:9590
# 2014-07-25 00:00:00 sum:9676
# 2014-06-26 00:00:00 sum:9712
# 2014-05-26 00:00:00 sum:9679
# 2014-04-28 00:00:00 sum:9711
#
#
# probability of being a salary : 99.55094520476878%
# having these payments :
# 2014-09-26 00:00:00 sum:10068
# 2014-08-26 00:00:00 sum:9966
# 2014-07-25 00:00:00 sum:10088
# 2014-06-26 00:00:00 sum:10090
# 2014-05-26 00:00:00 sum:10090
# 2014-04-28 00:00:00 sum:10092
#
#
# probability of being a salary : 39.54221039250952%
# having these payments :
# 2014-06-27 00:00:00 sum:79158
# 2014-05-28 00:00:00 sum:34681
# 2014-04-29 00:00:00 sum:34678
#
#
# probability of being a salary : 94.0746948809411%
# having these payments :
# 2014-06-25 00:00:00 sum:60818
# 2014-05-27 00:00:00 sum:60815
# 2014-04-28 00:00:00 sum:68461
#
#
# probability of being a salary : 54.20922060478015%
# having these payments :
# 2014-06-26 00:00:00 sum:103769
# 2014-05-28 00:00:00 sum:48271
# 2014-04-29 00:00:00 sum:54298
#
#
# probability of being a salary : 99.55483557238807%
# having these payments :
# 2014-09-26 00:00:00 sum:9396
# 2014-08-26 00:00:00 sum:9298
# 2014-07-25 00:00:00 sum:9410
# 2014-06-26 00:00:00 sum:9418
# 2014-05-26 00:00:00 sum:9409
# 2014-04-28 00:00:00 sum:9412
#
#
# probability of being a salary : 95.4995577180536%
# having these payments :
# 2014-09-26 00:00:00 sum:19639
# 2014-08-26 00:00:00 sum:17766
# 2014-07-17 00:00:00 sum:18751
# 2014-06-26 00:00:00 sum:18441
# 2014-05-26 00:00:00 sum:17183
# 2014-04-28 00:00:00 sum:18172
#
#
# probability of being a salary : 99.56114987238337%
# having these payments :
# 2014-09-26 00:00:00 sum:10852
# 2014-08-26 00:00:00 sum:10736
# 2014-07-25 00:00:00 sum:10864
# 2014-06-26 00:00:00 sum:10820
# 2014-05-26 00:00:00 sum:10867
# 2014-04-28 00:00:00 sum:10873
#
#
# probability of being a salary : 99.38707388582138%
# having these payments :
# 2014-09-26 00:00:00 sum:9567
# 2014-08-26 00:00:00 sum:9491
# 2014-07-25 00:00:00 sum:9636
# 2014-06-26 00:00:00 sum:9651
# 2014-05-26 00:00:00 sum:9647
# 2014-04-28 00:00:00 sum:9646
#
#
# probability of being a salary : 82.98350050674986%
# having these payments :
# 2014-09-26 00:00:00 sum:17716
# 2014-08-21 00:00:00 sum:21174
# 2014-07-29 00:00:00 sum:28087
# 2014-06-26 00:00:00 sum:24539
# 2014-05-19 00:00:00 sum:20672
# 2014-04-25 00:00:00 sum:18531
#
#
# probability of being a salary : 99.53311709909204%
# having these payments :
# 2014-09-26 00:00:00 sum:11385
# 2014-08-26 00:00:00 sum:11257
# 2014-07-25 00:00:00 sum:11399
# 2014-06-26 00:00:00 sum:11407
# 2014-05-26 00:00:00 sum:11383
# 2014-04-28 00:00:00 sum:11411
#
#
# probability of being a salary : 97.28353451741697%
# having these payments :
# 2014-09-30 00:00:00 sum:10562
# 2014-08-28 00:00:00 sum:11349
# 2014-07-30 00:00:00 sum:11224
# 2014-06-30 00:00:00 sum:11372
# 2014-05-29 00:00:00 sum:11367
# 2014-04-28 00:00:00 sum:11498
#
#
# probability of being a salary : 99.20558614513781%
# having these payments :
# 2014-09-26 00:00:00 sum:8691
# 2014-08-26 00:00:00 sum:8519
# 2014-07-25 00:00:00 sum:8700
# 2014-06-26 00:00:00 sum:8710
# 2014-05-26 00:00:00 sum:8624
# 2014-04-28 00:00:00 sum:8709
#
#
# probability of being a salary : 65.62087654554524%
# having these payments :
# 2014-08-26 00:00:00 sum:80306
# 2014-07-30 00:00:00 sum:34109
# 2014-07-21 00:00:00 sum:54946
#
#
# probability of being a salary : 99.99052680380693%
# having these payments :
# 2014-06-30 00:00:00 sum:30265
# 2014-05-30 00:00:00 sum:30269
# 2014-04-30 00:00:00 sum:30272
#
#
# probability of being a salary : 99.83681864350001%
# having these payments :
# 2014-06-27 00:00:00 sum:28617
# 2014-05-27 00:00:00 sum:28520
# 2014-04-29 00:00:00 sum:28621
#
#
# probability of being a salary : 99.5284142695021%
# having these payments :
# 2014-09-26 00:00:00 sum:9239
# 2014-08-26 00:00:00 sum:9131
# 2014-07-25 00:00:00 sum:9252
# 2014-06-26 00:00:00 sum:9216
# 2014-05-26 00:00:00 sum:9254
# 2014-04-28 00:00:00 sum:9252
#
#
# probability of being a salary : 81.1204617193603%
# having these payments :
# 2014-09-30 00:00:00 sum:7913
# 2014-06-25 00:00:00 sum:8376
# 2014-04-29 00:00:00 sum:11475
#
#
# probability of being a salary : 99.76013325253504%
# having these payments :
# 2014-09-29 00:00:00 sum:8964
# 2014-08-25 00:00:00 sum:8971
# 2014-07-30 00:00:00 sum:8973
# 2014-06-28 00:00:00 sum:9025
# 2014-05-26 00:00:00 sum:9001
# 2014-04-26 00:00:00 sum:8973
#
#
# probability of being a salary : 99.26969222685611%
# having these payments :
# 2014-09-29 00:00:00 sum:10063
# 2014-08-27 00:00:00 sum:10010
# 2014-07-30 00:00:00 sum:9892
# 2014-06-27 00:00:00 sum:10079
#
#
# probability of being a salary : 98.68412265362983%
# having these payments :
# 2014-09-29 00:00:00 sum:10025
# 2014-08-27 00:00:00 sum:10084
# 2014-07-30 00:00:00 sum:9888
# 2014-06-27 00:00:00 sum:10088
# 2014-05-28 00:00:00 sum:10088
# 2014-04-29 00:00:00 sum:9734
#
#
# probability of being a salary : 99.21647970285089%
# having these payments :
# 2014-09-29 00:00:00 sum:14992
# 2014-08-27 00:00:00 sum:14936
# 2014-07-30 00:00:00 sum:14928
# 2014-06-27 00:00:00 sum:14927
# 2014-05-28 00:00:00 sum:14932
# 2014-04-29 00:00:00 sum:14635
#
#
# probability of being a salary : 97.42721145933511%
# having these payments :
# 2014-09-29 00:00:00 sum:14602
# 2014-08-27 00:00:00 sum:14091
# 2014-07-30 00:00:00 sum:13595
# 2014-06-27 00:00:00 sum:14131
# 2014-05-28 00:00:00 sum:13944
# 2014-04-29 00:00:00 sum:13523
#
#
# probability of being a salary : 93.19872596949833%
# having these payments :
# 2014-09-25 00:00:00 sum:15353
# 2014-08-26 00:00:00 sum:14691
# 2014-07-24 00:00:00 sum:14730
# 2014-06-27 00:00:00 sum:16174
# 2014-05-28 00:00:00 sum:14921
# 2014-04-24 00:00:00 sum:17582
#
#
# probability of being a salary : 94.22609401020891%
# having these payments :
# 2014-09-23 00:00:00 sum:43152
# 2014-08-27 00:00:00 sum:43152
# 2014-07-28 00:00:00 sum:43157
# 2014-04-28 00:00:00 sum:48908
#
#
# probability of being a salary : 97.65037350108476%
# having these payments :
# 2014-09-29 00:00:00 sum:11356
# 2014-08-27 00:00:00 sum:11536
# 2014-07-30 00:00:00 sum:11455
# 2014-06-27 00:00:00 sum:12114
# 2014-05-28 00:00:00 sum:11524
# 2014-04-29 00:00:00 sum:11282
#
#
# probability of being a salary : 90.7412792878681%
# having these payments :
# 2014-09-26 00:00:00 sum:17245
# 2014-08-26 00:00:00 sum:22717
# 2014-07-25 00:00:00 sum:23004
# 2014-06-26 00:00:00 sum:23019
# 2014-05-26 00:00:00 sum:23013
# 2014-04-28 00:00:00 sum:23016
#
#
# probability of being a salary : 99.51063392235518%
# having these payments :
# 2014-09-26 00:00:00 sum:8321
# 2014-08-26 00:00:00 sum:8223
# 2014-07-25 00:00:00 sum:8332
# 2014-06-26 00:00:00 sum:8336
# 2014-05-26 00:00:00 sum:8335
# 2014-04-28 00:00:00 sum:8334
#
#
# probability of being a salary : 99.4951797663912%
# having these payments :
# 2014-08-28 00:00:00 sum:9245
# 2014-07-31 00:00:00 sum:7022
# 2014-06-27 00:00:00 sum:9272
# 2014-04-30 00:00:00 sum:9355
#
#
# probability of being a salary : 99.78867229181859%
# having these payments :
# 2014-08-27 00:00:00 sum:16452
# 2014-07-30 00:00:00 sum:16443
# 2014-06-26 00:00:00 sum:16361
# 2014-05-29 00:00:00 sum:16450
# 2014-04-30 00:00:00 sum:16445
#
#
# probability of being a salary : 96.69949763922703%
# having these payments :
# 2014-09-26 00:00:00 sum:11465
# 2014-08-25 00:00:00 sum:10489
# 2014-07-25 00:00:00 sum:11384
# 2014-06-25 00:00:00 sum:10901
# 2014-05-26 00:00:00 sum:11002
# 2014-04-28 00:00:00 sum:11533
#
#
# probability of being a salary : 99.77865065027596%
# having these payments :
# 2014-09-30 00:00:00 sum:16189
# 2014-08-28 00:00:00 sum:16286
# 2014-07-30 00:00:00 sum:16285
# 2014-06-30 00:00:00 sum:16238
# 2014-05-30 00:00:00 sum:16282
# 2014-04-30 00:00:00 sum:16282
#
#
# probability of being a salary : 99.87820319499131%
# having these payments :
# 2014-09-26 00:00:00 sum:13773
# 2014-08-26 00:00:00 sum:13817
# 2014-07-26 00:00:00 sum:13798
# 2014-06-26 00:00:00 sum:13813
# 2014-05-27 00:00:00 sum:13817
#
#
# probability of being a salary : 87.17388540642058%
# having these payments :
# 2014-09-26 00:00:00 sum:24422
# 2014-07-28 00:00:00 sum:24335
# 2014-06-26 00:00:00 sum:29992
# 2014-05-27 00:00:00 sum:20512
# 2014-04-28 00:00:00 sum:22876
#
#
# probability of being a salary : 93.58825677078433%
# having these payments :
# 2014-09-19 00:00:00 sum:27025
# 2014-08-26 00:00:00 sum:30399
# 2014-07-29 00:00:00 sum:25443
# 2014-06-26 00:00:00 sum:26890
# 2014-05-26 00:00:00 sum:26750
# 2014-04-29 00:00:00 sum:29580
#
#
# probability of being a salary : 99.61415908332393%
# having these payments :
# 2014-09-26 00:00:00 sum:8170
# 2014-08-26 00:00:00 sum:8096
# 2014-07-28 00:00:00 sum:7574
# 2014-06-26 00:00:00 sum:8091
# 2014-05-27 00:00:00 sum:8120
#
#
# probability of being a salary : 98.89678112018963%
# having these payments :
# 2014-09-26 00:00:00 sum:13089
# 2014-08-26 00:00:00 sum:13009
# 2014-07-28 00:00:00 sum:13284
# 2014-06-27 00:00:00 sum:12924
# 2014-05-27 00:00:00 sum:13293
# 2014-04-25 00:00:00 sum:13268
#
#
# probability of being a salary : 93.8131266754916%
# having these payments :
# 2014-09-29 00:00:00 sum:9612
# 2014-08-27 00:00:00 sum:10352
# 2014-07-29 00:00:00 sum:9609
# 2014-06-27 00:00:00 sum:9933
# 2014-05-29 00:00:00 sum:9984
# 2014-04-29 00:00:00 sum:11407
#
#
# probability of being a salary : 99.95928161307602%
# having these payments :
# 2014-08-20 00:00:00 sum:9707
# 2014-07-30 00:00:00 sum:9697
# 2014-06-24 00:00:00 sum:9704
# 2014-05-27 00:00:00 sum:9700
# 2014-04-28 00:00:00 sum:9697
#
#
# probability of being a salary : 99.87136430650287%
# having these payments :
# 2014-08-26 00:00:00 sum:11078
# 2014-07-29 00:00:00 sum:11069
# 2014-06-18 00:00:00 sum:11040
# 2014-05-28 00:00:00 sum:11077
# 2014-04-23 00:00:00 sum:11075
#
#
# probability of being a salary : 79.85278378451481%
# having these payments :
# 2014-08-27 00:00:00 sum:45811
# 2014-07-24 00:00:00 sum:42877
# 2014-06-27 00:00:00 sum:27308
# 2014-05-29 00:00:00 sum:39924
# 2014-04-25 00:00:00 sum:53734
#
#
# probability of being a salary : 64.06493205562538%
# having these payments :
# 2014-07-19 00:00:00 sum:27522
# 2014-07-19 00:00:00 sum:8227
# 2014-07-29 00:00:00 sum:23414
# 2014-06-25 00:00:00 sum:4220
# 2014-05-26 00:00:00 sum:8333
# 2014-05-26 00:00:00 sum:24787
#
#
# probability of being a salary : 88.67892928778302%
# having these payments :
# 2014-06-26 00:00:00 sum:19955
# 2014-05-26 00:00:00 sum:25876
# 2014-04-25 00:00:00 sum:26426
#
#
# probability of being a salary : 99.80775213285476%
# having these payments :
# 2014-09-26 00:00:00 sum:11071
# 2014-08-26 00:00:00 sum:11072
# 2014-07-28 00:00:00 sum:11069
# 2014-06-10 00:00:00 sum:11074
# 2014-06-26 00:00:00 sum:11077
# 2014-05-26 00:00:00 sum:11022
# 2014-04-28 00:00:00 sum:11034
#
#
# probability of being a salary : 99.97887403466748%
# having these payments :
# 2014-09-26 00:00:00 sum:11069
# 2014-08-26 00:00:00 sum:11073
# 2014-07-26 00:00:00 sum:11073
# 2014-06-26 00:00:00 sum:11075
# 2014-05-26 00:00:00 sum:11069
# 2014-04-26 00:00:00 sum:11074
#
#
# probability of being a salary : 78.04613234295272%
# having these payments :
# 2014-09-26 00:00:00 sum:17991
# 2014-08-26 00:00:00 sum:22640
# 2014-07-25 00:00:00 sum:25918
# 2014-06-26 00:00:00 sum:19079
# 2014-05-26 00:00:00 sum:33374
# 2014-04-25 00:00:00 sum:28309
#
#
# probability of being a salary : 99.9867890883702%
# having these payments :
# 2014-09-25 00:00:00 sum:27525
# 2014-08-27 00:00:00 sum:27517
# 2014-07-28 00:00:00 sum:27524
# 2014-06-26 00:00:00 sum:27525
# 2014-05-27 00:00:00 sum:27522
# 2014-04-28 00:00:00 sum:27529
#
#
# probability of being a salary : 85.28955122659721%
# having these payments :
# 2014-09-26 00:00:00 sum:27549
# 2014-07-28 00:00:00 sum:38289
# 2014-06-26 00:00:00 sum:28026
# 2014-05-27 00:00:00 sum:30714
# 2014-04-28 00:00:00 sum:27419
#
#
# probability of being a salary : 93.0001185381971%
# having these payments :
# 2014-09-26 00:00:00 sum:27292
# 2014-07-28 00:00:00 sum:30680
# 2014-06-26 00:00:00 sum:32471
# 2014-05-27 00:00:00 sum:4107
#
#
# probability of being a salary : 97.59981487595427%
# having these payments :
# 2014-09-29 00:00:00 sum:10781
# 2014-08-27 00:00:00 sum:11462
# 2014-07-29 00:00:00 sum:10788
# 2014-06-27 00:00:00 sum:11156
# 2014-05-29 00:00:00 sum:11158
# 2014-04-29 00:00:00 sum:10751
#
#
# probability of being a salary : 91.8617482960855%
# having these payments :
# 2014-09-26 00:00:00 sum:20906
# 2014-08-26 00:00:00 sum:23332
# 2014-07-25 00:00:00 sum:26426
# 2014-06-26 00:00:00 sum:26091
# 2014-05-26 00:00:00 sum:22513
# 2014-04-25 00:00:00 sum:24504
#
#
# probability of being a salary : 96.20595824970218%
# having these payments :
# 2014-09-19 00:00:00 sum:25111
# 2014-08-26 00:00:00 sum:25152
# 2014-07-29 00:00:00 sum:23447
# 2014-06-26 00:00:00 sum:24480
# 2014-05-26 00:00:00 sum:23729
# 2014-04-29 00:00:00 sum:22623
#
#
# probability of being a salary : 86.19433066897663%
# having these payments :
# 2014-09-26 00:00:00 sum:21246
# 2014-08-28 00:00:00 sum:30625
# 2014-07-28 00:00:00 sum:32076
# 2014-06-27 00:00:00 sum:28241
# 2014-05-27 00:00:00 sum:32458
# 2014-04-28 00:00:00 sum:24782
# 2014-04-30 00:00:00 sum:6655
#
#
# probability of being a salary : 98.04333587182742%
# having these payments :
# 2014-09-29 00:00:00 sum:37134
# 2014-08-28 00:00:00 sum:36642
# 2014-07-30 00:00:00 sum:35428
#
#
# probability of being a salary : 98.97795354062676%
# having these payments :
# 2014-09-26 00:00:00 sum:11159
# 2014-08-26 00:00:00 sum:10994
# 2014-06-26 00:00:00 sum:11244
# 2014-05-27 00:00:00 sum:11084
# 2014-04-28 00:00:00 sum:11317
#
#
# probability of being a salary : 99.07333519864218%
# having these payments :
# 2014-09-30 00:00:00 sum:20008
# 2014-08-28 00:00:00 sum:19845
# 2014-07-31 00:00:00 sum:20265
# 2014-06-30 00:00:00 sum:19766
# 2014-05-30 00:00:00 sum:20001
# 2014-04-30 00:00:00 sum:19713
#
#
# probability of being a salary : 32.59199177889116%
# having these payments :
# 2014-08-27 00:00:00 sum:9512
# 2014-08-27 00:00:00 sum:22917
# 2014-07-28 00:00:00 sum:7780
# 2014-07-17 00:00:00 sum:22753
# 2014-06-25 00:00:00 sum:9509
# 2014-06-13 00:00:00 sum:22913
# 2014-05-26 00:00:00 sum:7754
# 2014-05-23 00:00:00 sum:22909
# 2014-04-14 00:00:00 sum:22918
# 2014-04-28 00:00:00 sum:9510
#
#
# probability of being a salary : 99.236366433467%
# having these payments :
# 2014-09-30 00:00:00 sum:36150
# 2014-08-29 00:00:00 sum:35516
# 2014-07-31 00:00:00 sum:36031
#
#
# probability of being a salary : 45.550214701811065%
# having these payments :
# 2014-09-30 00:00:00 sum:14382
# 2014-08-27 00:00:00 sum:14829
# 2014-05-30 00:00:00 sum:16259
# 2014-04-29 00:00:00 sum:34637
#
#
# probability of being a salary : 99.62536224807542%
# having these payments :
# 2014-09-29 00:00:00 sum:9209
# 2014-08-28 00:00:00 sum:9213
# 2014-07-24 00:00:00 sum:9121
# 2014-06-26 00:00:00 sum:9181
# 2014-05-26 00:00:00 sum:9207
# 2014-04-17 00:00:00 sum:9176
#
#
# probability of being a salary : 73.46568073250165%
# having these payments :
# 2014-09-26 00:00:00 sum:22100
# 2014-08-26 00:00:00 sum:50183
# 2014-07-24 00:00:00 sum:50508
#
#
# probability of being a salary : 98.35588008582612%
# having these payments :
# 2014-09-29 00:00:00 sum:9064
# 2014-09-29 00:00:00 sum:4171
# 2014-08-28 00:00:00 sum:4241
# 2014-08-28 00:00:00 sum:9228
# 2014-07-25 00:00:00 sum:4122
# 2014-07-25 00:00:00 sum:9289
# 2014-06-25 00:00:00 sum:8903
# 2014-06-25 00:00:00 sum:4028
#
#
# probability of being a salary : 73.2694270276972%
# having these payments :
# 2014-07-28 00:00:00 sum:16908
# 2014-06-30 00:00:00 sum:16120
# 2014-05-28 00:00:00 sum:28872
# 2014-04-30 00:00:00 sum:28265
#
#
# probability of being a salary : 99.69811718751968%
# having these payments :
# 2014-09-30 00:00:00 sum:22431
# 2014-08-29 00:00:00 sum:22263
# 2014-07-31 00:00:00 sum:22387
# 2014-06-30 00:00:00 sum:22252
# 2014-05-30 00:00:00 sum:22283
# 2014-04-30 00:00:00 sum:22286
#
#
# probability of being a salary : 99.84991294951071%
# having these payments :
# 2014-09-30 00:00:00 sum:8336
# 2014-08-28 00:00:00 sum:8327
# 2014-07-31 00:00:00 sum:8313
# 2014-06-30 00:00:00 sum:8330
# 2014-05-28 00:00:00 sum:8301
# 2014-04-30 00:00:00 sum:8334
#
#
# probability of being a salary : 95.01470482482121%
# having these payments :
# 2014-09-29 00:00:00 sum:21219
# 2014-08-28 00:00:00 sum:23222
# 2014-07-29 00:00:00 sum:22651
# 2014-06-27 00:00:00 sum:24095
# 2014-05-30 00:00:00 sum:22342
# 2014-04-29 00:00:00 sum:20807
#
#
# probability of being a salary : 83.26825937426446%
# having these payments :
# 2014-09-19 00:00:00 sum:22448
# 2014-08-18 00:00:00 sum:40963
# 2014-07-22 00:00:00 sum:38219
# 2014-06-30 00:00:00 sum:41094
# 2014-05-30 00:00:00 sum:38218
# 2014-04-30 00:00:00 sum:34872
#
#
# probability of being a salary : 85.43547410619142%
# having these payments :
# 2014-09-25 00:00:00 sum:56046
# 2014-08-26 00:00:00 sum:42879
# 2014-07-28 00:00:00 sum:42060
# 2014-06-26 00:00:00 sum:39831
# 2014-05-27 00:00:00 sum:35751
# 2014-04-24 00:00:00 sum:42884
# 2014-04-28 00:00:00 sum:37392
#
#
# probability of being a salary : 96.93310190569349%
# having these payments :
# 2014-09-26 00:00:00 sum:13160
# 2014-08-27 00:00:00 sum:13190
# 2014-07-25 00:00:00 sum:13838
# 2014-06-26 00:00:00 sum:13351
# 2014-05-26 00:00:00 sum:13369
# 2014-04-25 00:00:00 sum:14306
#
#
# probability of being a salary : 79.54513930521246%
# having these payments :
# 2014-09-29 00:00:00 sum:33004
# 2014-08-28 00:00:00 sum:27528
# 2014-07-28 00:00:00 sum:19303
#
#
# probability of being a salary : 91.42857344047744%
# having these payments :
# 2014-09-19 00:00:00 sum:18898
# 2014-08-26 00:00:00 sum:24317
# 2014-07-29 00:00:00 sum:20711
# 2014-06-26 00:00:00 sum:20076
# 2014-05-26 00:00:00 sum:21520
# 2014-04-29 00:00:00 sum:23027
#
#
# probability of being a salary : 97.20008902279244%
# having these payments :
# 2014-09-29 00:00:00 sum:8556
# 2014-08-26 00:00:00 sum:9176
# 2014-07-25 00:00:00 sum:8532
# 2014-06-25 00:00:00 sum:8877
# 2014-05-27 00:00:00 sum:8911
# 2014-04-25 00:00:00 sum:8527
#
#
# probability of being a salary : 99.89706666007423%
# having these payments :
# 2014-06-30 00:00:00 sum:27466
# 2014-05-28 00:00:00 sum:27524
# 2014-04-29 00:00:00 sum:27528
#
#
# probability of being a salary : 95.14515974642667%
# having these payments :
# 2014-09-24 00:00:00 sum:12096
# 2014-08-25 00:00:00 sum:13581
# 2014-07-25 00:00:00 sum:11779
# 2014-06-27 00:00:00 sum:12482
# 2014-05-28 00:00:00 sum:11992
# 2014-04-29 00:00:00 sum:12174
#
#
# probability of being a salary : 89.35385594742186%
# having these payments :
# 2014-09-29 00:00:00 sum:31807
# 2014-08-26 00:00:00 sum:33022
# 2014-07-29 00:00:00 sum:23128
# 2014-06-24 00:00:00 sum:30508
# 2014-05-27 00:00:00 sum:30231
# 2014-04-29 00:00:00 sum:27802
#
#
# probability of being a salary : 70.04785763582547%
# having these payments :
# 2014-09-30 00:00:00 sum:27525
# 2014-08-30 00:00:00 sum:27526
# 2014-07-30 00:00:00 sum:27521
# 2014-06-24 00:00:00 sum:8332
# 2014-04-28 00:00:00 sum:13817
#
#
# probability of being a salary : 72.36487213579355%
# having these payments :
# 2014-09-29 00:00:00 sum:96141
# 2014-09-29 00:00:00 sum:4852
# 2014-08-26 00:00:00 sum:55119
# 2014-08-26 00:00:00 sum:4852
# 2014-07-30 00:00:00 sum:4777
# 2014-07-30 00:00:00 sum:55144
# 2014-06-27 00:00:00 sum:55447
# 2014-06-27 00:00:00 sum:4853
# 2014-05-30 00:00:00 sum:4852
# 2014-05-30 00:00:00 sum:55243
# 2014-04-28 00:00:00 sum:55120
# 2014-04-28 00:00:00 sum:4856
#
#
# probability of being a salary : 99.91520203926937%
# having these payments :
# 2014-04-23 00:00:00 sum:5584
# 2014-04-25 00:00:00 sum:27522
# 2014-04-26 00:00:00 sum:27473
# 2014-04-27 00:00:00 sum:27523
#
#
# probability of being a salary : 94.4914976089253%
# having these payments :
# 2014-09-24 00:00:00 sum:8071
# 2014-08-25 00:00:00 sum:9023
# 2014-07-25 00:00:00 sum:7834
# 2014-06-27 00:00:00 sum:7922
# 2014-05-28 00:00:00 sum:7681
# 2014-04-29 00:00:00 sum:8536
#
#
# probability of being a salary : 47.45904534616633%
# having these payments :
# 2014-09-24 00:00:00 sum:7803
# 2014-08-25 00:00:00 sum:10656
# 2014-07-25 00:00:00 sum:23479
# 2014-06-27 00:00:00 sum:11179
# 2014-05-28 00:00:00 sum:9502
# 2014-04-29 00:00:00 sum:5107
#
#
# probability of being a salary : 99.484825214518%
# having these payments :
# 2014-09-26 00:00:00 sum:19362
# 2014-06-27 00:00:00 sum:19606
# 2014-04-30 00:00:00 sum:19460
#
#
# probability of being a salary : 97.93235053425917%
# having these payments :
# 2014-09-29 00:00:00 sum:12420
# 2014-08-27 00:00:00 sum:12679
# 2014-07-29 00:00:00 sum:12221
# 2014-06-27 00:00:00 sum:11991
# 2014-05-28 00:00:00 sum:12100
# 2014-04-25 00:00:00 sum:12613
#
#
# probability of being a salary : 22.560138310022428%
# having these payments :
# 2014-06-30 00:00:00 sum:8461
# 2014-05-28 00:00:00 sum:8466
# 2014-04-29 00:00:00 sum:22371
#
#
# probability of being a salary : 98.75518503667197%
# having these payments :
# 2014-09-30 00:00:00 sum:28954
# 2014-08-28 00:00:00 sum:29964
# 2014-07-31 00:00:00 sum:28874
# 2014-06-30 00:00:00 sum:29024
# 2014-05-29 00:00:00 sum:29202
# 2014-04-30 00:00:00 sum:29129
#
#
# probability of being a salary : 95.68809856687453%
# having these payments :
# 2014-09-24 00:00:00 sum:11164
# 2014-08-25 00:00:00 sum:10696
# 2014-07-25 00:00:00 sum:10837
# 2014-06-27 00:00:00 sum:11175
# 2014-05-28 00:00:00 sum:10369
# 2014-04-29 00:00:00 sum:9848
#
#
# probability of being a salary : 96.1323255269606%
# having these payments :
# 2014-09-24 00:00:00 sum:14801
# 2014-08-25 00:00:00 sum:14933
# 2014-07-25 00:00:00 sum:13924
# 2014-06-27 00:00:00 sum:13793
# 2014-05-28 00:00:00 sum:13443
# 2014-04-29 00:00:00 sum:14536
#
#
# probability of being a salary : 99.43753300286244%
# having these payments :
# 2014-09-29 00:00:00 sum:9640
# 2014-08-27 00:00:00 sum:9808
# 2014-07-29 00:00:00 sum:9651
# 2014-06-30 00:00:00 sum:9710
# 2014-05-29 00:00:00 sum:9714
# 2014-04-25 00:00:00 sum:9712
#
#
# probability of being a salary : 92.09766526007618%
# having these payments :
# 2014-09-30 00:00:00 sum:15640
# 2014-08-28 00:00:00 sum:14868
# 2014-07-31 00:00:00 sum:14487
# 2014-06-30 00:00:00 sum:14660
# 2014-04-30 00:00:00 sum:17681
#
#
# probability of being a salary : 98.78161042701988%
# having these payments :
# 2014-08-26 00:00:00 sum:32628
# 2014-07-28 00:00:00 sum:31698
# 2014-06-26 00:00:00 sum:31704
# 2014-05-26 00:00:00 sum:31602
# 2014-04-28 00:00:00 sum:31663
#
#
# probability of being a salary : 89.5542010036626%
# having these payments :
# 2014-08-26 00:00:00 sum:20050
# 2014-07-29 00:00:00 sum:24460
# 2014-05-29 00:00:00 sum:19985
#
#
# probability of being a salary : 94.25638216066746%
# having these payments :
# 2014-09-24 00:00:00 sum:9629
# 2014-08-25 00:00:00 sum:11098
# 2014-07-25 00:00:00 sum:9230
# 2014-06-27 00:00:00 sum:9902
# 2014-05-28 00:00:00 sum:9969
# 2014-04-29 00:00:00 sum:10091
#
#
# probability of being a salary : 91.5866953091315%
# having these payments :
# 2014-09-24 00:00:00 sum:12209
# 2014-08-25 00:00:00 sum:10968
# 2014-07-25 00:00:00 sum:12266
# 2014-06-27 00:00:00 sum:14269
# 2014-05-28 00:00:00 sum:11682
# 2014-04-29 00:00:00 sum:11890
#
#
# probability of being a salary : 96.87947600672615%
# having these payments :
# 2014-09-25 00:00:00 sum:12298
# 2014-08-28 00:00:00 sum:13301
# 2014-07-29 00:00:00 sum:12198
# 2014-06-20 00:00:00 sum:12469
# 2014-05-26 00:00:00 sum:12555
#
#
# probability of being a salary : 96.20907836338033%
# having these payments :
# 2014-09-30 00:00:00 sum:14888
# 2014-08-28 00:00:00 sum:15835
# 2014-07-31 00:00:00 sum:15082
# 2014-06-30 00:00:00 sum:14359
# 2014-05-30 00:00:00 sum:14221
# 2014-04-30 00:00:00 sum:14399
#
#
# probability of being a salary : 76.20118466544437%
# having these payments :
# 2014-09-25 00:00:00 sum:36407
# 2014-08-26 00:00:00 sum:42498
# 2014-07-25 00:00:00 sum:43019
# 2014-06-26 00:00:00 sum:44625
# 2014-05-26 00:00:00 sum:68093
# 2014-04-24 00:00:00 sum:41738
#
#
# probability of being a salary : 98.90216545226129%
# having these payments :
# 2014-08-28 00:00:00 sum:18782
# 2014-07-25 00:00:00 sum:18709
# 2014-06-27 00:00:00 sum:18217
# 2014-05-30 00:00:00 sum:18739
# 2014-04-28 00:00:00 sum:18636
#
#
# probability of being a salary : 99.96818013254656%
# having these payments :
# 2014-09-30 00:00:00 sum:9449
# 2014-07-29 00:00:00 sum:9446
# 2014-06-25 00:00:00 sum:9455
# 2014-06-24 00:00:00 sum:9448
# 2014-04-30 00:00:00 sum:9449
#
#
# probability of being a salary : 92.87177156076297%
# having these payments :
# 2014-09-24 00:00:00 sum:10007
# 2014-08-25 00:00:00 sum:10826
# 2014-07-25 00:00:00 sum:9304
# 2014-06-27 00:00:00 sum:9608
# 2014-05-28 00:00:00 sum:9699
# 2014-04-29 00:00:00 sum:11279
#
#
# probability of being a salary : 77.85587256665053%
# having these payments :
# 2014-09-29 00:00:00 sum:27225
# 2014-08-26 00:00:00 sum:30043
# 2014-07-30 00:00:00 sum:26962
# 2014-06-27 00:00:00 sum:26511
# 2014-05-30 00:00:00 sum:19985
# 2014-04-28 00:00:00 sum:40039
#
#
# probability of being a salary : 93.754672090098%
# having these payments :
# 2014-09-26 00:00:00 sum:11762
# 2014-08-27 00:00:00 sum:12034
# 2014-07-24 00:00:00 sum:11934
# 2014-06-27 00:00:00 sum:10216
#
#
# probability of being a salary : 99.11463726568077%
# having these payments :
# 2014-09-25 00:00:00 sum:49572
# 2014-08-28 00:00:00 sum:50897
# 2014-07-31 00:00:00 sum:49880
# 2014-06-26 00:00:00 sum:50299
# 2014-05-27 00:00:00 sum:50178
#
#
# probability of being a salary : 54.91468311080507%
# having these payments :
# 2014-09-26 00:00:00 sum:36627
# 2014-08-25 00:00:00 sum:39258
# 2014-07-29 00:00:00 sum:12577
# 2014-07-29 00:00:00 sum:7235
# 2014-06-26 00:00:00 sum:16141
#
#
# probability of being a salary : 94.65017072817527%
# having these payments :
# 2014-08-25 00:00:00 sum:4415
# 2014-07-25 00:00:00 sum:1679
# 2014-06-27 00:00:00 sum:10594
# 2014-05-28 00:00:00 sum:11090
# 2014-04-29 00:00:00 sum:12025
#
#
# probability of being a salary : 94.38467592262812%
# having these payments :
# 2014-07-30 00:00:00 sum:32025
# 2014-06-27 00:00:00 sum:35311
# 2014-05-28 00:00:00 sum:37534
# 2014-04-25 00:00:00 sum:34650
#
#
# probability of being a salary : 80.84281424425343%
# having these payments :
# 2014-09-08 00:00:00 sum:1389
# 2014-09-26 00:00:00 sum:11776
# 2014-08-26 00:00:00 sum:7853
# 2014-08-26 00:00:00 sum:4123
# 2014-07-25 00:00:00 sum:14886
# 2014-06-27 00:00:00 sum:15842
# 2014-05-27 00:00:00 sum:15658
# 2014-04-25 00:00:00 sum:15017
#
#
# probability of being a salary : 97.07526605517675%
# having these payments :
# 2014-09-25 00:00:00 sum:12304
# 2014-08-28 00:00:00 sum:13300
# 2014-07-29 00:00:00 sum:12297
# 2014-06-20 00:00:00 sum:12807
# 2014-05-26 00:00:00 sum:12801
#
#
# probability of being a salary : 99.0356517628358%
# having these payments :
# 2014-09-30 00:00:00 sum:7811
# 2014-08-27 00:00:00 sum:7986
# 2014-07-31 00:00:00 sum:7818
# 2014-06-30 00:00:00 sum:7975
# 2014-05-27 00:00:00 sum:7806
# 2014-04-30 00:00:00 sum:7875
#
#
# probability of being a salary : 72.70071680783533%
# having these payments :
# 2014-09-26 00:00:00 sum:33174
# 2014-08-27 00:00:00 sum:34181
# 2014-07-25 00:00:00 sum:9881
# 2014-07-23 00:00:00 sum:33974
# 2014-06-19 00:00:00 sum:37107
# 2014-05-27 00:00:00 sum:26987
# 2014-04-16 00:00:00 sum:34304
# 2014-04-29 00:00:00 sum:4430
#
#
# probability of being a salary : 99.70637408706847%
# having these payments :
# 2014-09-29 00:00:00 sum:11728
# 2014-08-27 00:00:00 sum:11649
# 2014-07-29 00:00:00 sum:11667
# 2014-06-27 00:00:00 sum:11732
# 2014-05-27 00:00:00 sum:11726
# 2014-04-29 00:00:00 sum:11734
#
#
# probability of being a salary : 88.91157956781637%
# having these payments :
# 2014-08-25 00:00:00 sum:2677
# 2014-07-25 00:00:00 sum:6471
# 2014-06-27 00:00:00 sum:8648
# 2014-05-28 00:00:00 sum:7993
# 2014-04-29 00:00:00 sum:10274
#
#
# probability of being a salary : 82.58180266003907%
# having these payments :
# 2014-07-28 00:00:00 sum:18823
# 2014-07-28 00:00:00 sum:18829
# 2014-06-24 00:00:00 sum:26769
# 2014-06-24 00:00:00 sum:26767
#
#
# probability of being a salary : 96.35625698376565%
# having these payments :
# 2014-09-25 00:00:00 sum:13710
# 2014-08-28 00:00:00 sum:15037
# 2014-07-29 00:00:00 sum:13848
# 2014-06-20 00:00:00 sum:14214
# 2014-05-26 00:00:00 sum:13692
#
#
# probability of being a salary : 94.49912365153345%
# having these payments :
# 2014-09-26 00:00:00 sum:12778
# 2014-08-26 00:00:00 sum:14862
# 2014-07-28 00:00:00 sum:13498
# 2014-06-24 00:00:00 sum:14318
# 2014-05-26 00:00:00 sum:13315
# 2014-04-17 00:00:00 sum:8329
# 2014-04-25 00:00:00 sum:4689
#
#
# probability of being a salary : 82.42091097491053%
# having these payments :
# 2014-09-30 00:00:00 sum:9957
# 2014-08-25 00:00:00 sum:9823
# 2014-07-23 00:00:00 sum:13982
# 2014-06-27 00:00:00 sum:10014
#
#
# probability of being a salary : 88.81470654995931%
# having these payments :
# 2014-06-27 00:00:00 sum:8443
# 2014-05-28 00:00:00 sum:10075
# 2014-04-29 00:00:00 sum:11187
#
#
# probability of being a salary : 99.92702152579818%
# having these payments :
# 2014-09-29 00:00:00 sum:16560
# 2014-08-27 00:00:00 sum:16533
# 2014-07-29 00:00:00 sum:16557
#
#
# probability of being a salary : 63.048472466101224%
# having these payments :
# 2014-09-26 00:00:00 sum:18119
# 2014-09-26 00:00:00 sum:11348
# 2014-08-26 00:00:00 sum:9584
# 2014-08-26 00:00:00 sum:16359
# 2014-07-25 00:00:00 sum:22572
# 2014-07-25 00:00:00 sum:9295
# 2014-06-24 00:00:00 sum:21807
# 2014-06-24 00:00:00 sum:9807
# 2014-05-26 00:00:00 sum:17641
# 2014-05-26 00:00:00 sum:8647
# 2014-04-25 00:00:00 sum:15164
# 2014-04-25 00:00:00 sum:9344
#
#
# probability of being a salary : 95.03159337495642%
# having these payments :
# 2014-09-24 00:00:00 sum:8508
# 2014-08-25 00:00:00 sum:10024
# 2014-07-25 00:00:00 sum:9200
# 2014-06-27 00:00:00 sum:9552
# 2014-05-28 00:00:00 sum:9102
# 2014-04-29 00:00:00 sum:9260
#
#
# probability of being a salary : 93.06654786453393%
# having these payments :
# 2014-09-24 00:00:00 sum:11203
# 2014-08-25 00:00:00 sum:12539
# 2014-07-25 00:00:00 sum:12495
# 2014-06-27 00:00:00 sum:12698
# 2014-05-28 00:00:00 sum:14156
# 2014-04-29 00:00:00 sum:12233
#
#
# probability of being a salary : 94.11641734510114%
# having these payments :
# 2014-09-26 00:00:00 sum:11598
# 2014-08-26 00:00:00 sum:12341
# 2014-07-25 00:00:00 sum:11410
# 2014-06-26 00:00:00 sum:10290
# 2014-05-27 00:00:00 sum:11805
# 2014-04-28 00:00:00 sum:10740
#
#
# probability of being a salary : 92.84653119215815%
# having these payments :
# 2014-09-24 00:00:00 sum:14803
# 2014-08-25 00:00:00 sum:14340
# 2014-07-25 00:00:00 sum:13937
# 2014-06-27 00:00:00 sum:12696
# 2014-05-28 00:00:00 sum:11889
# 2014-04-29 00:00:00 sum:13652
#
#
# probability of being a salary : 86.5419275675796%
# having these payments :
# 2014-09-26 00:00:00 sum:11823
# 2014-08-26 00:00:00 sum:13532
# 2014-07-25 00:00:00 sum:13111
# 2014-06-24 00:00:00 sum:15719
# 2014-05-26 00:00:00 sum:15121
# 2014-04-25 00:00:00 sum:17725
#
#
# probability of being a salary : 95.02499275824033%
# having these payments :
# 2014-09-26 00:00:00 sum:17584
# 2014-08-21 00:00:00 sum:16405
# 2014-07-24 00:00:00 sum:16066
# 2014-06-26 00:00:00 sum:15915
# 2014-05-27 00:00:00 sum:16397
# 2014-04-28 00:00:00 sum:14852
#
#
# probability of being a salary : 89.80329890482591%
# having these payments :
# 2014-09-26 00:00:00 sum:39946
# 2014-08-26 00:00:00 sum:39933
# 2014-07-28 00:00:00 sum:48580
#
#
# probability of being a salary : 88.71701802904036%
# having these payments :
# 2014-09-26 00:00:00 sum:13183
# 2014-08-22 00:00:00 sum:13905
# 2014-07-28 00:00:00 sum:12302
# 2014-06-25 00:00:00 sum:12661
# 2014-05-26 00:00:00 sum:12625
# 2014-04-25 00:00:00 sum:16598
#
#
# probability of being a salary : 99.98429579105061%
# having these payments :
# 2014-09-29 00:00:00 sum:14115
# 2014-08-28 00:00:00 sum:14121
# 2014-07-24 00:00:00 sum:14119
# 2014-06-27 00:00:00 sum:14116
# 2014-05-29 00:00:00 sum:14120
# 2014-04-25 00:00:00 sum:14120
#
#
# probability of being a salary : 92.9713927162768%
# having these payments :
# 2014-09-26 00:00:00 sum:9386
# 2014-09-26 00:00:00 sum:1584
# 2014-08-26 00:00:00 sum:9454
# 2014-08-26 00:00:00 sum:4418
# 2014-07-28 00:00:00 sum:9497
# 2014-04-28 00:00:00 sum:10981
# 2014-04-28 00:00:00 sum:2374
#
#
# probability of being a salary : 93.22808760735055%
# having these payments :
# 2014-09-26 00:00:00 sum:14214
# 2014-08-26 00:00:00 sum:15104
# 2014-07-28 00:00:00 sum:13137
# 2014-06-25 00:00:00 sum:14789
# 2014-05-23 00:00:00 sum:13939
# 2014-04-25 00:00:00 sum:12309
#
#
# probability of being a salary : 93.44266563400674%
# having these payments :
# 2014-06-30 00:00:00 sum:9133
# 2014-05-26 00:00:00 sum:10401
# 2014-04-28 00:00:00 sum:10709
#
#
# probability of being a salary : 99.95488771018096%
# having these payments :
# 2014-09-29 00:00:00 sum:41068
# 2014-08-28 00:00:00 sum:41068
# 2014-07-28 00:00:00 sum:41015
# 2014-06-30 00:00:00 sum:41061
# 2014-05-28 00:00:00 sum:41063
# 2014-04-28 00:00:00 sum:41060
#
#
# probability of being a salary : 99.18319553650387%
# having these payments :
# 2014-09-29 00:00:00 sum:8409
# 2014-08-29 00:00:00 sum:8602
# 2014-07-30 00:00:00 sum:8460
# 2014-06-30 00:00:00 sum:8408
# 2014-05-30 00:00:00 sum:8535
# 2014-04-30 00:00:00 sum:8468
#
#
# probability of being a salary : 98.46596639256094%
# having these payments :
# 2014-09-29 00:00:00 sum:8002
# 2014-08-31 00:00:00 sum:8200
# 2014-07-30 00:00:00 sum:7889
# 2014-06-27 00:00:00 sum:7886
# 2014-05-30 00:00:00 sum:7885
# 2014-04-27 00:00:00 sum:7847
#
#
# probability of being a salary : 90.7645801755854%
# having these payments :
# 2014-09-30 00:00:00 sum:13711
# 2014-08-28 00:00:00 sum:13381
# 2014-07-23 00:00:00 sum:13005
# 2014-06-30 00:00:00 sum:13733
# 2014-05-30 00:00:00 sum:10893
# 2014-05-30 00:00:00 sum:14873
# 2014-04-30 00:00:00 sum:14833
# 2014-04-30 00:00:00 sum:12094
#
#
# probability of being a salary : 98.36658327117284%
# having these payments :
# 2014-09-23 00:00:00 sum:9883
# 2014-08-25 00:00:00 sum:9881
# 2014-07-24 00:00:00 sum:9548
# 2014-06-26 00:00:00 sum:9556
# ...
# 2014-05-28 00:00:00 sum:27526
# 2014-04-17 00:00:00 sum:54944
#
#
# probability of being a salary : 97.55622858871959%
# having these payments :
# 2014-09-26 00:00:00 sum:8835
# 2014-08-27 00:00:00 sum:8835
# 2014-07-29 00:00:00 sum:8758
# 2014-06-27 00:00:00 sum:8903
# 2014-05-27 00:00:00 sum:8901
# 2014-04-28 00:00:00 sum:9413
#
#
# probability of being a salary : 99.50309895711275%
# having these payments :
# 2014-09-19 00:00:00 sum:20779
# 2014-08-26 00:00:00 sum:20971
# 2014-07-17 00:00:00 sum:20966
# 2014-06-26 00:00:00 sum:20968
# 2014-05-27 00:00:00 sum:21106
# 2014-04-29 00:00:00 sum:20966
#
#
# probability of being a salary : 99.65758849836048%
# having these payments :
# 2014-09-29 00:00:00 sum:11689
# 2014-08-28 00:00:00 sum:11809
# 2014-07-28 00:00:00 sum:11711
# 2014-06-27 00:00:00 sum:11762
# 2014-05-27 00:00:00 sum:11761
# 2014-04-29 00:00:00 sum:11716
#
#
# probability of being a salary : 99.87329051769758%
# having these payments :
# 2014-09-28 00:00:00 sum:13811
# 2014-08-28 00:00:00 sum:13815
# 2014-07-28 00:00:00 sum:13820
# 2014-06-28 00:00:00 sum:13819
# 2014-05-28 00:00:00 sum:13808
# 2014-04-28 00:00:00 sum:13769
#
#
# probability of being a salary : 99.31763586564372%
# having these payments :
# 2014-07-28 00:00:00 sum:8273
# 2014-05-26 00:00:00 sum:8404
# 2014-04-28 00:00:00 sum:8299
#
#
# probability of being a salary : 99.73563080102943%
# having these payments :
# 2014-09-26 00:00:00 sum:10113
# 2014-08-25 00:00:00 sum:10113
# 2014-07-25 00:00:00 sum:10117
# 2014-06-25 00:00:00 sum:10110
# 2014-05-28 00:00:00 sum:10041
# 2014-04-28 00:00:00 sum:10109
#
#
# probability of being a salary : 90.87117906567039%
# having these payments :
# 2014-09-26 00:00:00 sum:39862
# 2014-08-26 00:00:00 sum:38496
# 2014-07-28 00:00:00 sum:42602
# 2014-06-26 00:00:00 sum:37120
# 2014-05-27 00:00:00 sum:45348
# 2014-04-28 00:00:00 sum:34378
#
#
# probability of being a salary : 91.76025460901258%
# having these payments :
# 2014-09-26 00:00:00 sum:10857
# 2014-08-26 00:00:00 sum:12562
# 2014-07-25 00:00:00 sum:10153
# 2014-06-30 00:00:00 sum:383
# 2014-06-27 00:00:00 sum:10081
# 2014-05-23 00:00:00 sum:11021
# 2014-04-17 00:00:00 sum:11526
#
#
# probability of being a salary : 90.40494935772568%
# having these payments :
# 2014-09-25 00:00:00 sum:10430
# 2014-08-26 00:00:00 sum:7943
# 2014-07-25 00:00:00 sum:10222
# 2014-06-26 00:00:00 sum:10605
# 2014-05-28 00:00:00 sum:10216
# 2014-04-15 00:00:00 sum:9831
#
#
# probability of being a salary : 95.63556847454984%
# having these payments :
# 2014-09-29 00:00:00 sum:14284
# 2014-08-28 00:00:00 sum:15616
# 2014-07-28 00:00:00 sum:15164
# 2014-06-26 00:00:00 sum:15578
# 2014-05-29 00:00:00 sum:14232
# 2014-04-28 00:00:00 sum:15991
#
#
# probability of being a salary : 74.41228222696135%
# having these payments :
# 2014-09-23 00:00:00 sum:22915
# 2014-08-26 00:00:00 sum:23310
# 2014-07-23 00:00:00 sum:19915
# 2014-06-26 00:00:00 sum:16697
# 2014-05-26 00:00:00 sum:19504
# 2014-04-28 00:00:00 sum:8315
#
#
# probability of being a salary : 99.99481456516386%
# having these payments :
# 2014-09-24 00:00:00 sum:55294
# 2014-08-28 00:00:00 sum:55301
# 2014-07-30 00:00:00 sum:55298
#
#
# probability of being a salary : 86.71316931944685%
# having these payments :
# 2014-09-26 00:00:00 sum:16053
# 2014-08-27 00:00:00 sum:16913
# 2014-07-25 00:00:00 sum:15986
# 2014-06-25 00:00:00 sum:12599
# 2014-05-27 00:00:00 sum:11360
# 2014-04-28 00:00:00 sum:14145
#
#
# probability of being a salary : 99.98289362129526%
# having these payments :
# 2014-09-26 00:00:00 sum:16443
# 2014-08-28 00:00:00 sum:16447
# 2014-07-29 00:00:00 sum:16449
# 2014-06-27 00:00:00 sum:16445
# 2014-05-22 00:00:00 sum:16450
# 2014-04-25 00:00:00 sum:16451
#
#
# probability of being a salary : 99.99605397814115%
# having these payments :
# 2014-09-29 00:00:00 sum:31608
# 2014-08-28 00:00:00 sum:31605
# 2014-07-30 00:00:00 sum:31607
#
#
# probability of being a salary : 75.76474522821871%
# having these payments :
# 2014-09-22 00:00:00 sum:13800
# 2014-08-28 00:00:00 sum:27570
# 2014-07-30 00:00:00 sum:5602
# 2014-07-30 00:00:00 sum:28346
#
#
# probability of being a salary : 99.73037597780852%
# having these payments :
# 2014-09-26 00:00:00 sum:13817
# 2014-08-26 00:00:00 sum:13816
# 2014-07-28 00:00:00 sum:13796
# 2014-06-26 00:00:00 sum:13816
# 2014-05-27 00:00:00 sum:13815
# 2014-04-28 00:00:00 sum:13714
#
#
# probability of being a salary : 99.99468014885912%
# having these payments :
# 2014-09-29 00:00:00 sum:45614
# 2014-08-28 00:00:00 sum:45612
# 2014-07-28 00:00:00 sum:45618
# 2014-06-30 00:00:00 sum:45618
# 2014-05-28 00:00:00 sum:45618
# 2014-04-28 00:00:00 sum:45614
#
#
# probability of being a salary : 88.92138762230132%
# having these payments :
# 2014-09-23 00:00:00 sum:22023
# 2014-08-26 00:00:00 sum:26382
# 2014-07-23 00:00:00 sum:26483
# 2014-06-26 00:00:00 sum:20555
# 2014-05-26 00:00:00 sum:20317
# 2014-04-28 00:00:00 sum:23160
#
#
# probability of being a salary : 95.55545084154787%
# having these payments :
# 2014-09-26 00:00:00 sum:13785
# 2014-08-26 00:00:00 sum:14691
# 2014-07-28 00:00:00 sum:13619
# 2014-06-24 00:00:00 sum:15386
# 2014-05-26 00:00:00 sum:14377
# 2014-04-17 00:00:00 sum:8328
# 2014-04-25 00:00:00 sum:5918
#
#
# probability of being a salary : 99.98579968219755%
# having these payments :
# 2014-09-25 00:00:00 sum:11071
# 2014-08-26 00:00:00 sum:11072
# 2014-07-28 00:00:00 sum:11076
# 2014-06-25 00:00:00 sum:11073
# 2014-05-26 00:00:00 sum:11073
# 2014-04-24 00:00:00 sum:11072
#
#
# probability of being a salary : 97.49506405967884%
# having these payments :
# 2014-08-27 00:00:00 sum:10838
# 2014-07-28 00:00:00 sum:11037
# 2014-06-23 00:00:00 sum:11334
# 2014-05-26 00:00:00 sum:11636
# 2014-04-23 00:00:00 sum:11059
#
#
# probability of being a salary : 99.64345759545027%
# having these payments :
# 2014-09-29 00:00:00 sum:13818
# 2014-08-27 00:00:00 sum:13713
# 2014-07-29 00:00:00 sum:13817
#
#
# probability of being a salary : 97.03658670206917%
# having these payments :
# 2014-07-28 00:00:00 sum:11204
# 2014-06-26 00:00:00 sum:11803
# 2014-05-29 00:00:00 sum:12034
# 2014-04-28 00:00:00 sum:5871
#
#
# probability of being a salary : 63.32464540237832%
# having these payments :
# 2014-06-27 00:00:00 sum:38495
# 2014-06-26 00:00:00 sum:27524
# 2014-05-27 00:00:00 sum:13819
#
#
# probability of being a salary : 99.56919978407922%
# having these payments :
# 2014-09-23 00:00:00 sum:6884
# 2014-08-27 00:00:00 sum:6981
# 2014-07-25 00:00:00 sum:8528
# 2014-06-26 00:00:00 sum:8557
# 2014-05-26 00:00:00 sum:8465
# 2014-04-24 00:00:00 sum:8553
#
#
# probability of being a salary : 58.10419192765748%
# having these payments :
# 2014-09-30 00:00:00 sum:16925
# 2014-08-28 00:00:00 sum:17143
# 2014-07-28 00:00:00 sum:8330
# 2014-07-29 00:00:00 sum:8432
# 2014-06-30 00:00:00 sum:7473
# 2014-06-27 00:00:00 sum:9680
#
#
# probability of being a salary : 96.7941531826905%
# having these payments :
# 2014-09-30 00:00:00 sum:12476
# 2014-08-28 00:00:00 sum:11523
# 2014-07-30 00:00:00 sum:11866
# 2014-06-27 00:00:00 sum:11565
# 2014-05-29 00:00:00 sum:12281
# 2014-04-29 00:00:00 sum:4341
#
#
# probability of being a salary : 99.97232700510207%
# having these payments :
# 2014-09-29 00:00:00 sum:7782
# 2014-08-26 00:00:00 sum:7785
# 2014-07-28 00:00:00 sum:7692
# 2014-06-26 00:00:00 sum:7784
# 2014-05-27 00:00:00 sum:7780
# 2014-04-28 00:00:00 sum:7786
#
#
# probability of being a salary : 95.14519743112467%
# having these payments :
# 2014-09-30 00:00:00 sum:8629
# 2014-08-28 00:00:00 sum:9126
# 2014-07-31 00:00:00 sum:9713
#
#
# probability of being a salary : 96.82808518508239%
# having these payments :
# 2014-09-29 00:00:00 sum:9839
# 2014-08-26 00:00:00 sum:10604
# 2014-07-28 00:00:00 sum:9835
# 2014-06-27 00:00:00 sum:10223
#
#
# probability of being a salary : 90.53252291352226%
# having these payments :
# 2014-09-26 00:00:00 sum:11651
# 2014-08-26 00:00:00 sum:9407
# 2014-07-28 00:00:00 sum:10626
# 2014-06-26 00:00:00 sum:11876
# 2014-05-28 00:00:00 sum:9645
#
#
# probability of being a salary : 98.08194472790555%
# having these payments :
# 2014-08-26 00:00:00 sum:16049
# 2014-07-24 00:00:00 sum:16596
# 2014-06-25 00:00:00 sum:16629
# 2014-05-26 00:00:00 sum:15935
#
#
# probability of being a salary : 99.71984423030426%
# having these payments :
# 2014-07-29 00:00:00 sum:8335
# 2014-06-25 00:00:00 sum:2850
# 2014-05-26 00:00:00 sum:8282
# 2014-04-25 00:00:00 sum:8327
#
#
# probability of being a salary : 94.31048361965412%
# having these payments :
# 2014-07-28 00:00:00 sum:2432
# 2014-06-26 00:00:00 sum:15807
# 2014-05-28 00:00:00 sum:14078
# 2014-04-28 00:00:00 sum:14127
#
#
# probability of being a salary : 82.33932795564701%
# having these payments :
# 2014-09-30 00:00:00 sum:49666
# 2014-08-28 00:00:00 sum:48074
# 2014-07-30 00:00:00 sum:25689
# 2014-06-30 00:00:00 sum:44078
# 2014-05-30 00:00:00 sum:48071
# 2014-04-30 00:00:00 sum:49671
#
#
# probability of being a salary : 88.85950809503915%
# having these payments :
# 2014-09-30 00:00:00 sum:14719
# 2014-08-28 00:00:00 sum:16672
# 2014-07-31 00:00:00 sum:15077
# 2014-06-30 00:00:00 sum:16617
# 2014-05-30 00:00:00 sum:19750
# 2014-04-30 00:00:00 sum:14695
#
#
# probability of being a salary : 95.26428011619652%
# having these payments :
# 2014-09-29 00:00:00 sum:15503
# 2014-09-30 00:00:00 sum:1712
# 2014-08-27 00:00:00 sum:17960
# 2014-07-25 00:00:00 sum:16530
# 2014-06-27 00:00:00 sum:17117
# 2014-05-21 00:00:00 sum:17068
# 2014-04-16 00:00:00 sum:16589
#
#
# probability of being a salary : 99.99215169155507%
# having these payments :
# 2014-09-29 00:00:00 sum:27521
# 2014-09-16 00:00:00 sum:8327
# 2014-08-27 00:00:00 sum:27526
# 2014-07-29 00:00:00 sum:27525
#
#
# probability of being a salary : 99.75028635569288%
# having these payments :
# 2014-09-30 00:00:00 sum:14112
# 2014-08-27 00:00:00 sum:14117
# 2014-07-30 00:00:00 sum:14019
# 2014-06-27 00:00:00 sum:14113
# 2014-05-29 00:00:00 sum:14119
# 2014-04-29 00:00:00 sum:14099
#
#
# probability of being a salary : 99.66790191547994%
# having these payments :
# 2014-08-26 00:00:00 sum:12321
# 2014-07-28 00:00:00 sum:12222
# 2014-06-27 00:00:00 sum:12261
#
#
# probability of being a salary : 88.26398974427156%
# having these payments :
# 2014-09-29 00:00:00 sum:14065
# 2014-08-28 00:00:00 sum:12929
# 2014-07-29 00:00:00 sum:12847
# 2014-06-26 00:00:00 sum:13309
# 2014-05-27 00:00:00 sum:13196
# 2014-04-25 00:00:00 sum:17306
#
#
# probability of being a salary : 99.43740807323371%
# having these payments :
# 2014-09-26 00:00:00 sum:8363
# 2014-08-27 00:00:00 sum:8468
# 2014-07-29 00:00:00 sum:8464
# 2014-06-30 00:00:00 sum:8462
# 2014-05-27 00:00:00 sum:8385
# 2014-04-29 00:00:00 sum:8365
#
#
# probability of being a salary : 83.91063923489024%
# having these payments :
# 2014-09-26 00:00:00 sum:9803
# 2014-08-26 00:00:00 sum:14641
# 2014-07-28 00:00:00 sum:16260
# 2014-06-26 00:00:00 sum:10889
# 2014-05-28 00:00:00 sum:14735
# 2014-04-28 00:00:00 sum:15116
#
#
# probability of being a salary : 81.49231007024781%
# having these payments :
# 2014-09-26 00:00:00 sum:16570
# 2014-08-25 00:00:00 sum:15962
# 2014-07-28 00:00:00 sum:16565
# 2014-06-26 00:00:00 sum:11329
# 2014-05-27 00:00:00 sum:11330
# 2014-04-29 00:00:00 sum:11332
#
#
# probability of being a salary : 99.7249834685962%
# having these payments :
# 2014-09-26 00:00:00 sum:9837
# 2014-08-26 00:00:00 sum:9812
# 2014-07-28 00:00:00 sum:9823
# 2014-06-26 00:00:00 sum:9832
# 2014-05-26 00:00:00 sum:9766
# 2014-04-28 00:00:00 sum:9851
#
#
# probability of being a salary : 81.20837865079264%
# having these payments :
# 2014-06-30 00:00:00 sum:2792
# 2014-05-22 00:00:00 sum:27529
# 2014-05-29 00:00:00 sum:16555
# 2014-04-24 00:00:00 sum:27528
#
#
# probability of being a salary : 99.73970257813221%
# having these payments :
# 2014-09-26 00:00:00 sum:13902
# 2014-08-27 00:00:00 sum:13801
# 2014-07-24 00:00:00 sum:13843
# 2014-04-30 00:00:00 sum:13841
#
#
# probability of being a salary : 91.97813671385258%
# having these payments :
# 2014-09-26 00:00:00 sum:11477
# 2014-08-26 00:00:00 sum:13363
# 2014-07-28 00:00:00 sum:12684
# 2014-06-26 00:00:00 sum:13595
# 2014-05-28 00:00:00 sum:13955
# 2014-04-28 00:00:00 sum:14974
#
#
# probability of being a salary : 42.388246120937886%
# having these payments :
# 2014-09-29 00:00:00 sum:11198
# 2014-08-28 00:00:00 sum:35747
# 2014-08-28 00:00:00 sum:14904
# 2014-08-27 00:00:00 sum:11097
# 2014-07-24 00:00:00 sum:10514
# 2014-07-24 00:00:00 sum:30952
# 2014-07-24 00:00:00 sum:12556
# 2014-06-27 00:00:00 sum:30957
# 2014-06-27 00:00:00 sum:17282
# 2014-06-26 00:00:00 sum:11487
# 2014-06-09 00:00:00 sum:5591
# 2014-05-28 00:00:00 sum:26128
# 2014-05-28 00:00:00 sum:15551
# 2014-05-20 00:00:00 sum:11450
# 2014-04-04 00:00:00 sum:13814
# 2014-04-28 00:00:00 sum:10570
# 2014-04-30 00:00:00 sum:25436
# 2014-04-30 00:00:00 sum:1895
#
#
# probability of being a salary : 92.04539211217589%
# having these payments :
# 2014-09-29 00:00:00 sum:21310
# 2014-08-28 00:00:00 sum:22115
# 2014-07-30 00:00:00 sum:21067
# 2014-06-30 00:00:00 sum:21080
# 2014-05-28 00:00:00 sum:25731
# 2014-04-29 00:00:00 sum:21027
#
#
# probability of being a salary : 7.204404770046812%
# having these payments :
# 2014-07-28 00:00:00 sum:13810
# 2014-06-30 00:00:00 sum:36604
# 2014-05-26 00:00:00 sum:10582
# 2014-04-29 00:00:00 sum:8224
#
#
# probability of being a salary : 99.20149677622314%
# having these payments :
# 2014-09-29 00:00:00 sum:76831
# 2014-08-28 00:00:00 sum:75401
# 2014-07-31 00:00:00 sum:76570
# 2014-06-27 00:00:00 sum:76567
# 2014-05-30 00:00:00 sum:77469
# 2014-04-30 00:00:00 sum:76564
#
#
# probability of being a salary : 99.48955845632223%
# having these payments :
# 2014-09-29 00:00:00 sum:8331
# 2014-08-27 00:00:00 sum:8332
# 2014-06-27 00:00:00 sum:8335
# 2014-05-20 00:00:00 sum:8335
# 2014-04-26 00:00:00 sum:8227
#
#
# probability of being a salary : 99.9864848953381%
# having these payments :
# 2014-09-26 00:00:00 sum:20672
# 2014-08-26 00:00:00 sum:20675
# 2014-07-28 00:00:00 sum:20667
# 2014-06-26 00:00:00 sum:20673
# 2014-05-27 00:00:00 sum:20668
# 2014-04-28 00:00:00 sum:20672
#
#
# probability of being a salary : 99.97936597561956%
# having these payments :
# 2014-09-30 00:00:00 sum:11071
# 2014-08-26 00:00:00 sum:11074
# 2014-07-23 00:00:00 sum:11073
# 2014-06-27 00:00:00 sum:11076
# 2014-05-27 00:00:00 sum:11076
# 2014-04-29 00:00:00 sum:11078
#
#
# probability of being a salary : 99.91752561453093%
# having these payments :
# 2014-06-27 00:00:00 sum:9445
# 2014-05-26 00:00:00 sum:9428
# 2014-04-30 00:00:00 sum:9444
#
#
# probability of being a salary : 99.83138059324361%
# having these payments :
# 2014-09-29 00:00:00 sum:8595
# 2014-08-27 00:00:00 sum:8621
# 2014-07-28 00:00:00 sum:8637
# 2014-06-27 00:00:00 sum:8634
# 2014-05-27 00:00:00 sum:8636
# 2014-04-28 00:00:00 sum:8628
#
#
# probability of being a salary : 99.98564127970612%
# having these payments :
# 2014-09-29 00:00:00 sum:28617
# 2014-08-27 00:00:00 sum:28621
# 2014-07-29 00:00:00 sum:28627
#
#
# probability of being a salary : 91.43693281688182%
# having these payments :
# 2014-09-26 00:00:00 sum:20710
# 2014-08-26 00:00:00 sum:24005
# 2014-07-25 00:00:00 sum:18540
# 2014-06-24 00:00:00 sum:20155
# 2014-05-27 00:00:00 sum:22122
# 2014-04-28 00:00:00 sum:23034
#
#
# probability of being a salary : 37.35798180255998%
# having these payments :
# 2014-08-27 00:00:00 sum:47620
# 2014-07-28 00:00:00 sum:10320
# 2014-07-28 00:00:00 sum:14225
# 2014-07-28 00:00:00 sum:34095
# 2014-04-15 00:00:00 sum:59881
#
#
# probability of being a salary : 81.95404628856761%
# having these payments :
# 2014-09-26 00:00:00 sum:11794
# 2014-08-26 00:00:00 sum:13534
# 2014-07-28 00:00:00 sum:8408
#
#
# probability of being a salary : 46.0885305475936%
# having these payments :
# 2014-09-29 00:00:00 sum:13785
# 2014-08-28 00:00:00 sum:9655
# 2014-08-28 00:00:00 sum:34652
# 2014-08-27 00:00:00 sum:15931
# 2014-07-24 00:00:00 sum:23971
# 2014-07-24 00:00:00 sum:15161
# 2014-07-24 00:00:00 sum:6356
# 2014-06-27 00:00:00 sum:37126
# 2014-06-27 00:00:00 sum:7103
# 2014-06-26 00:00:00 sum:17085
# 2014-05-28 00:00:00 sum:15828
# 2014-05-28 00:00:00 sum:30953
# 2014-05-28 00:00:00 sum:19449
# 2014-04-30 00:00:00 sum:15785
# 2014-04-30 00:00:00 sum:34657
# 2014-04-30 00:00:00 sum:13471
#
#
# probability of being a salary : 85.88819312365334%
# having these payments :
# 2014-09-30 00:00:00 sum:37119
# 2014-09-30 00:00:00 sum:37119
# 2014-07-25 00:00:00 sum:27940
# 2014-07-25 00:00:00 sum:27936
#
#
# probability of being a salary : 99.89305346310206%
# having these payments :
# 2014-09-26 00:00:00 sum:8530
# 2014-08-26 00:00:00 sum:8533
# 2014-07-29 00:00:00 sum:8535
# 2014-06-26 00:00:00 sum:8512
# 2014-05-29 00:00:00 sum:5042
#
#
# probability of being a salary : 99.94088645074784%
# having these payments :
# 2014-07-28 00:00:00 sum:10512
# 2014-06-26 00:00:00 sum:10524
# 2014-05-26 00:00:00 sum:10529
# 2014-04-28 00:00:00 sum:10520
#
#
# run successfull

# %% [markdown]
# ### 6. Trendy v dátach - 2 výšky platieb
#
# V dátach platieb medzi dvomi účtami sa objavoval vzor, kde platby boli v 2 rôznych výškach.
# Rozhodli sme sa teda vyvinúť metódu pre meranie tohto trendu. Pôvodná idea bola použiť algoritmus z knižnice scikit.
# Chceli sme spustiť klasterizáciu pre každú sekvenciu platieb medzi 2 účtami samostatne.
# Aj pri limitovaní počtu iterácii bol ale k_means algoritmus knižnice scikit pre naše potreby príliš pomalý.
# Spracovanie datasetu bolo v desiatkách minút. Preto sme sa rozhodli vyvinúť síce jednoduchší, a určite nepresnejší,
# no rýchlejší algoritmus na identifikáciu 2 klastrov v platbách medzi 2 účtami.

# %% [markdown]
# ### 7. Klasterizácia
#
# Pre zoznam transakcií medzi 2 účtami chceme určiť, či sa dajú rozdeliť na 2 klastre. Pre porovnanie, či sú dáta klastrované,
# robíme klasterizáciu aj s 1 klastrom, následne porovnáme chyby obidvoch metód.<br>
#
# #### 7.1. Navrhovaný algoritmus<br>
# 7.1.1 Inicializácia centier<br>
# Zistíme priemer, maximum a minimum medzi hodnotami. Prvé centrum inicializujeme ako stred medzi maximom a priemerom.
# Druhé centrum je stred medzi minimom a priemerom. Centrum pre 1 klaster je priemer.<br>
# 7.1.2 Výpočet chyby<br>
# Chybu pre obidve klasterizácie sme počítali ako rozdiel hodnôt platieb a klastrov,
# pre 2 klastre sme brali vzdialenosť k bližšiemu z nich.
# Nepoužili sme "mean squared error", pretože sme nechceli zvýrazňovať outlier-y.<br>
# Pre očakávané dáta bude stále chyba pre 2 klastre menšia, preto sme potrebovali zaviesť pomer týchto chýb,
# ten sme dostali vydelením chyby pre jeden klaster chybov pre 2 klastre.
# Takisto, čím ďalej sú od seba 2 klastre, tým je výsledné rozdelenie jednoznačnejšie,
# teda vzdialenosť klastrov (pri metóde 2 klastrov) tiež prispieva do výslednej miery v pomere 30 k 70.
#
# #### 7.2. Problémy riešenia
# Výpočet percent je relatívny voči datasetu. Predpokladá, že dáta obsahujú celú škálu prípadov, od platieb ktoré majú iba jeden klaster, t.j. sú skoro rovnaké, až po kompletne oddeliteľné platby do 2 klastrov.
#
# #### 7.3 Implementácia <br>

# %%
from __future__ import division

import numpy as np
from sklearn import cluster

class Clustering:
	
	def __init__(self, loaded):
		self.connections = loaded.payments_list
		self.payments = loaded.payments
		self.payments_origin = loaded.payments
		self.keyset = loaded.keyset
		self.mean = np.mean(loaded.amounts)
		self.std_paym = np.std(loaded.amounts)
	
	def scale_data(self, data):
		data -= self.mean
		data /= self.std_paym
		return data
		
	def normalize_payments(self):
		for k, v in self.payments.items():
			for p in v:
				p.amount = self.scale_data(p.amount)
				
	def my_kmeans(self, amount, iterate= 10):
		l_mean = np.mean(amount)
		l_max = np.max(amount)
		l_min = np.min(amount)
		high_center = l_mean + (l_max - l_mean)/2
		low_center = l_mean - (l_mean - l_min)/2
		one_center = l_mean 	#do we have one cluster?
		diff_high = 0		# how much should center be moved
		diff_low = 0
		for j in range(0,iterate):
			diff_high = 0
			diff_low = 0
			diff_one = 0
			for i in amount:
				low = abs(i - low_center)
				high =  abs(i - high_center)
				one = abs(i - one_center)
				if low > high:
					diff_high += i - high_center # important if positive or negative
				else:
					diff_low += i - low_center
				diff_one += i - one_center
			low_center += diff_low/len(amount)*0.5
			high_center += diff_high/len(amount)*0.5
			one_center += diff_one/len(amount)*0.5 
		return (low_center, high_center, one_center)
	
	def k_means_error(self, amount, l_center, h_center, one_center):
		error = 0
		one_error = 0
		for p in amount:
			dist_from_low = abs(l_center - p)
			dist_from_high = abs(h_center- p)
			dist_from_one = abs(one_center - p)
			if dist_from_high < dist_from_low:
				error += dist_from_high
			else:
				error += dist_from_low
			one_error += dist_from_one 
		return (error/len(amount), one_error/len(amount))
		
	def do_clustering(self):
		counter = 0
		err_rate_max = 0
		dst_max = 0
		for k, v in self.payments.items():
			amount = list()	#list of payment's height
			counter += 1
			if counter % 10000 == 0:
				print("data processed :" + str(counter))
			if len(v) > 2:
				for p in v:
					amount.append(p.amount)
				l_cluster, h_cluster, one_cluster = self.my_kmeans(amount)
				self.connections[k].two_cl_err, self.connections[k].one_cl_err = self.k_means_error(amount, l_cluster, h_cluster, one_cluster)
				err_r = self.connections[k].one_cl_err / self.connections[k].two_cl_err   # how many times is error bigger for one cluster
				
				# c dst part
				c_dst = abs(l_cluster - h_cluster)
				if c_dst > dst_max:
					dst_max = c_dst
				self.connections[k].cluster_dst = c_dst
				# end c dst part
				
				if self.connections[k].two_cl_err < self.connections[k].one_cl_err:
					if err_r > err_rate_max:
						err_rate_max = err_r
					self.connections[k].err_rate = err_r		# decisively one cluster, thus minimal value would be added to' err_rate_loc'
		
		print('err r max '  + str(err_rate_max))
		for k, v in self.connections.items():
			if self.connections[k].two_cl_err < self.connections[k].one_cl_err:
				self.connections[k].cluster_dst_perc = (self.connections[k].cluster_dst / dst_max) * 100
				self.connections[k].cluster_err_perc = (self.connections[k].err_rate / err_rate_max) * 100
				self.connections[k].cluster_perc = self.connections[k].cluster_err_perc*0.70 + self.connections[k].cluster_dst_perc*0.3
				if self.connections[k].cluster_perc > 50:
					print("clustering: " + str(self.connections[k].cluster_perc) + "%")
					for p in self.payments[k]:
						print(p.amount, end= ", ")
					print('\n')
cl = Clustering(l)
cl.do_clustering()
# Out:
# data processed :10000
# data processed :20000
# data processed :30000
# data processed :40000
# data processed :50000
# data processed :60000
# data processed :70000
# data processed :80000
# data processed :90000
# data processed :100000
# data processed :110000
# data processed :120000
# data processed :130000
# err r max 37.731746878775816
# clustering: 66.30293499656568%
# 8234, 17021, 8204, 17022, 8267, 17019, 8262, 17028, 8261, 17026, 8264, 17020,
#
# clustering: 66.65827861098651%
# 2298, 8538, 2281, 8556, 2249, 8481, 2340, 8561, 2288, 8513, 2295, 8556,
#
# clustering: 66.96510596699204%
# 22068, 22068, 22066, 22315, 22319, 22315,
#
# clustering: 51.86399194241274%
# 17555, 17559, 17563, 17711, 17713, 17712,
#
# clustering: 66.47178464628838%
# 39923, 39919, 39920, 40110, 40108, 40105,
#
# clustering: 68.4915472333344%
# 8134, 10570, 8067, 10575, 8162, 10545, 8161, 10542, 8162, 10545, 8161, 10569,
#
# clustering: 67.61786679075598%
# 30470, 30469, 30462, 30780, 30777, 30783,
#
# clustering: 67.66097426619359%
# 22821, 22819, 22815, 23021, 23021, 23024,
#
# clustering: 64.46371832186246%
# 43490, 43491, 43497, 43777, 43774, 43777,
#
# clustering: 66.20627341116581%
# 12108, 9436, 12109, 9435, 12108, 9441, 12071, 9443, 12103, 9438, 12104, 9440,
#
# clustering: 66.54515698261177%
# 5005, 12733, 5006, 12728, 4936, 12628, 4997, 12731, 5002, 12730, 4986, 12729,
#
# clustering: 55.04381738436603%
# 15674, 17899, 15667, 17989, 15674, 17991, 15673, 17983, 15668, 17983, 15671, 17982,
#
# clustering: 63.1453531934737%
# 11023, 8432, 11083, 8511, 11085, 8516, 11084, 8516, 11011, 8516, 11080, 8513,
#
# clustering: 66.5294817418125%
# 5640, 1986, 2031, 5678, 1994, 5645, 5678, 1981, 2018, 5672, 1978, 5680,
#
# clustering: 65.34276705979192%
# 36562, 36563, 36564, 36763, 36767, 36768,
#
# clustering: 65.97251927782516%
# 11145, 18218, 11144, 18219, 11151, 18219, 18222, 11149, 18222, 11151, 18222, 11143,
#
# clustering: 55.44726383483658%
# 16171, 7637, 16202, 7669, 16195, 7573, 16170, 7668, 16123, 7677, 16198, 6838,
#
# clustering: 66.55000880668585%
# 7878, 11542, 7862, 11545, 7838, 11539, 7883, 11539, 7882, 11543, 7877, 11546,
#
# clustering: 66.04005685709309%
# 20621, 11030, 20626, 11027, 20562, 11030, 20621, 11029, 20619, 11030, 20625, 11031,
#
# clustering: 66.50086193321806%
# 1980, 326, 318, 1958,
#
# clustering: 56.842444431244374%
# 5674, 2586, 5585, 2653, 5673, 2623, 2587, 5576, 5676, 2623, 5679, 2668,
#
# clustering: 55.94645735979349%
# 525, 2542, 526, 2629, 514, 2627, 506, 2589, 519, 2621, 525, 2623,
#
# clustering: 67.37421748811961%
# 25073, 25077, 25075, 25241, 25240, 25243,
#
# clustering: 65.89306660570625%
# 8209, 12349, 12395, 8209, 12314, 8206, 8213, 12393, 12398, 8208, 12397, 8205,
#
# clustering: 66.31285800000558%
# 4284, 16187, 4284, 16168, 4224, 16246, 4286, 16244, 4253, 16242, 4273, 16244,
#
# clustering: 55.902808235108445%
# 2639, 5680, 2609, 5674, 5577, 2588, 5672, 2683, 5681, 2610, 5673, 2656,
#
# clustering: 64.24115846418161%
# 9029, 8379, 9032, 8410, 9031, 8411, 9026, 8404, 9024, 8396, 9023, 8403,
#
# clustering: 67.73702444147024%
# 7201, 9949, 7202, 9949, 7189, 9946, 7109, 9941, 7188, 9946, 7200, 9948,
#
# clustering: 62.91975200998941%
# 26922, 26922, 26919, 27158, 27165, 27163,
#
# clustering: 66.84283485532144%
# 25307, 25312, 25309, 25542, 25543, 25544,
#
# clustering: 66.95390965105913%
# 9007, 3402, 8981, 3429, 8937, 3433, 9010, 3346, 8976, 3429, 9001, 3410,
#
# clustering: 64.86016849986093%
# 5618, 9797, 5614, 9826, 5609, 9829, 5609, 9741, 5614, 9824, 5615, 9827,
#
# clustering: 54.42855917543263%
# 16569, 16566, 16569, 16740, 16732, 16736,
#
# clustering: 57.73956646272277%
# 10461, 8788, 10403, 8791, 10462, 8740, 10445, 8790, 10465, 8783, 10469, 8785,
#
# clustering: 67.20576640082794%
# 8862, 8857, 9152, 8862, 9147, 9150,
#
# clustering: 55.38947959234046%
# 13340, 14805, 13240, 14809, 13341, 14744, 13340, 14801, 13343, 14806, 13336, 14804,
#
# clustering: 65.97737550547062%
# 7044, 13715, 7037, 13714, 7042, 13717, 7039, 13717, 7035, 13718, 7041, 13718,
#
# clustering: 63.517268856304916%
# 13579, 8477, 13579, 8479, 13516, 8472, 13581, 8476, 13580, 8472, 8472,
#
# clustering: 67.5723525938104%
# 7672, 4614, 7700, 4706, 7697, 4714, 7695, 4706, 7697, 4614, 4708, 7670,
#
# clustering: 66.07632722742693%
# 12347, 10828, 12347, 10827, 12341, 10827, 12344, 10831, 12344, 10827, 12345, 10833,
#
# clustering: 66.05053261131373%
# 10222, 15120, 10226, 15116, 10216, 15124, 15115, 10223, 10222, 15119, 10218, 15118,
#
# clustering: 66.64778072245579%
# 10606, 17827, 10602, 17821, 10513, 17821, 10604, 17823, 17825, 10602, 10601, 17820,
#
# clustering: 60.455308131098874%
# 5916, 8151, 5898, 8088, 5912, 8148, 5916, 8145, 5812, 8152, 5847, 8145,
#
# clustering: 66.28252188119673%
# 6272, 16340, 6211, 16340, 6276, 16340, 6281, 16340, 6274, 16339, 6269, 16337,
#
# clustering: 66.34164651642237%
# 15062, 1346, 15063, 1348, 15097, 1323, 15099, 1317, 15017, 1331, 15146, 1337,
#
# clustering: 69.09549008894676%
# 15097, 13432, 15102, 13343, 13432, 15103, 15099, 13434, 15105, 13435, 15100, 13426,
#
# clustering: 62.97796996312006%
# 21245, 21249, 21242, 21493, 21498, 21500,
#
# clustering: 60.27989159725514%
# 6386, 9341, 9427, 6385, 6369, 9432, 9400, 6388, 9428, 6391, 6390, 9432,
#
# clustering: 52.085519741835284%
# 1451, 660, 1454, 654, 1462, 667, 651, 1475, 653, 1437, 1422, 663,
#
# clustering: 66.22981450459174%
# 4039, 8520, 4039, 8518, 4031, 8514, 3941, 8519, 4045, 8431, 4008, 8497,
#
# clustering: 61.18409903064123%
# 1334, 1323, 1347, 649, 647, 663,
#
# clustering: 52.64536522379341%
# 9643, 7132, 9642, 7134, 9639, 7120, 9637, 7134, 9556, 7129, 9538, 7131,
#
# clustering: 67.46135963693588%
# 14115, 17815, 17830, 14112, 17837, 14121, 14114, 17832, 14113, 17837, 17834, 14019,
#
# clustering: 66.74559864396952%
# 11009, 6088, 11005, 6001, 11003, 6081, 11005, 6015, 11008, 6089, 11001, 6081,
#
# clustering: 67.75982715110457%
# 31356, 31352, 31359, 31621, 31618, 31625,
#
# clustering: 66.6538600722363%
# 15352, 7910, 15459, 7930, 15459, 7946, 15453, 7856, 15458, 7963, 15456, 7911,
#
# clustering: 63.9437262071744%
# 26621, 26620, 26621, 26846, 26856, 26846,
#
# clustering: 52.60313695736225%
# 1327, 1302, 1293, 675, 645, 674,
#
# clustering: 66.33835909937255%
# 4087, 15232, 4060, 15229, 4089, 15235, 4067, 15202, 4009, 15229, 4094, 15228,
#
# clustering: 66.43371707175828%
# 23696, 23695, 23695, 23897, 23900, 23899,
#
# clustering: 64.9219041531344%
# 12188, 8807, 12224, 8813, 12143, 8812, 12221, 8707, 12223, 8753, 12220, 8811,
#
# clustering: 54.548491626302265%
# 19957, 19956, 19954, 20106, 20115, 20107,
#
# clustering: 66.88049395804971%
# 14560, 7339, 14503, 7340, 14467, 7340, 14465, 7333, 14562, 7265, 14559, 7338,
#
# clustering: 56.247475134770596%
# 6370, 7407, 6373, 7407, 6375, 7370, 6371, 7405, 6373, 7410, 6369, 7402,
#
# clustering: 66.26861879928497%
# 4011, 14715, 3960, 14639, 3978, 14716, 4016, 14710, 4015, 14716, 4020, 14715,
#
# clustering: 65.98768823663964%
# 30246, 11929, 30240, 11938, 30243, 11929, 30244, 11934, 30244, 11930, 30239, 11931,
#
# clustering: 63.188909788334904%
# 33606, 33607, 33611, 33792, 33794, 33794,
#
# clustering: 61.082982238694264%
# 15840, 15843, 15846, 16008, 16012, 16011,
#
# clustering: 68.14910702219035%
# 8843, 6484, 8839, 6431, 8840, 6492, 8837, 6388, 8836, 6491, 8836, 6486,
#
# clustering: 66.6717476560963%
# 1313, 5658, 1348, 5616, 5674, 1330, 1317, 5600, 5628, 1326, 1347, 5674,
#
# clustering: 66.57606014602649%
# 5598, 1349, 1309, 5657, 5677, 1310, 1339, 5669, 5672, 1320, 1316, 5617,
#
# clustering: 66.11522721855891%
# 12976, 7948, 12977, 7943, 12974, 7942, 12979, 7944, 12976, 7929, 12972, 7942,
#
# clustering: 66.69024444920699%
# 8429, 13931, 8364, 13937, 8429, 13929, 8350, 13902, 8426, 13930, 8431, 13935,
#
# clustering: 55.074688865359676%
# 667, 5621, 5681, 646, 5681, 648, 5665, 660, 673, 646,
#
# clustering: 63.57043545778351%
# 9058, 12442, 9053, 12441, 12361, 9056, 12441, 9054, 12444, 9056, 9055, 12393,
#
# clustering: 65.99776101863684%
# 6962, 6962, 6962, 1304, 1307, 1323,
#
# clustering: 66.49987180618909%
# 1336, 5678, 5629, 1354, 5682, 1293, 5663, 1291, 1295, 5653, 5678, 1301,
#
# clustering: 64.46272656871479%
# 24405, 24411, 24403, 24708, 24705, 24701,
#
# clustering: 56.91668912974267%
# 16221, 16220, 16225, 16366, 16364, 16362,
#
# clustering: 66.32292706906236%
# 7068, 1328, 1309, 7073, 1332, 7065, 6995, 1318, 1303, 7073, 7071, 1348,
#
# clustering: 66.16990058951328%
# 8885, 14035, 8903, 14037, 8897, 14014, 8906, 14033, 8905, 14030, 8897, 14035,
#
# clustering: 66.26958960153041%
# 6319, 6241, 6321, 671, 675, 676,
#
# clustering: 66.0909719953271%
# 1310, 5681, 5681, 1317, 5670, 1307, 1339, 5673, 5681, 1306, 5679, 1309,
#
# clustering: 66.69816523816183%
# 36378, 36384, 36379, 36711, 36712, 36708,
#
# clustering: 64.08374153042124%
# 5680, 1335, 5588, 1293, 5678, 1350, 5680, 1293, 1328, 5679, 5673, 1337,
#
# clustering: 66.12986949215295%
# 6317, 1330, 6325, 1334, 1318, 6323, 6324, 1311, 1315, 6320, 1341, 6324,
#
# clustering: 67.25909957062346%
# 11668, 10594, 11668, 10594, 11674, 10595, 11675, 10592, 11675, 10570, 11675, 10592,
#
# clustering: 66.72049562608846%
# 9634, 5629, 9573, 5633, 9641, 5630, 9573, 5597, 5627, 9640, 5615, 9641,
#
# clustering: 61.44975944820286%
# 5187, 5258, 5257, 8080, 8043, 8042, 8038,
#
# clustering: 66.13940770908266%
# 11348, 1302, 1326, 11321, 1307, 11352, 11353, 1321, 1341, 11356, 1342, 11343,
#
# clustering: 66.44321318976118%
# 6969, 6890, 6967, 1297, 1302, 1346,
#
# clustering: 67.30278167665485%
# 12076, 15372, 15374, 12074, 11998, 15368, 12080, 15369, 15370, 12074, 12075, 15367,
#
# clustering: 65.8883410229168%
# 194, 197, 194, 197,
#
# clustering: 66.2220599186764%
# 19848, 9980, 19852, 9930, 19846, 9972, 19843, 9978, 19843, 9980,
#
# clustering: 66.37334494883761%
# 17314, 16760, 17306, 16760,
#
# clustering: 50.620607677240265%
# 4198, 21023, 4238, 21379, 21950, 4236, 4240, 21952,
#
# clustering: 53.93301211469167%
# 9184, 5101, 9203, 4992, 9198, 4910,
#
# clustering: 66.19649958170531%
# 9198, 43701, 43675, 9342,
#
# clustering: 66.40680390378924%
# 13258, 20176, 13251, 20264, 13253, 20267, 13225, 20263, 13245, 20265, 13255, 20195,
#
# clustering: 66.12259488143613%
# 11784, 8645, 8642, 11785, 11790, 8642, 11788, 8641, 11784, 8639, 11767, 8646,
#
# clustering: 66.06309664703952%
# 20910, 15076, 20948, 15073, 20953, 15075, 20953, 15076, 20947, 15078, 20950, 15071,
#
# clustering: 59.28129552116376%
# 9146, 11101, 9150, 11105, 11049, 9151, 11110, 9146, 11106, 9153, 11104, 9150,
#
# clustering: 58.39352236398389%
# 12601, 9336, 12605, 9333, 12506, 9340, 12506, 9334, 12606, 9291, 12604, 9335,
#
# clustering: 67.08898933339331%
# 9925, 6580, 9930, 6664, 9930, 6664, 9914, 6592, 9932, 6567, 9932, 6657,
#
# clustering: 65.88833259490531%
# 33, 33, 34, 33, 34, 34,
#
# clustering: 66.60989107806932%
# 35849, 35849, 35851, 36064, 36065, 36067,
#
# clustering: 67.07278631672766%
# 27655, 27662, 27660, 27870, 27870, 27874,
#
# clustering: 66.34388048343486%
# 15473, 14099, 15473, 14104, 15478, 14099, 15473, 14097, 15475, 14095, 15481, 14099,
#
# clustering: 52.358678953935%
# 27740, 27738, 27740, 27898, 27898, 27892,
#
# clustering: 66.82536770584998%
# 9111, 14618, 9114, 14617, 9024, 14615, 9109, 14619, 9111, 14613, 9115, 14619,
#
# clustering: 66.59041829906013%
# 12470, 17374, 17367, 12474, 12425, 17367, 17369, 12423, 17305, 12478, 17371, 12478,
#
# clustering: 66.08201907381547%
# 12143, 20201, 12141, 20202, 12143, 20208, 12142, 20204, 12124, 20201, 12135, 20199,
#
# clustering: 65.98866436797609%
# 9977, 9977, 9984, 12703, 12699, 12703,
#
# clustering: 66.4544551726935%
# 8250, 11142, 8246, 11141, 8245, 11131, 8245, 11143, 8245, 11146, 8223, 11144,
#
# clustering: 66.30774364870747%
# 2807, 2833, 2825, 286, 279, 276,
#
# clustering: 56.428155039466326%
# 15556, 15549, 15549, 15765, 15764, 15768,
#
# clustering: 66.39010031863283%
# 9351, 10421, 9353, 10425, 9352, 10418, 9357, 10418, 10417, 9352, 10423, 9349,
#
# clustering: 68.69263605490661%
# 11406, 12218, 11440, 12221, 11440, 12227, 11437, 12222, 11435, 12221, 11438, 12220,
#
# clustering: 66.82657538604495%
# 38410, 38412, 38413, 38649, 38648, 38651,
#
# clustering: 66.32622384394524%
# 12095, 12095, 12093, 12211, 12208, 12210,
#
# clustering: 64.61784154272272%
# 26383, 26383, 26386, 26605, 26599, 26597,
#
# clustering: 54.078180968241824%
# 55729, 55723, 55723, 55909, 55907, 55914,
#
# clustering: 66.01079285013083%
# 8697, 21672, 8701, 21667, 8703, 21675, 21675, 8699, 8695, 21674, 21629, 8697,
#
# clustering: 66.88236350636589%
# 6497, 11683, 6462, 11683, 6406, 11678, 6503, 11679, 6495, 11681, 6501, 11686,
#
# clustering: 66.85894924387755%
# 14951, 11077, 14952, 11142, 14957, 11155, 14958, 11096, 14959, 11153, 14960, 11144,
#
# clustering: 64.7674041775303%
# 40588, 40590, 40595, 40857, 40855, 40857,
#
# clustering: 66.23620999006604%
# 4838, 8196, 8221, 4839, 4833, 8224, 4834, 8177, 4834, 8220, 8221, 4837,
#
# clustering: 62.88808278886708%
# 10701, 7998, 10724, 8038, 10731, 7940, 10732, 8024, 10656, 8025, 10728, 8034,
#
# clustering: 66.16867788081076%
# 14017, 10260, 14016, 10260, 13971, 10261, 14016, 10254, 14015, 10251, 14011, 10254,
#
# clustering: 67.90492186431925%
# 6964, 9092, 6977, 9094, 6972, 9094, 6875, 9094, 6932, 9090, 6979, 9090,
#
# clustering: 66.42340353330245%
# 4036, 13085, 4035, 13098, 4028, 13098, 4033, 13102, 3948, 13098, 3982, 13103,
#
# clustering: 66.0137808851221%
# 16833, 10473, 16827, 10471, 10475, 16825, 10480, 16826, 10471, 16817, 10471, 16828,
#
# clustering: 67.02405553158707%
# 5603, 1994, 1946, 5660, 2007, 5656, 5636, 1950, 5676, 1974, 5628, 1976,
#
# clustering: 66.10837731762464%
# 3616, 17108, 3583, 17105, 3616, 17102, 3622, 17102, 3622, 17108, 3623, 17107,
#
# clustering: 66.67093742853896%
# 9083, 15489, 9080, 15536, 8978, 15537, 8997, 15535, 9052, 15537, 9067, 15536,
#
# clustering: 52.95503811178727%
# 12000, 12003, 12003, 12086, 12091, 12086,
#
# clustering: 51.85492515884738%
# 11471, 11475, 11472, 11562, 11563, 11563,
#
# clustering: 66.26622739048031%
# 12848, 16969, 12849, 17028, 12846, 17029, 12844, 17034, 12847, 16988, 12844, 17034,
#
# clustering: 64.71023643432156%
# 8031, 11552, 8031, 11554, 8034, 11548, 7933, 11476, 8029, 11554, 8028, 11549,
#
# clustering: 66.85929196715335%
# 4442, 7156, 4441, 7158, 4447, 7154, 4442, 7157, 4395, 7153, 4390, 7152,
#
# clustering: 63.30133432859777%
# 930, 4386, 929, 4431, 944, 4437, 4432, 908, 925, 4383, 946, 4336,
#
# clustering: 63.46004315639958%
# 7100, 10212, 7069, 10220, 7094, 10214, 7100, 10216, 7096, 10214, 7098, 10147,
#
# clustering: 68.03360444549412%
# 18291, 18287, 18287, 18518, 18518, 18527,
#
# clustering: 66.40910998252255%
# 14714, 7924, 7905, 14730, 7932, 14726, 7867, 14728, 14725, 7923, 14728, 7925,
#
# clustering: 58.038719653065456%
# 13160, 1699, 13182, 1732, 13182, 1730, 13652, 1757, 1482, 13100, 1720, 1717, 13184, 1719, 1726,
#
# clustering: 63.703879322863614%
# 17989, 17983, 17990, 18154, 18152, 18154,
#
# clustering: 67.11968387708723%
# 11745, 10084, 11745, 10084, 11741, 10120, 11749, 10127, 11742, 10114, 11744, 10126,
#
# clustering: 66.54825214671054%
# 5955, 9744, 5920, 9742, 5959, 9745, 5956, 9719, 5955, 9740, 5958, 9743,
#
# clustering: 66.93580939220298%
# 9958, 12990, 9961, 12995, 12994, 9960, 12994, 9957, 12982, 9964, 9908, 12993,
#
# clustering: 66.75117099860222%
# 8811, 13323, 8814, 13316, 8836, 13323, 8772, 13323, 8845, 13280, 8838, 13316,
#
# clustering: 66.58124152774609%
# 14362, 13654, 14361, 13647, 14360, 13652, 14356, 13651, 14355, 13652, 14356, 13648,
#
# clustering: 59.868101210391686%
# 16844, 16838, 16843, 16962, 16961, 16964,
#
# clustering: 63.630300738900615%
# 12440, 8767, 12442, 8768, 12439, 8687, 12439, 8756, 12440, 8765, 8766, 12357,
#
# clustering: 66.00450075962087%
# 9481, 26393, 26444, 9483, 26446, 9481, 26447, 9479, 26447, 9479, 26444, 9479,
#
# clustering: 53.172072360818674%
# 21751, 25595, 21746, 25604, 21702, 25597, 21872, 25723, 21873, 25718, 25723, 21783,
#
# clustering: 65.98771101183756%
# 12059, 21396, 12052, 21392, 21388, 12053, 21391, 12055, 21387, 12050, 12054, 21394,
#
# clustering: 66.15176562656951%
# 15414, 10451, 15407, 10443, 15412, 10446, 15408, 10447, 15411, 10450, 15354, 10452,
#
# clustering: 66.23389378990304%
# 13320, 11856, 13319, 11850, 11852, 13318, 13313, 11859, 13321, 11850, 13314, 11857,
#
# clustering: 56.1592475506686%
# 11013, 9615, 11067, 9614, 11069, 9587, 11061, 9617, 11069, 9615, 11064, 9611,
#
# clustering: 54.631875116062524%
# 4730, 6635, 4812, 6675, 4807, 6670, 4808, 6676, 4808, 6587, 4806, 6671,
#
# clustering: 65.98232621761362%
# 19918, 10109, 19914, 10112, 19924, 10111, 19918, 10114, 19919, 10114, 19919, 10109,
#
# clustering: 66.80843982130035%
# 31402, 20569, 20569, 31393, 31397, 20578, 31547, 20691, 31553, 20689, 20694, 31550,
#
# clustering: 66.50635706140736%
# 10170, 10179, 10170, 6433, 6433, 6391,
#
# clustering: 66.06361449901576%
# 5036, 15793, 5033, 15730, 5036, 15793, 5037, 15796, 5030, 15802, 5033, 15796,
#
# clustering: 67.71339265306015%
# 9394, 8569, 9385, 8593, 9392, 8590, 9393, 8590, 9396, 8589, 9395, 8592,
#
# clustering: 55.009307060782405%
# 7235, 9368, 7230, 9374, 7236, 9279, 7238, 9348, 7230, 9372, 7152, 9369,
#
# clustering: 66.3371720967987%
# 11886, 11886, 11887, 12033, 12035, 12035,
#
# clustering: 65.34274782909031%
# 24789, 24784, 24790, 25001, 25004, 25008,
#
# clustering: 66.0240494072546%
# 1222, 1218, 1206, 9507, 9514, 9511,
#
# clustering: 65.95323770172423%
# 8177, 10709, 8270, 10718, 8266, 10710, 8267, 10664, 8179, 10709, 8272, 10714,
#
# clustering: 66.58498677386144%
# 5677, 1351, 1299, 5603, 5676, 1302, 5675, 1349, 5675, 1336, 5649, 1315,
#
# clustering: 56.35364267223512%
# 9411, 11488, 9378, 11417, 9411, 11491, 9355, 11494, 9411, 11497, 9385, 11495,
#
# clustering: 66.43277998109494%
# 5675, 650, 5619, 656, 5594, 658, 5680, 672, 5673, 669, 5675, 667,
#
# clustering: 59.938137047972276%
# 5052, 7889, 7899, 5076, 5139, 7820, 5127, 7901, 5136, 7882, 7887, 5043,
#
# clustering: 67.85452257782653%
# 31608, 31611, 31606, 31825, 31825, 31831,
#
# clustering: 51.93019989770631%
# 9770, 11936, 9770, 11932, 9774, 11935, 9771, 11838, 9769, 11938, 9776, 11931,
#
# clustering: 55.50149536473916%
# 22744, 22741, 22747, 22898, 22902, 22896,
#
# clustering: 54.86324749772762%
# 14113, 14121, 16444, 16447, 16447,
#
# clustering: 67.34148047129526%
# 7689, 5422, 7690, 5524, 7688, 5519, 7684, 5528, 7673, 5465, 7683, 5521,
#
# clustering: 64.21829138860353%
# 1348, 1354, 4962, 5034, 1352, 5033, 1291, 1335, 5038, 1320, 5039,
#
# clustering: 66.10603541212943%
# 1117, 1110, 28, 28,
#
# clustering: 66.36947678666841%
# 5625, 677, 651, 5668, 5638, 662, 5678, 660, 5680, 646, 5674, 671,
#
# clustering: 59.19679804511455%
# 34774, 34778, 34776, 34947, 34943, 34949,
#
# clustering: 67.06451312341812%
# 1313, 5675, 5651, 1338, 5681, 1320, 1351, 5606, 1353, 5572, 5573, 1320,
#
# clustering: 66.87182524701167%
# 5673, 1998, 5622, 1941, 5678, 1998, 5674, 2010, 5653, 1975, 5676, 1952,
#
# clustering: 66.6466288175738%
# 1350, 1348, 1338, 666, 667, 674,
#
# clustering: 66.3803326898684%
# 3604, 13230, 3534, 13232, 13232, 3606, 3611, 13224, 3595, 13228, 13232, 3514,
#
# clustering: 60.29252827218906%
# 858, 3328, 851, 3302, 846, 3391, 836, 3302, 846, 3398, 836, 3368,
#
# clustering: 66.27794206827336%
# 5680, 662, 5677, 661, 5675, 657, 5608, 649, 648, 5679, 654, 5637,
#
# clustering: 66.20036434811286%
# 6371, 14596, 6333, 14597, 6372, 14598, 6371, 14591, 6372, 14592, 6368, 14596,
#
# clustering: 66.64062109623326%
# 5701, 5664, 5708, 2874, 2883, 2857,
#
# clustering: 60.569684944105234%
# 10181, 6969, 10184, 6968, 6923, 10186, 10096, 6911, 6939, 10186, 10183, 6974,
#
# clustering: 56.07816073680467%
# 19124, 776, 1529, 19176, 659, 19272, 19224,
#
# clustering: 55.34957497287472%
# 47747, 47748, 23807, 24047, 23838, 24044, 47800, 47670, 47746, 47886,
#
# clustering: 54.7855344099156%
# 12954, 7916, 12958, 7920, 12952,
#
# clustering: 66.28385040093345%
# 26173, 26174, 26176, 26566, 26567, 26568,
#
# clustering: 66.44895032577159%
# 15186, 12712, 15182, 12720, 15183, 12720, 15187, 12718, 15183, 12691, 15184, 12691,
#
# clustering: 53.040944366772706%
# 18355, 18355, 18356, 18491, 18493, 18487,
#
# clustering: 55.32127000061748%
# 12488, 10893, 12487, 10889, 12426, 10892, 12487, 10853, 12488, 10886, 12488, 10886,
#
# clustering: 67.26703654359154%
# 16227, 19248, 19252, 16154, 19243, 16226, 19250, 16222, 19251, 16224, 19248, 16221,
#
# clustering: 57.83127341664166%
# 20756, 20747, 20756, 20958, 20951, 20955,
#
# clustering: 60.857601122479274%
# 20387, 20385, 20388, 20554, 20548, 20551,
#
# clustering: 52.64581614322286%
# 20836, 20833, 20837, 20900, 20901, 20900,
#
# clustering: 66.09194598557424%
# 6962, 6971, 6969, 1324, 1334, 1349,
#
# clustering: 66.36544021694012%
# 20409, 11566, 20404, 11558, 11569, 20399, 11569, 20403, 11503, 20400, 20400, 11566,
#
# clustering: 66.25175995683462%
# 16655, 20252, 16656, 20248, 16658, 20254, 16654, 20201, 16657, 20225, 16663, 20250,
#
# clustering: 60.565134116527844%
# 25191, 25186, 25190, 25426, 25419, 25425,
#
# clustering: 52.75751051997926%
# 1352, 1312, 1322, 666, 669, 670,
#
# clustering: 50.794090669021884%
# 24579, 24582, 24582, 24766, 24759, 24767,
#
# clustering: 63.297588374356266%
# 9336, 9357, 9261, 5753, 5755, 5758,
#
# clustering: 66.53390953199612%
# 804, 5769, 5865, 790, 5867, 777, 5865, 791, 786, 5776, 804, 5866,
#
# clustering: 66.80970377483865%
# 15023, 7559, 7460, 15026, 15023, 7564, 7562, 14948, 15021, 7559, 7564, 15026,
#
# clustering: 65.99540283166677%
# 11475, 11479, 11478, 11592, 11593, 11596,
#
# clustering: 62.04121896863035%
# 26883, 26881, 26888, 27120, 27120, 27118,
#
# clustering: 59.66155292972199%
# 7667, 10564, 7664, 10490, 7663, 10592, 7664, 10590, 7663, 10562, 7579, 10588,
#
# clustering: 63.70658387232899%
# 1956, 5681, 5587, 1947, 5579, 2001, 1981, 5678, 2009, 5675, 1938, 5652,
#
# clustering: 61.464209032151565%
# 1313, 1328, 1334, 676, 653, 674,
#
# clustering: 67.34186160824929%
# 19160, 19153, 19162, 19452, 19453, 19451,
#
# clustering: 66.3538122844933%
# 14972, 8791, 14969, 8793, 14971, 8791, 14974, 8792, 14973, 8788, 14977, 8747,
#
# clustering: 66.58504917500663%
# 16375, 8423, 16371, 8471, 16374, 8523, 16372, 8525, 16374, 8524, 16372, 8531,
#
# clustering: 66.66669808602622%
# 5678, 1305, 5677, 1337, 5678, 1295, 5682, 1344, 1292, 5637, 5602, 1338,
#
# clustering: 66.49344423044674%
# 10244, 4594, 10240, 4659, 10239, 4618, 10243, 4661, 10241, 4654, 10240, 4655,
#
# clustering: 50.28996112768691%
# 5593, 3973, 3978, 5674, 5634, 3970, 5576, 3942, 3971, 5674, 3909, 5645,
#
# clustering: 66.16331593581423%
# 9083, 6881, 9082, 6880, 9076, 6875, 9067, 6876, 9082, 6882, 9077, 6878,
#
# clustering: 67.11868578963485%
# 12733, 8286, 12736, 8384, 12736, 8350, 12736, 8387, 12739, 8383, 12738, 8384,
#
# clustering: 68.20850725578096%
# 20745, 20749, 20750, 20968, 20961, 20962,
#
# clustering: 66.82133625368732%
# 8062, 12393, 12393, 8062, 12397, 8059, 12393, 8058, 7992, 12397, 8061, 12394,
#
# clustering: 66.2429723557514%
# 13481, 7118, 13479, 7117, 13481, 7122, 13455, 7090, 13483, 7123, 7118, 13484,
#
# clustering: 66.56065270163585%
# 9995, 17435, 9989, 17435, 9888, 17433, 9994, 17433, 9934, 17367, 9888, 17435,
#
# clustering: 66.74174874886154%
# 6248, 6320, 6221, 668, 668, 649,
#
# clustering: 66.53797532420617%
# 5155, 12491, 5152, 12486, 5152, 12486, 5077, 12484, 5157, 12488, 12489, 5157,
#
# clustering: 53.63698900174576%
# 1031, 1951, 1958, 1042, 1033, 1992, 1056, 1972, 1050, 1994, 1030, 1989,
#
# clustering: 66.60828200492307%
# 21964, 21962, 21967, 22242, 22243, 22242,
#
# clustering: 66.05156058760586%
# 10105, 15513, 15512, 10103, 15517, 10106, 10102, 15510, 15489, 10099, 10100, 15513,
#
# clustering: 66.32474770483726%
# 13433, 5379, 13440, 5434, 13438, 5435, 13437, 5438, 13436, 5431, 13438, 5431,
#
# clustering: 66.7149964928451%
# 11354, 11357, 11734, 11352, 11728, 11733,
#
# clustering: 66.43633476118846%
# 13336, 6009, 13339, 5996, 13333, 6010, 13335, 5941, 13340, 6007, 13339, 6008,
#
# clustering: 66.04563721303272%
# 675, 9561, 9572, 654, 9577, 673, 9571, 665, 9576, 650, 650, 9575,
#
# clustering: 66.50896830989691%
# 11792, 4584, 11798, 4487, 11798, 4579, 11799, 4534, 11792, 4509, 11785, 4585,
#
# clustering: 55.01879146580497%
# 646, 5646, 5677, 669, 667, 5673, 651, 5659, 662, 674,
#
# clustering: 67.2118493088009%
# 9227, 12190, 9226, 12180, 9220, 12188, 9227, 12190, 9223, 12188, 9159, 12184,
#
# clustering: 58.70682124637149%
# 2904, 7332, 2972, 7330, 2918, 7282, 7234, 2891, 2947, 7330, 7334,
#
# clustering: 66.11550413057459%
# 9041, 13059, 9048, 13089, 9047, 13086, 9042, 13075, 9040, 13087, 9046, 13085,
#
# clustering: 56.96351236700053%
# 5814, 6881, 5784, 6876, 5809, 6873, 5817, 6877, 5775, 6873, 5760, 6875,
#
# clustering: 50.585890951794916%
# 11485, 12303, 11483, 12263, 11483, 12305, 11487, 12304, 11489, 12305, 11432, 12304,
#
# clustering: 51.61787981054975%
# 24569, 24569, 24575, 24724, 24725, 24725,
#
# clustering: 67.24655105007086%
# 9676, 12880, 9676, 12875, 9678, 12877, 9671, 12883, 9602, 12881, 9670, 12877,
#
# clustering: 54.14592817078008%
# 21839, 21838, 21833, 21962, 21957, 21959,
#
# clustering: 53.9751171093845%
# 9836, 7521, 9737, 7506, 9829, 7520, 9829, 7521, 9828, 7527, 9828, 7523,
#
# clustering: 66.60144262798984%
# 12484, 6002, 12485, 6073, 12481, 6082, 12489, 6075, 12489, 6078, 12483, 6076,
#
# clustering: 66.77033015644099%
# 10208, 4080, 10203, 3983, 10204, 4021, 10202, 4088, 10204, 4085, 10201, 4088,
#
# clustering: 68.29401082548127%
# 14411, 16394, 16388, 14337, 16396, 14412, 16388, 14413, 16383, 14418, 16396, 14419,
#
# clustering: 67.94803456420259%
# 19980, 19984, 19984, 20146, 20150, 20147,
#
# clustering: 66.34068646991724%
# 21096, 9003, 21100, 8937, 21099, 9005, 21098, 8913, 21062, 9009, 21097, 9003,
#
# clustering: 66.531427302424%
# 7809, 15201, 15204, 7810, 15198, 7710, 15206, 7756, 15205, 7811, 7750, 15198,
#
# clustering: 66.07261971726864%
# 7281, 14609, 7282, 14566, 7276, 14603, 7279, 14590, 7279, 14601, 7277, 14601,
#
# clustering: 65.97104183750824%
# 20555, 9177, 20557, 9178, 20556, 9177, 20561, 9179, 20556, 9175, 20558, 9177,
#
# clustering: 52.412812218192556%
# 13744, 14945, 13826, 14999, 14999, 13827, 13821, 15001, 13821, 15002, 15000, 13824,
#
# clustering: 66.7864132705079%
# 6964, 6904, 6892, 1292, 1351, 1321,
#
# clustering: 67.47457165115655%
# 3349, 3306, 3323, 1556, 1580, 1586,
#
# clustering: 66.40774495767978%
# 5680, 1327, 5674, 1298, 1297, 5677, 1345, 5646, 5675, 1339, 1325, 5680,
#
# clustering: 66.04297009993884%
# 5673, 1973, 5678, 1952, 5672, 1964, 1965, 5612, 2004, 5681, 1984, 5680,
#
# clustering: 66.33771072787079%
# 5681, 1331, 5675, 1293, 5677, 1319, 5677, 1343, 5675, 1305, 5680, 1316,
#
# clustering: 66.47957480154044%
# 11802, 5195, 11804, 5149, 11801, 5164, 11807, 5242, 11802, 5219, 11810, 5227,
#
# clustering: 66.50132380785898%
# 6032, 14295, 6060, 14289, 5987, 14293, 6062, 14219, 6057, 14296, 6060, 14290,
#
# clustering: 66.78100186836757%
# 3592, 3614, 7487, 7568,
#
# clustering: 66.08642969401663%
# 10008, 10006, 10013, 6125, 6135, 6135,
#
# clustering: 52.6019082910907%
# 19860, 19863, 19866, 20012, 20014, 20019,
#
# clustering: 66.1655642867845%
# 6297, 6322, 6323, 646, 670, 660,
#
# clustering: 66.54431241138278%
# 1048, 7609, 7536, 1015, 7545, 1048, 1026, 7615, 7553, 1053, 7611, 1008,
#
# clustering: 66.04929313679112%
# 14009, 14006, 1338, 1319, 14007, 1300,
#
# clustering: 66.16800520358188%
# 15617, 9490, 15574, 9471, 15613, 9485, 15615, 9483, 15612, 9492, 15617, 9492,
#
# clustering: 64.9616606932%
# 516, 2574, 2581, 520, 2581, 526, 2579, 523, 2540, 509, 2581, 515,
#
# clustering: 66.9861518391754%
# 10346, 15553, 10282, 15552, 10251, 15449, 10343, 15469, 10275, 15547, 10316, 15552,
#
# clustering: 65.98300592789126%
# 19473, 10133, 10141, 19473, 19468, 10134, 19465, 10135, 19466, 10140, 19474, 10137,
#
# clustering: 67.51032319183864%
# 5588, 1936, 1991, 5584, 5678, 1982, 5674, 2009, 5640, 1976, 1968, 5628,
#
# clustering: 66.40509655014338%
# 6815, 1947, 1959, 6756, 1995, 6815, 6815, 1944, 6810, 2007, 1955, 6817,
#
# clustering: 67.45500122835462%
# 6752, 9708, 6748, 9710, 6664, 9707, 6750, 9700, 6654, 9709, 6753, 9710,
#
# clustering: 50.77653846070368%
# 7962, 7712, 7961, 7709, 7967,
#
# clustering: 65.88835787893977%
# 192, 199, 192, 199,
#
# clustering: 66.35592119257814%
# 9038, 4080, 4068, 9037, 9039, 4061, 9043, 4112, 4142, 9044, 4082, 9042,
#
# clustering: 51.705791622313214%
# 3667, 6924, 3808, 6964,
#
# clustering: 67.76908416031912%
# 14490, 13279, 14494, 13278, 14492, 13277, 14486, 13276, 14485, 13280, 14485, 13244,
#
# clustering: 66.4152785895899%
# 9410, 16435, 9411, 16438, 9414, 16432, 9410, 16431, 16431, 9418, 9355, 16433,
#
# clustering: 63.72731443872047%
# 20410, 20411, 20403, 20594, 20591, 20592,
#
# clustering: 66.98696045544683%
# 20488, 21022, 20486, 21015, 20486, 21015, 20487, 21017, 20492, 21017, 20463, 21018,
#
# clustering: 66.10956268753853%
# 12920, 7543, 12919, 7545, 12914, 7542, 12920, 7530, 12914, 7539, 12923, 7526,
#
# clustering: 65.05266584521516%
# 25545, 25547, 25539, 25761, 25764, 25762,
#
# clustering: 54.71695801844689%
# 28, 29, 28, 29, 28,
#
# clustering: 66.5360290433623%
# 12524, 12519, 12932, 12935,
#
# clustering: 67.1828794006876%
# 35679, 35681, 35674, 35894, 35896, 35897,
#
# clustering: 67.31867472172509%
# 14755, 11751, 14752, 11832, 14756, 11785, 14755, 11829, 14752, 11833, 14755, 11837,
#
# clustering: 67.7923189311764%
# 5285, 8631, 5203, 8563, 5298, 8626, 5295, 8633, 5256, 8633, 5299, 8570,
#
# clustering: 66.67677435409009%
# 7509, 12564, 7523, 12560, 7497, 12500, 7572, 12558, 7572, 12560, 7576, 12563,
#
# clustering: 66.5771615557995%
# 10925, 5650, 10982, 5621, 10946, 5642, 10980, 5603, 10982, 5661, 10983, 5661,
#
# clustering: 66.53558268371357%
# 7477, 9235, 7492, 9241, 7474, 9232, 7495, 9234, 7486, 9240, 7490, 9233,
#
# clustering: 66.052232945065%
# 17927, 24131, 24168, 17920, 24157, 17921, 24170, 17922, 24170, 17926, 24168, 17926,
#
# clustering: 66.56674473358224%
# 8213, 13979, 8279, 13981, 8280, 13975, 8271, 13981, 8276, 13973, 8277, 13978,
#
# clustering: 67.40358777832216%
# 8232, 10644, 8234, 10637, 8225, 10638, 8230, 10636, 8172, 10637, 8229, 10638,
#
# clustering: 66.44968636962389%
# 17193, 8768, 17194, 8759, 8765, 17199, 17193, 8766, 17193, 8769, 17198, 8690,
#
# clustering: 66.00699825978619%
# 11279, 17795, 11289, 17791, 11288, 17788, 11287, 17787, 11279, 17796, 11281, 17794,
#
# clustering: 58.51786425935734%
# 1291, 1323, 1291, 669, 676, 658,
#
# clustering: 66.40206075931034%
# 10079, 6403, 6455, 10159, 6455, 10161, 6456, 10141, 6355, 10161, 6452, 10118,
#
# clustering: 67.04123935051312%
# 10536, 7656, 10536, 7692, 10537, 7697, 10537, 7691, 10534, 7693, 10534, 7629,
#
# clustering: 63.84423855344428%
# 653, 5661, 655, 649, 5678, 664, 5673, 656, 5579, 653, 5634,
#
# clustering: 66.42138577488663%
# 13019, 8349, 13021, 8347, 13024, 8353, 13020, 8292, 13021, 8297, 13026, 8289,
#
# clustering: 57.66817218466217%
# 5678, 3325, 3330, 5682, 3332, 5630, 3308, 5680, 5615, 3331, 3295, 5579,
#
# clustering: 67.01278671350534%
# 8101, 13420, 8095, 13515, 8098, 13521, 8096, 13519, 8041, 13414, 8100, 13490,
#
# clustering: 66.39685356389997%
# 14637, 5133, 5136, 14630, 14640, 5134, 14630, 5057, 14636, 5032, 5074, 14637,
#
# clustering: 66.49626996635928%
# 5676, 1978, 1959, 5677, 5679, 1949, 5672, 2009, 5614, 1972, 5680, 1941,
#
# clustering: 66.37451939461005%
# 1986, 7074, 1973, 7065, 2007, 7042, 7070, 1971, 7014, 2011, 7071, 1983,
#
# clustering: 65.6137733378059%
# 5674, 1329, 5659, 1353, 5675, 1349, 1330, 5593, 5682, 1347, 1322, 5666,
#
# clustering: 66.50082811862875%
# 11311, 15911, 15911, 11312, 15908, 11308, 11304, 15911, 11255, 15909, 15907, 11278,
#
# clustering: 66.48557743354202%
# 8329, 13814, 8328, 13721,
#
# clustering: 66.450931349387%
# 6905, 6969, 6971, 1319, 1296, 1342,
#
# clustering: 60.45136402611001%
# 14367, 11303, 14359, 11307, 14367, 11307, 14366, 11309, 14360, 11311, 14283, 11308,
#
# clustering: 53.46067725628803%
# 7993, 9678, 7986, 9680, 7990, 9683, 7988, 9608, 7991, 9662, 7986, 9684,
#
# clustering: 53.576461648721256%
# 8129, 5685, 8174, 5772, 8169, 5772, 8188, 5680, 8099, 5695, 8187, 5770,
#
# clustering: 56.65643150812978%
# 7842, 10139, 7842, 10135, 7917, 10140, 7915, 10140, 7922, 10140, 7921, 10058,
#
# clustering: 66.47503492262943%
# 14016, 5691, 14021, 5610, 14014, 5688, 14018, 5697, 14017, 5699, 14014, 5599,
#
# clustering: 66.51541115641842%
# 14882, 7119, 14886, 7045, 14886, 7022, 14884, 7119, 14884, 7119, 14881, 7113,
#
# clustering: 58.66432922425032%
# 18360, 18359, 18364, 18517, 18520, 18521,
#
# clustering: 66.47217537157387%
# 10763, 16376, 10765, 16322, 10714, 16374, 10763, 16373, 10761, 16370, 10732, 16371,
#
# clustering: 66.19742360495066%
# 19770, 19774, 19772, 20000, 20004, 20006,
#
# clustering: 68.13582831278597%
# 13303, 656, 13260, 670, 13235, 670, 13739, 677, 13254, 667, 13286, 649,
#
# clustering: 63.42850044988191%
# 16107, 19673, 16116, 19598, 16138, 19677, 16145, 19672, 16145, 19679, 16136, 19675,
#
# clustering: 66.8525457518373%
# 1077, 528, 529, 1092,
#
# clustering: 65.98016991469854%
# 14430, 19169, 14429, 19174, 14433, 19174, 14426, 19172, 14427, 19169, 14430, 19174,
#
# clustering: 63.15412825790584%
# 11711, 9533, 11656, 9607, 11693, 9603, 11715, 9602, 11711, 9605, 11710, 9608,
#
# clustering: 66.70325539777839%
# 7359, 15305, 7414, 15206, 7315, 15309, 7415, 15312, 7419, 15309, 7404, 15311,
#
# clustering: 57.02695634081677%
# 1330, 512, 522, 1348, 1351, 508, 508, 1354, 1335, 512, 525, 1315,
#
# clustering: 64.08915208712146%
# 26893, 26890, 26888, 27061, 27056, 27058,
#
# clustering: 55.09086304324293%
# 7848, 10219, 7807, 10214, 7908, 10213, 7914, 10192, 7883, 10124, 7909, 10220,
#
# clustering: 66.16851757581561%
# 14151, 10223, 14150, 10226, 14159, 10225, 14158, 10227, 14150, 10224, 14157, 10212,
#
# clustering: 66.1306377572874%
# 1304, 1303, 1351, 6965, 6969, 6966,
#
# clustering: 66.11150118726025%
# 2000, 20832, 2042, 20825, 1973, 20828, 1995, 20828, 2011, 20825, 2035, 20826,
#
# clustering: 66.75646247658216%
# 11944, 7158, 11940, 7190, 11946, 7113, 11948, 7188, 11946, 7184, 11941, 7186,
#
# clustering: 60.628678559537036%
# 7710, 4332, 7800, 4404, 7804, 4403, 7805, 4404, 7807, 4336, 7803, 4403,
#
# clustering: 66.27179157625179%
# 20704, 9669, 20702, 9657, 20699, 9575, 20707, 9667, 20700, 9573, 20700, 9605,
#
# clustering: 62.478431661211594%
# 10204, 7707, 10259, 7720, 7715, 10256, 7710, 10183, 7649, 10261, 10255, 7717,
#
# clustering: 50.562570481903485%
# 26946, 26954, 26949, 27105, 27108, 27106,
#
# clustering: 67.38288991069122%
# 11438, 12390, 11443, 12394, 11439, 12394, 11442, 12398, 11420, 12392, 11441, 12396,
#
# clustering: 66.24087028906307%
# 44535, 44531, 44532, 44847, 44847, 44847,
#
# clustering: 62.62800699485995%
# 5677, 1300, 5577, 1292, 5680, 1299, 5677, 1337, 5678, 1353, 1291, 5673,
#
# clustering: 66.49863521989582%
# 107, 53, 108, 53,
#
# clustering: 64.20625952521443%
# 1301, 5676, 1341, 5616, 1349, 5674, 1346, 5674, 1337, 5678, 5574, 1315,
#
# clustering: 67.63855441890486%
# 26666, 26671, 26670, 26899, 26904, 26900,
#
# clustering: 66.7136775769797%
# 15796, 10901, 15801, 10902, 15796, 10907, 15805, 10842, 15799, 10907, 15795, 10910,
#
# clustering: 66.52333421928242%
# 2012, 1982, 1979, 7613, 7515, 7593,
#
# clustering: 66.3285524154624%
# 6323, 6323, 6225, 663, 664, 670,
#
# clustering: 66.52465072754653%
# 6662, 11201, 6665, 11158, 6665, 11213, 6662, 11212, 6630, 11211, 6664, 11216,
#
# clustering: 66.58932381378781%
# 657, 5672, 5654, 654, 5591, 651, 5586, 651, 5636, 674, 5678, 673,
#
# clustering: 66.14054780530849%
# 13157, 9672, 13163, 9673, 13163, 9677, 13118, 9672, 13164, 9675, 13158, 9677,
#
# clustering: 66.310667719835%
# 29853, 29853, 29855, 30170, 30167, 30169,
#
# clustering: 66.38019481461666%
# 12350, 3622, 12344, 3692, 12351, 3639, 12351, 3701, 12347, 3622, 12248, 3698,
#
# clustering: 56.0971068956976%
# 5317, 7404, 5319, 7403, 5323, 7403, 5322, 7400, 5322, 7405, 5324, 7330,
#
# clustering: 54.05520633524209%
# 12718, 14918, 12720, 14914, 12720, 14914, 12720, 14912, 12718, 14828, 12718, 14915,
#
# clustering: 61.42038805132188%
# 659, 672, 661, 3598, 3689, 3663,
#
# clustering: 65.36726701408999%
# 2010, 5676, 2030, 5641, 5676, 1974, 1938, 5673, 5675, 1951, 5597, 2009,
#
# clustering: 62.16074374980771%
# 524, 2523, 521, 2543, 2583, 509, 2542, 529, 2614, 524, 2591, 529,
#
# clustering: 64.87871746224539%
# 5677, 1330, 5665, 1344, 1343, 5673, 5676, 1320, 5676, 1305, 5590, 1308,
#
# clustering: 66.67444604617573%
# 7508, 14030, 14031, 7507, 14034, 7511, 7512, 13983, 14016, 7473, 7429, 14030,
#
# clustering: 64.62675518526174%
# 5678, 655, 5674, 675, 5672, 659, 5675, 653, 5578, 669, 5674, 654,
#
# clustering: 50.22974863637444%
# 1174, 556, 1203, 572,
#
# clustering: 65.45323451380553%
# 648, 5579, 5679, 645, 5676, 666, 673, 5677,
#
# clustering: 66.48809627356934%
# 1330, 5613, 5672, 1305, 5681, 1299,
#
# clustering: 56.99077205103718%
# 922, 12257, 943, 11845,
#
# clustering: 66.0973466170349%
# 18069, 8618, 17975, 8624, 18069, 8622, 18064, 8622, 18065, 8614, 18066, 8623,
#
# clustering: 67.05246860632046%
# 7824, 12373, 7825, 12368, 7827, 12375, 7829, 12369, 7721, 12376, 7743, 12369,
#
# clustering: 64.74830593532126%
# 34945, 34952, 34956, 35281, 35282, 35282,
#
# clustering: 66.57022510457125%
# 663, 5677, 663, 5672, 663, 5598, 5587, 646, 646, 5680, 655, 5629,
#
# clustering: 60.67240990397389%
# 13249, 9698, 13152, 9697, 13250, 9693, 13248, 9645, 13246, 9700, 13249, 9694,
#
# clustering: 66.18565201559535%
# 12607, 14637, 12608, 14634, 14634, 12609, 12608, 14617, 12613, 14638, 12605, 14635,
#
# clustering: 66.3464921949782%
# 4215, 10857, 4214, 10855, 4162, 10861, 4190, 10855, 4215, 10854, 4208, 10857,
#
# clustering: 66.43706766638631%
# 17629, 8044, 17631, 8049, 17637, 8024, 17633, 8051, 17629, 8048, 17628, 7962,
#
# clustering: 67.23954894232504%
# 25283, 25283, 25282, 25536, 25529, 25530,
#
# clustering: 66.9133063290518%
# 28347, 28344, 28342, 28696, 28692, 28691,
#
# clustering: 63.77653326736488%
# 1330, 5680, 1334, 5678, 1298, 5628, 1292, 1349, 5675, 1302, 5680,
#
# clustering: 66.06854515737638%
# 13041, 7408, 12993, 7410, 13043, 7407, 13045, 7409, 13047, 7408, 13041, 7408,
#
# clustering: 66.98775150742075%
# 13558, 11129, 13561, 11128, 13527, 11125, 13562, 11128, 13561, 11099, 13559, 11083,
#
# clustering: 66.44216442693399%
# 8473, 15829, 8467, 15836, 8410, 15806, 8474, 15828, 8467, 15833, 8468, 15835,
#
# clustering: 66.03765871951475%
# 19419, 13267, 19416, 13273, 19418, 13269, 19421, 13261, 19420, 13269, 19424, 13270,
#
# clustering: 66.13032512489204%
# 2810, 2735, 16891, 16894,
#
# clustering: 66.41446710447211%
# 10237, 15497, 10241, 15500, 10190, 15500, 10236, 15498, 10226, 15494, 10238, 15499,
#
# clustering: 63.36018048121544%
# 27142, 27139, 27149, 27490, 27493, 27495,
#
# clustering: 66.19658890017328%
# 19932, 19933, 19931, 20071, 20073, 20069,
#
# clustering: 66.00922341627653%
# 25287, 13714, 25323, 13711, 25328, 13712, 25323, 13709, 25322, 13711, 25329, 13711,
#
# clustering: 58.433856586424085%
# 38939, 38945, 38936, 39192, 39188, 39191,
#
# clustering: 67.66635302405726%
# 8240, 9520, 8269, 9526, 8272, 9511, 8275, 9526, 8272, 9519, 8274, 9519,
#
# clustering: 58.4500901530831%
# 21009, 21010, 21001, 21177, 21171, 21171,
#
# clustering: 66.50466425411098%
# 663, 5673, 675, 5677, 5581, 651, 5590, 646, 5679, 647, 5679, 667,
#
# clustering: 67.08156035388663%
# 7640, 10114, 10167, 7532, 10166, 7639, 10163, 7639, 10150, 7639, 10165, 7640,
#
# clustering: 59.19218668888876%
# 9936, 6796, 9936, 6829, 9934, 6833, 9939, 6826, 9939, 6825, 9845, 6823,
#
# clustering: 66.21758583089068%
# 7414, 16251, 7419, 16256, 7413, 16253, 7378, 16255, 7413, 16255, 7411, 16212,
#
# clustering: 60.19783652403895%
# 6132, 2592, 6253, 2627,
#
# clustering: 58.87091448943195%
# 930, 474, 942, 466, 924, 457, 940, 468, 942, 471, 467, 938,
#
# clustering: 66.09088817564603%
# 15258, 12052, 15255, 12053, 15255, 12045, 15252, 12051, 15257, 12050, 15250, 12053,
#
# clustering: 65.98116438501526%
# 18302, 10320, 18284, 10312, 18303, 10312, 18299, 10312, 18303, 10313, 18305, 10312,
#
# clustering: 55.122644997116794%
# 14870, 14817, 7203, 7146, 14840,
#
# clustering: 65.88486586784182%
# 5672, 1958, 2025, 5670, 1943, 5680, 1994, 5673, 5608, 1969, 5679, 1963,
#
# clustering: 69.32006367162346%
# 8797, 10542, 8801, 10543, 8797, 10545, 8699, 10539, 8797, 10542, 8801, 10547,
#
# clustering: 66.39191302052099%
# 5597, 650, 670, 5675, 5679, 649, 676, 5643, 5679, 676, 646, 5680,
#
# clustering: 66.59858910249416%
# 15528, 7234, 15532, 7234, 15531, 7135, 15524, 7230, 15532, 7231, 15533, 7234,
#
# clustering: 66.77023640645432%
# 10281, 11571, 10267, 11572, 10283, 11574, 10279, 11579, 10288, 11573, 10280, 11579,
#
# clustering: 66.98263067291418%
# 9446, 5893, 9449, 5893, 9447, 5891, 9454, 5818, 9448, 5827, 9445, 5897,
#
# clustering: 67.20372327164255%
# 9755, 9062, 9757, 9075, 9754, 9076, 9756, 9073, 9753, 9075, 9758, 9076,
#
# clustering: 66.08709606393106%
# 26117, 26122, 26116, 26364, 26370, 26363,
#
# clustering: 58.76406882498881%
# 9091, 12393, 9086, 12396, 9090, 12389, 9087, 12380, 9091, 12292, 9092, 12391,
#
# clustering: 67.00814974527167%
# 14474, 9889, 14475, 9859, 14471, 9796, 14475, 9889, 14475, 9890, 14478, 9887,
#
# clustering: 67.26846876624857%
# 8107, 11755, 8105, 11760, 8105, 11754, 8106, 11759, 11753, 8075, 8014, 11760,
#
# clustering: 63.83362886902691%
# 12637, 8694, 12582, 8768, 12533, 8776, 12609, 8776, 12633, 8772, 12634, 8739,
#
# clustering: 68.65694160552808%
# 13362, 1354, 13329, 1324, 13453, 1319, 13926, 1342, 13321, 1343, 13398, 1347,
#
# clustering: 66.25174189217869%
# 4252, 10514, 4266, 10609, 4251, 10609, 4278, 10607, 4277, 10609, 4274, 10605,
#
# clustering: 59.06145905640949%
# 19979, 19982, 19985, 20149, 20153, 20153,
#
# clustering: 66.02478218152976%
# 14715, 7869, 14721, 7873, 14716, 7876, 14723, 7869, 14721, 7870, 14722, 7862,
#
# clustering: 65.96535169997794%
# 11961, 19461, 11958, 19457, 11957, 19462, 11957, 19458, 11955, 19461, 11962, 19462,
#
# clustering: 67.06383825620713%
# 12731, 7929, 7933, 12727, 7918, 12687, 7858, 12643, 7927, 12734, 7844, 12730,
#
# clustering: 66.38474412310707%
# 6895, 13917, 6890, 13922, 6840, 13925, 6861, 13921, 6854, 13919, 6813, 13923,
#
# clustering: 67.11462861653733%
# 16676, 650, 16713, 677, 16648, 672, 16951, 669, 16520, 647, 16621, 646,
#
# clustering: 67.39110946672444%
# 18895, 18897, 18895, 19000, 19002, 18999,
#
# clustering: 66.73262160411734%
# 14411, 10492, 14413, 10437, 14406, 10496, 14408, 10498, 14411, 10429, 14414, 10494,
#
# clustering: 66.50479326232794%
# 8047, 15547, 8143, 15551, 8138, 15551, 8142, 15535, 8107, 15548, 8060, 15554,
#
# clustering: 64.32065450645952%
# 15304, 13062, 15356, 13067, 15324, 13064, 15355, 13065, 15356, 13062, 15357, 13059,
#
# clustering: 58.4500901530831%
# 17701, 17707, 17707, 17869, 17877, 17868,
#
# clustering: 65.24182049742468%
# 9279, 4793, 9278, 4737, 9192, 4758, 9278, 4740, 9275, 4800, 9275, 4793,
#
# clustering: 63.426750649500065%
# 10936, 7539, 10929, 7540, 10938, 7543, 10932, 7536, 10930, 7542, 10861, 7536,
#
# clustering: 65.98458960306425%
# 9125, 9125, 9124, 5616, 5612, 5620,
#
# clustering: 66.66702169236504%
# 8864, 13175, 8866, 13182, 8853, 13180, 13181, 8809, 13175, 8870, 13177, 8866,
#
# clustering: 66.06797303861215%
# 22413, 30116, 22411, 30117, 22401, 30104, 22415, 30118, 22418, 30120, 22411, 30105,
#
# clustering: 58.913376617233986%
# 8571, 6983, 8569, 6918, 8566, 6986, 8565, 6912, 8565, 6983, 8569, 6953,
#
# clustering: 66.50802436724378%
# 6315, 17636, 6311, 17696, 6311, 17695, 6305, 17701, 6317, 17702, 6211, 17698,
#
# clustering: 58.318614219137736%
# 9565, 12374, 9567, 12377, 9563, 12342, 9565, 12277, 9572, 12347, 9572, 12375,
#
# clustering: 66.35855793048982%
# 17054, 7766, 17063, 7693, 17015, 7721, 17057, 7764, 17054, 7770, 17058, 7730,
#
# clustering: 62.09430243937044%
# 5506, 4265, 5501, 4173, 5506, 4267, 5500, 4258, 5473, 4265, 5507, 4263,
#
# clustering: 50.101316402380654%
# 14562, 14563, 14567, 14707, 14704, 14710,
#
# clustering: 66.81909942505987%
# 5676, 2026, 5678, 1959, 5622, 2005, 5679, 1956, 5680, 2030, 5673, 1990,
#
# clustering: 55.715774890527506%
# 16224, 16225, 16225, 16378, 16370, 16372,
#
# clustering: 58.192967241947265%
# 6651, 9181, 6653, 9184, 6677, 9180, 6713, 9102, 6713, 9109, 6719, 9180,
#
# clustering: 66.53571648660883%
# 1304, 5677, 1320, 5635, 1349, 5674, 5680, 1348, 1330, 5675, 5649, 1329,
#
# clustering: 66.59193307562578%
# 4215, 9086, 4201, 9080, 4253, 9078, 4256, 9085, 4163, 9080, 4167, 9084,
#
# clustering: 66.17171507036966%
# 10779, 9184, 10776, 9181, 10777, 9186, 9187, 10777, 9180, 10777, 9183, 10781,
#
# clustering: 51.07516617006793%
# 18912, 18915, 18918, 19037, 19035, 19039,
#
# clustering: 66.18044449499209%
# 506, 6152, 6150, 527, 512, 6156, 6157, 513, 6096, 526, 6150, 508,
#
# clustering: 66.08485314778167%
# 7522, 918, 7521, 930, 7513, 933, 7513, 945, 7518, 916, 7520, 930,
#
# clustering: 56.46930934795589%
# 1145, 2841, 1130, 2759, 1128, 2771, 1151, 2848, 1142, 2812, 1112, 2780,
#
# clustering: 66.53218100226242%
# 656, 5666, 5674, 673, 5677, 647, 5601, 676, 5652, 653, 656, 5591,
#
# clustering: 66.35102283993132%
# 6325, 6255, 6324, 660, 646, 673,
#
# clustering: 66.73141654052537%
# 7520, 1473, 7421, 1463, 7452, 1447, 7412, 1423, 7514, 1424, 1462, 7512,
#
# clustering: 58.52520666921783%
# 939, 2025, 937, 2013, 913, 1965, 946, 1965, 938, 1980, 943, 1973,
#
# clustering: 60.5901254226449%
# 200, 193, 200, 387, 394, 385,
#
# clustering: 54.47277672293678%
# 197, 198, 401, 393,
#
# clustering: 55.6245576564152%
# 6962, 6959, 6960, 5540, 5506,
#
# clustering: 53.25275384372518%
# 11650, 9259, 11544, 9333, 11644, 9333, 11642, 9279, 11647, 9335, 9341, 11646,
#
# clustering: 66.49536583996797%
# 3273, 3298, 653, 675,
#
# clustering: 66.64141195575989%
# 7068, 6849, 7068, 6844,
#
# clustering: 58.87864229763774%
# 49051, 8195, 7853, 8666, 49045, 8326, 50286,
#
# clustering: 54.82714318051161%
# 27525, 23258, 27529, 23255, 27503,
#
# clustering: 51.63513805429204%
# 19940, 19937, 19932, 20076, 20075, 20075,
#
# clustering: 66.34446328105672%
# 3932, 12433, 3913, 12433, 3976, 12434, 3893, 12439, 3983, 12432, 3959, 12438,
#
# clustering: 62.664908607121376%
# 20005, 20005, 20005, 20187, 20184, 20190,
#
# clustering: 55.00028325231493%
# 3294, 31048, 31056, 3399, 31047, 3391, 31050, 3336, 31048, 31039,
#
# clustering: 65.71108616008466%
# 19567, 19566, 19560, 19753, 19747, 19746,
#
# clustering: 66.20598003971418%
# 22417, 22417, 22418, 22626, 22626, 22627,
#
# clustering: 65.7613344481735%
# 52062, 52064, 52055, 52310, 52308, 52306,
#
# clustering: 55.48158273048595%
# 23424, 23427, 23419, 23638, 23644, 23645,
#
# clustering: 59.289206461853134%
# 24290, 24291, 24284, 24422, 24425, 24423,
#
# clustering: 66.58819786949526%
# 16824, 11653, 16823, 11655, 16823, 11587, 16825, 11649, 11654, 16825, 16827, 11626,
#
# clustering: 56.049931231132284%
# 9132, 11841, 9129, 11746, 9126, 11844, 9131, 11839, 9128, 11840, 9123, 11843,
#
# clustering: 66.92463625244613%
# 47866, 47863, 47861, 48128, 48123, 48129,
#
# clustering: 66.20450503968536%
# 2453, 16556, 2454, 16555, 2403, 16561, 2372, 16555, 2390, 16556, 2465, 16559,
#
# clustering: 67.29565176101647%
# 12728, 7993, 12652, 8016, 12725, 8010, 12723, 8016, 12724, 8014, 12726, 7911,
#
# clustering: 59.710486842174596%
# 16364, 16364, 16367, 16580, 16580, 16574,
#
# clustering: 66.12611303044257%
# 8980, 19960, 8982, 19962, 8945, 19956, 8977, 19960, 8986, 19960, 8979, 19962,
#
# clustering: 53.77408361370271%
# 11126, 13713, 11132, 13713, 11024, 13713, 11053, 13718, 11129, 13637, 11041, 13710,
#
# clustering: 67.63533838101714%
# 8294, 9615, 8352, 9608, 8347, 9608, 8317, 9615, 8353, 9610, 8354, 9608,
#
# clustering: 57.5995587582577%
# 9760, 11021, 11021, 9786, 9786, 11020, 9788, 10980, 11019, 9759, 9792, 11028,
#
# clustering: 58.25875396365516%
# 7678, 4956, 7584, 4870, 7680, 4913, 7663, 4932, 7675, 4956, 7674, 4962,
#
# clustering: 66.28388173768013%
# 3495, 8883, 3499, 8924, 8926, 3501, 8919, 3473, 3495, 8922, 3501, 8925,
#
# clustering: 55.1471619335502%
# 8486, 11025, 11122, 8480, 8488, 11119, 8481, 11125, 11124, 8481, 11124, 8488,
#
# clustering: 51.19198172252841%
# 11185, 11180, 11183, 11358, 11350, 11356,
#
# clustering: 63.33122271477188%
# 25720, 25715, 25718, 25922, 25920, 25916,
#
# clustering: 68.48398653327651%
# 15113, 13407, 13406, 15106, 13405, 15112, 15110, 13408, 13333, 15108, 13407, 15108,
#
# clustering: 62.04986657733437%
# 9089, 12456, 9093, 12384, 9089, 12467, 9093, 12464, 9090, 12460, 9089, 12470,
#
# clustering: 66.50347436449943%
# 6937, 6918, 6966, 1340, 1296, 1325,
#
# clustering: 65.95881161439415%
# 19692, 9865, 19700, 9868, 19700, 9867, 19697, 9865, 9868, 19698, 19696, 9866,
#
# clustering: 51.89217782310563%
# 3807, 6318, 6291, 3890, 6217, 3895, 6319, 3896, 3837, 6318, 3798, 6244,
#
# clustering: 50.639305911817665%
# 941, 2623, 2620, 927, 2588, 918, 2545, 938, 942, 2521, 2573, 920,
#
# clustering: 66.29292468178832%
# 9926, 15571, 9922, 15578, 9918, 15576, 9889, 15572, 9923, 15568, 9919, 15571,
#
# clustering: 66.05477102312226%
# 12529, 12537, 12527, 9048, 9052, 9050,
#
# clustering: 55.82530442458436%
# 21168, 21163, 21164, 21351, 21346, 21352,
#
# clustering: 59.21929744718205%
# 21815, 21808, 21812, 21980, 21983, 21979,
#
# clustering: 66.42073882691462%
# 21093, 10201, 21088, 10292, 21094, 10227, 21089, 10288, 21031, 10291, 21097, 10293,
#
# clustering: 67.09304661833976%
# ...
# 12443, 37122, 12439, 37087,
#
# clustering: 64.41181073005103%
# 5681, 1291, 5583, 1296, 1348, 5633, 1297, 5600, 5656, 1324, 1314,
#
# clustering: 63.75354390811802%
# 16120, 1321, 16283, 1343, 16860, 1648, 16156, 1314, 16508, 1344, 16206, 1363,
#
# clustering: 54.12346901709269%
# 2837, 5027, 2780, 5036, 2806, 4945, 2847, 4999, 2819, 5042, 2777, 5041,
#
# clustering: 66.24469661426889%
# 10111, 1294, 10096, 1310, 10105, 1349, 1340, 10112, 1325, 10112, 1313, 10049,
#
# clustering: 63.76900894953389%
# 646, 668, 5624, 662, 5627, 5676, 656, 675, 5675, 5678, 661,
#
# clustering: 63.66772278473803%
# 1306, 5674, 5655, 1292, 5648, 1337, 1312, 5573, 5675, 1349, 5678, 1302,
#
# clustering: 66.3956513011238%
# 6320, 6274, 6280, 652, 667, 674,
#
# clustering: 61.070783069883944%
# 1982, 5681, 2022, 5674, 1958, 5583, 1953, 5680, 2028, 5576, 2018, 5678,
#
# clustering: 55.27097292003737%
# 1340, 1317, 1308, 673, 663, 651,
#
# clustering: 66.26957992993397%
# 1946, 8049, 8055, 1961, 1978, 8058, 1976, 8053, 2012, 8052, 1943, 8061,
#
# clustering: 54.25922816873507%
# 26378, 10694, 26827, 11313,
#
# clustering: 67.05740261403501%
# 1998, 1990, 1996, 1307, 1311, 1296,
#
# clustering: 65.2591036352935%
# 1342, 5675, 1301, 5677, 5681, 1300, 1351, 5681, 1346, 5679, 5597, 1295,
#
# clustering: 66.77960971013003%
# 1307, 1306, 1298, 651, 647, 659,
#
# clustering: 61.12417803853935%
# 2782, 2832, 2845, 5588, 5515, 5591,
#
# clustering: 54.178152433994434%
# 5638, 1294, 5596, 1342, 1312, 5680, 5679, 1304, 1311, 1297,
#
# clustering: 59.751088959674696%
# 5574, 5579, 8328, 8236,
#
# clustering: 66.07729471955291%
# 13700, 3668, 13746, 3661, 13736, 3665,
#
# clustering: 51.633825350653325%
# 3464, 3534, 3467, 3533,
#
# clustering: 53.8090694694016%
# 1821, 479, 1805, 484, 1847, 487, 1853, 486, 1791, 481, 1867, 473,
#
# clustering: 66.08228015415642%
# 1964, 5634, 5677, 1956, 1984, 5678, 1992, 5649, 5674, 2010, 5597, 1985,
#
# clustering: 55.0888885085273%
# 2022, 510, 1937, 527, 1986, 514, 2012, 526, 1966, 519, 524, 1986,
#
# clustering: 50.08652864857149%
# 2628, 5638, 5604, 2683, 5675, 2613, 5677, 2675, 2669, 2633,
#
# clustering: 55.46523993600899%
# 5584, 5585, 4220, 137207, 137208,
#
# clustering: 63.24770257886424%
# 14500, 674, 14535, 663, 14529, 674, 14470, 672, 15659, 655, 14465, 660,
#
# clustering: 66.14605219060199%
# 6964, 6967, 6968, 1310, 1294, 1333,
#
# clustering: 66.29547097017203%
# 662, 7608, 7507, 676, 651, 7609, 7609, 648, 7613, 658, 7565, 663,
#
# clustering: 66.69922182079081%
# 5608, 1294, 5637, 1295, 5676, 1322, 5673, 1353, 5629, 1297, 5678, 1345,
#
# clustering: 66.1446773156973%
# 5681, 674, 5678, 661, 5681, 650, 5674, 664, 5663, 670, 651, 5672,
#
# clustering: 53.441889992669246%
# 2795, 2845, 2792, 5592, 5591, 5491,
#
# clustering: 67.17791287816553%
# 24615, 9203, 9126, 24552, 24551, 9200, 9199, 24577, 9187, 24452, 24816, 9195,
#
# clustering: 66.23046399142265%
# 8113, 917, 8167, 941, 8167, 945, 912, 8165, 8140, 945, 930, 8164,
#
# clustering: 66.18678424326382%
# 5680, 649, 5677, 676, 5679, 655, 675, 5673, 5677, 653, 5647, 665,
#
# clustering: 67.19859226122362%
# 3723, 1331, 1353, 3671, 3705, 1326, 1312, 3721, 1315, 3700, 1300, 3679,
#
# clustering: 56.403744591705475%
# 21453, 3401, 21455, 2610, 21528, 2402, 21440, 2634, 21445, 3257, 21221,
#
# clustering: 64.09341691387188%
# 2028, 5659, 1987, 5673, 2019, 5679, 5593, 1954, 5675, 2022, 5673, 1943,
#
# clustering: 59.731727807211335%
# 5673, 2587, 2680, 5579, 5674, 2684, 2631, 5680, 2662, 5645, 5676, 2678,
#
# clustering: 66.27376366122851%
# 8430, 15002, 8430, 14991, 8438, 15001, 8439, 15005, 8438, 14943, 8429, 14906,
#
# clustering: 66.26278653325382%
# 12383, 1479, 1469, 12387, 1433, 12379, 12323, 1446, 1412, 12382, 12385, 1475,
#
# clustering: 65.44107645099528%
# 1332, 6324, 6322, 1336, 6230, 1291, 6322, 1297, 6323, 1331, 6317, 1305,
#
# clustering: 67.04822669565887%
# 1317, 1322, 1308, 666, 657, 654,
#
# clustering: 56.278593565616355%
# 1294, 1322, 1292, 673, 647, 662,
#
# clustering: 63.49957176185094%
# 5680, 1338, 5681, 1307, 5640, 1294, 5674, 1290, 5673, 1294, 5576, 1312,
#
# clustering: 62.38741161483456%
# 43982, 3802, 43977, 3725, 43978, 3706, 3558, 43974, 3782,
#
# clustering: 58.39464166262866%
# 1720, 1762, 1794, 3489, 3521, 3526,
#
# clustering: 56.84906478678624%
# 8333, 288, 8600, 84, 8603, 190,
#
# clustering: 66.03952299184029%
# 593, 19481, 19507, 578,
#
# clustering: 54.791368005489424%
# 12152, 12544, 12152, 12543, 12545,
#
# clustering: 66.06249396040792%
# 516, 7607, 7611, 525, 506, 7607, 7613, 513, 511, 7616, 7608, 524,
#
# clustering: 63.01528277074864%
# 5680, 2005, 5680, 1960, 1953, 5672, 5681, 1974, 1960, 5680, 1956,
#
# clustering: 66.92907724265636%
# 5494, 5591, 5496, 5592,
#
# clustering: 66.56329072525422%
# 673, 5586, 647, 5667, 652, 5586, 671, 5681, 646, 5674, 668, 5679,
#
# clustering: 66.26415035562655%
# 646, 656, 653, 6321, 6320, 6249,
#
# clustering: 66.48965256800263%
# 828, 277, 837, 278,
#
# clustering: 66.09171547079619%
# 11069, 11073, 11898, 11897,
#
# clustering: 59.21739382421849%
# 26137, 172, 26372, 168, 275, 28272, 165, 26297, 169, 169, 26659, 167, 26252, 166, 373,
#
# clustering: 63.68590509913437%
# 5588, 5523, 5521, 5587,
#
# clustering: 59.25605100186166%
# 38958, 39274, 40442, 297, 125, 1270,
#
# clustering: 66.26008153473568%
# 2851, 461, 474, 2840, 2847, 458, 2828, 457, 464, 2849, 463, 2848,
#
# clustering: 66.1733393245535%
# 2850, 9150, 2815, 9153, 9154, 2849,
#
# clustering: 62.19558690221063%
# 670, 5680, 655, 5679, 5673, 663, 5676, 660, 5673,
#
# clustering: 59.116269777328%
# 14541, 14549, 14542, 16350, 16302, 16357,
#
# clustering: 64.75906205874371%
# 5676, 1344, 5674, 1324, 5580, 1338, 5679, 1325, 1305, 5614, 5682, 1315,
#
# clustering: 52.41570555173902%
# 15505, 15506, 342, 15500, 226, 15497, 77, 15505, 15504, 961,
#
# clustering: 63.72920887609911%
# 10389, 1989, 2002, 10385, 1977, 10300, 1930, 10385, 1939, 10384, 1995,
#
# clustering: 65.98214735841827%
# 22603, 21877, 22604, 21876,
#
# clustering: 66.19453616604%
# 16835, 16291, 16833, 16288,
#
# clustering: 66.92514409184794%
# 17753, 22165, 22242, 17875,
#
# clustering: 66.37734869117074%
# 20926, 20926, 20922, 21882, 21879, 21887,
#
# clustering: 66.15847044029894%
# 521, 9274, 521, 9275, 510, 9265, 524, 9274, 9180, 506, 9256, 513,
#
# clustering: 67.02224716866422%
# 15221, 15239, 15238, 16186, 16181, 16178,
#
# clustering: 66.80640026076244%
# 938, 719, 9147, 9146,
#
# clustering: 66.26632205543298%
# 1422, 1412, 2839, 2845,
#
# clustering: 66.18156436690577%
# 373, 380, 4110, 4007,
#
# clustering: 54.91929981587524%
# 1476, 1697, 27523, 27521, 1504,
#
# clustering: 67.31551917861701%
# 1992, 5681, 5590, 2028, 2010, 5589, 5629, 1971, 5680, 2001, 1936, 5674,
#
# clustering: 66.30997205275744%
# 5674, 653, 5654, 656, 658, 5677, 5577, 668, 5678, 655, 670, 5622,
#
# clustering: 55.389597930061235%
# 10277, 10617, 10272, 10618, 10620,
#
# clustering: 62.77819892147354%
# 2843, 2816, 2804, 1394, 1419, 1371,
#
# clustering: 66.25041247475977%
# 8328, 4218, 4179, 8332,
#
# clustering: 54.82770249580478%
# 27528, 13793, 27525, 27526, 13812,
#
# clustering: 56.30300831235433%
# 21878, 22602, 21848, 22606, 22604,
#
# clustering: 65.9796058250416%
# 6960, 6964, 6961, 12448, 12441, 12443,
#
# clustering: 66.22893833665216%
# 5676, 667, 5674, 653, 5673, 669, 676, 5660, 650, 5682, 677, 5674,
#
# clustering: 66.33926182833736%
# 7615, 7607, 7583, 1945, 1938, 2000,
#
# clustering: 53.40618532648974%
# 1282, 9896, 914, 9979,
#
# clustering: 50.10366676074982%
# 27529, 27527, 8257, 27522, 27474, 8333, 27524, 27525, 27525, 8329, 27528, 8329, 27523, 27523, 8330, 8307,
#
# clustering: 66.10181345750117%
# 19727, 19098, 19725, 19100,
#
# clustering: 58.38958740904183%
# 9008, 8773, 2257, 2256,
#
# clustering: 57.736743618314925%
# 16952, 1300, 17048, 1308, 17209, 1340, 17157, 1311, 18440, 1303, 17223, 1325,
#
# clustering: 66.36483190140159%
# 1343, 5676, 1306, 5673, 5678, 1311, 5630, 1331, 5677, 1304, 5678, 1353,
#
# clustering: 61.146011881861746%
# 2459, 2470, 2416, 3662, 3667, 3665,
#
# clustering: 65.33462726611751%
# 17306, 17308, 17310, 17505, 17510, 17509,
#
# clustering: 54.71695801839927%
# 138, 139, 139, 138, 138,
#
# clustering: 66.54604436592437%
# 15435, 37768, 14937, 37905, 15433, 37769, 14940, 37449, 15431, 38116, 15430, 37769,
#
# clustering: 70.02036155132576%
# 4858, 9633, 4850, 9635, 9612, 4857, 9640, 4859, 4899, 9864, 4757, 9638,
#
# clustering: 50.09607472089919%
# 1959, 3866, 1987, 3888, 3795, 1986, 3885, 1956, 2015, 3846, 2026, 3892,
#
# clustering: 66.44885802301737%
# 5679, 1294, 1336, 5673, 1342, 5675, 5675, 1330, 5676, 1299, 5674, 1354,
#
# clustering: 54.77900730467344%
# 24784, 22045, 22038, 24782, 22038,
#
# clustering: 66.26619893520034%
# 5508, 5538, 8329, 8328,
#
# clustering: 55.13195961692619%
# 2797, 2784, 549, 568, 575,
#
# clustering: 66.61092079299581%
# 15946, 15434, 15948, 15443,
#
# clustering: 66.70566138017251%
# 10257, 9934, 10259, 9928,
#
# clustering: 50.66256454912865%
# 8465, 8699, 8710, 8461,
#
# clustering: 66.52574891831733%
# 14736, 2691, 14683, 2732, 14805, 2777,
#
# clustering: 65.96306658614998%
# 38491, 30270, 38493, 30262,
#
# clustering: 55.24945207390095%
# 7107, 7350, 7110, 7351, 7350,
#
# clustering: 66.17662493642389%
# 8467, 8558, 18107, 18100, 18105, 8463,
#
# clustering: 57.7587700147775%
# 1796, 466, 1855, 476, 1837, 458, 1810, 475, 1788, 470, 1834, 465,
#
# clustering: 66.04534105512552%
# 8334, 8332, 8324, 4771, 4761, 4762,
#
# clustering: 60.80690614493781%
# 1232, 1328, 17465, 16938,
#
# clustering: 66.12447758877202%
# 1424, 4214, 1409, 4218,
#
# clustering: 66.71874596828462%
# 417, 988, 983, 426,
#
# clustering: 65.88833259490531%
# 29, 28, 28, 29, 29, 28,
#
# clustering: 66.21879885905352%
# 11449, 1336, 11447, 1290, 11450, 1338, 1310, 11445, 11356, 1300, 11449, 1326,
#
# clustering: 66.3086958378764%
# 1313, 5677, 5675, 1313, 5677, 1353, 1346, 5680, 5646, 1340, 5672, 1312,
#
# clustering: 66.38658779652701%
# 18237, 18241, 18240, 21116, 21078, 21125,
#
# clustering: 66.1860854080261%
# 1342, 6416, 1338, 6384, 1332, 6409, 1328, 6412, 1350, 6407, 1344, 6407,
#
# clustering: 61.58969412994225%
# 1029, 669, 1017, 651, 1019, 668, 668, 1016, 1018, 655, 1017, 663,
#
# clustering: 64.89351022453165%
# 6023, 1116, 6016, 1093, 6017, 1099, 6024, 1116, 6020, 1144, 5926, 1128,
#
# clustering: 66.0835381277012%
# 6972, 1468, 1458, 6963, 6963, 1467, 6965, 1470, 6964, 1453, 6971, 1454,
#
# clustering: 63.75472227503292%
# 14366, 9844, 14360, 9842, 14363, 9838, 14364, 9841, 14363, 14328, 9813,
#
# clustering: 66.73303381597663%
# 1328, 5596, 1350, 5657, 5671, 1331, 1310, 5673, 1322, 5673, 5583, 1301,
#
# clustering: 66.12663476593697%
# 82369, 82361, 137203, 137207,
#
# clustering: 66.13983610172313%
# 11077, 11070, 5587, 5556,
#
# clustering: 65.60421022787808%
# 5679, 1304, 5675, 1352, 1321, 5680, 1347, 5677, 5599, 1307, 1325, 5677,
#
# clustering: 52.3680969093239%
# 5528, 5586, 5589, 279, 5588, 275, 5586, 282, 5592, 275,
#
# clustering: 66.00157330878017%
# 30703, 10967, 30703, 10967, 30709, 10962, 30704, 10959, 30707, 10966, 30710, 10963,
#
# clustering: 66.3636866616336%
# 1418, 6795, 1439, 6800, 6798, 1416, 1457, 6726, 6796, 1442, 6798, 1456,
#
# clustering: 66.816661204675%
# 8288, 5593, 5559, 8329,
#
# clustering: 66.43699746214438%
# 5673, 1317, 5674, 1352, 5674, 1301, 5645, 1312, 5677, 1348, 5673, 1338,
#
# clustering: 64.59708458660396%
# 2653, 5649, 5595, 2627, 5629, 2586, 2673, 5679, 5654, 2659, 5681, 2590,
#
# clustering: 63.673583528287075%
# 1332, 5673, 1296, 5675, 1316, 5672, 1301, 5659, 5677, 1352, 1333,
#
# clustering: 63.9144439292235%
# 5681, 654, 5678, 658, 651, 5623, 668, 5654, 5590, 658, 669,
#
# clustering: 65.58833212269116%
# 4219, 4150, 4213, 1140, 1140, 1144,
#
# clustering: 66.24012504134448%
# 675, 5681, 5642, 675, 5675, 653, 650, 5677, 674, 5672, 661, 5677,
#
# clustering: 66.13131854872603%
# 13915, 659, 13872, 648, 13919, 648, 13892, 646, 13832, 660, 13918, 674,
#
# clustering: 66.86944081804842%
# 14814, 675, 14838, 656, 14848, 652, 14854, 655, 14839, 676, 15061, 650,
#
# clustering: 61.08549561721662%
# 3858, 5564, 5562, 3866, 5561, 3890, 5568, 3865, 5538, 3796, 5564, 3895,
#
# clustering: 66.13646094208481%
# 27941, 27929, 29721, 29722,
#
# clustering: 66.39084884262063%
# 650, 6320, 6320, 676, 645, 6251, 674, 6243, 662, 6319, 645, 6323,
#
# clustering: 66.40719762460634%
# 664, 664, 653, 6318, 6326, 6230,
#
# clustering: 63.395480034193156%
# 9383, 5674, 5672, 9472, 9469, 5604, 9468, 5637, 9469, 5672, 9466, 5672,
#
# clustering: 66.41225080340858%
# 12713, 12755, 12762, 14061, 14052, 14057,
#
# clustering: 54.84483967769839%
# 7430, 35955, 35961, 7426, 35955, 35958, 35962, 7430, 35962, 7427,
#
# clustering: 65.88833259490531%
# 37, 38, 37, 38, 38, 37,
#
# clustering: 66.27158384649393%
# 14151, 528, 14235, 520, 14198, 508, 14176, 513, 14271, 514, 14248, 522,
#
# clustering: 63.92848235339824%
# 14229, 6948, 14153, 6963, 14009, 6968, 14061, 6924, 13948, 6967, 14069, 6963,
#
# clustering: 62.86163623980995%
# 2675, 5636, 2686, 5587, 5589, 2680, 5675, 2689, 5666, 2675, 2642, 5673,
#
# clustering: 66.80210955490396%
# 1320, 1290, 1352, 6874, 6926, 6966,
#
# clustering: 66.19407680586069%
# 5664, 661, 5633, 672, 5673, 674, 5674, 667, 5680, 670, 5674, 669,
#
# clustering: 66.51195713736966%
# 6321, 942, 6248, 945, 6317, 911, 942, 6261, 6319, 911, 6325, 947,
#
# clustering: 66.49415622416934%
# 6688, 6687, 1840, 1852, 1864, 6598,
#
# clustering: 51.62911046561086%
# 9700, 256, 9705, 51, 226,
#
# clustering: 66.50147616299921%
# 5674, 1340, 1319, 5680, 5677, 1304, 1301, 5672, 1353, 5619, 5677, 1341,
#
# clustering: 66.80153491997021%
# 5677, 1936, 5615, 1988, 5676, 2003, 1973, 5681, 1972, 5674, 5675, 1954,
# clustering: 66.32008625675613%
# 9257, 2792, 9258, 2717, 9252, 2793, 9250, 2726, 9253, 2758, 9251, 2715,
#
# clustering: 55.03970689832702%
# 11419, 11426, 11420, 10460, 10465,
#
# clustering: 66.95117039940926%
# 19402, 1332, 19406, 1310, 19374, 1351, 20413, 1294, 19257, 1308, 19399, 1303,
#
# clustering: 66.89110303250858%
# 2536, 507, 519, 2598, 520, 2532, 2542, 525, 2581, 520, 514, 2578,
#
# clustering: 66.49371694676252%
# 996, 1001, 981, 2844, 2852, 2845,
#
# clustering: 66.09887979059864%
# 6320, 646, 6318, 660, 6320, 650, 655, 6325, 661, 6321, 6300, 654,
#
# clustering: 65.91418844382672%
# 35315, 35316, 37121, 37121,
#
# clustering: 54.893566679926835%
# 16720, 16182, 16716, 16183, 16718,
#
# clustering: 66.16834431620683%
# 15036, 14562, 15036, 14558,
#
# clustering: 65.88833259490531%
# 22, 22, 21, 21,
#
# clustering: 66.69236940751745%
# 21330, 21205, 21204, 21328,
#
# clustering: 66.08431157583675%
# 6811, 672, 6817, 675, 6809, 660, 659, 6813, 6812, 651, 652, 6808,
#
# clustering: 57.12149952690577%
# 32932, 8763, 33009, 8853, 33013, 9916, 33007, 9848, 33011, 10044, 33012, 10099,
#
# clustering: 66.86933250910783%
# 11475, 11470, 11845, 11851,
#
# clustering: 63.446088271243006%
# 25099, 111, 115, 113, 25099, 25030, 25122, 115, 25104, 25062, 113,
#
# clustering: 66.27676385115534%
# 8807, 1418, 1440, 8808, 8766, 1463, 1473, 8809, 1433, 8809, 8803, 1467,
#
# clustering: 54.7857042484302%
# 22340, 22344, 33444, 33447, 33451,
#
# clustering: 66.04449930999927%
# 6970, 6969, 6970, 1323, 1320, 1305,
#
# clustering: 54.87153208110636%
# 24783, 24788, 12373, 12351, 12444,
#
# clustering: 66.2213155196924%
# 30533, 916, 30504, 940, 30645, 946, 30634, 947, 30665, 911, 30565, 922,
#
# clustering: 67.51399865789026%
# 979, 963, 968, 1951, 1943, 1972,
#
# clustering: 65.88834523692255%
# 8333, 8333, 8329, 8329,
#
# clustering: 56.13011653137552%
# 839, 825, 828, 2843, 2788, 2751,
#
# clustering: 66.21950621442222%
# 524, 5700, 506, 5693, 516, 5645, 523, 5669, 505, 5700, 505, 5697,
#
# clustering: 66.10357504673024%
# 16450, 1464, 1480, 16452, 16448, 1478, 16447, 1486, 1441, 16451, 1486, 16446,
#
# clustering: 55.06928310980701%
# 10550, 10336, 10549, 10338, 10338,
#
# clustering: 54.77698993130003%
# 5585, 5591, 5593, 8327, 8327,
#
# clustering: 56.98442401678489%
# 7561, 14909, 7669, 15187,
#
# clustering: 65.94137373132999%
# 27940, 27936, 37119, 37119,
#
# clustering: 66.24266477770117%
# 5609, 656, 5680, 669, 5674, 673, 5675, 668, 5682, 669, 5678, 658,
#
# clustering: 56.26239756154444%
# 13254, 13294, 226, 950, 13289, 13295, 13294, 13293, 704, 318,
#
# clustering: 50.96449628594234%
# 9698, 9705, 6412, 9705, 6636,
#
# clustering: 53.71506256544101%
# 31362, 5045, 31364, 4996, 31366, 5040, 4954, 31364, 5034, 31364, 5041, 34103,
#
# clustering: 61.185316432267534%
# 2802, 2780, 2778, 1434, 1375, 1418,
#
# clustering: 52.434791503660755%
# 287, 558, 570, 283,

# %% [markdown]
# #### 7.4 Vyhodnotenie klasterizácie
#
# Algoritmus funguje, teda spojenia účtov kde je výška platieb rozdeliteľná do dvoch skupín dostanú vyššie percento klasterizácie.
# Praktické využitie vidíme napríklad pre klasifikáciu účtov s dvomi rôznymi zdrojmi príjmov.

# %% [markdown]
# ### 8. Grafy
#
# #### 8.1. Príjem z jedného účtu v porovnaní s pravdepodobnosťou, že sa jedná o mzdu.

# %%
import numpy as np
import matplotlib.pyplot as plt

class Graph_plotting:
	
	def __init__(self, loaded):
		self.payments = loaded.payments
		self.keyset = loaded.keyset
		self.connections = loaded.payments_list
		
	def monthly_salary_perc(self):
		percentages = []
		sum_salary = []
		for k, v in self.connections.items():
			if len(v.salaries) >= 3:
				percentages.append([v.salary_perc, sum(np.array(v.salaries)[:,1])])
		percentages = np.array(sorted(percentages, key = lambda percentages:percentages[1]))
		plt.figure(figsize=(15,7))
		plt.plot(percentages[:,1],percentages[:,0], 'o')
		plt.title('Probability of salary incoming to account vs. monthly income')
		plt.show()
		plt.close()
        
gg = Graph_plotting(l)
gg.monthly_salary_perc()

# %% [markdown]
# #### 8.2. Výška platby vs. pravdepodobnosť, že na účet prichádza mzda
#
# Graf vyjadruje pravdepodobnosť, že pre príchodzia platba je mzdou. Graf pracuje s platbami už vyfiltrovanými ako možné mzdy.

# %%
import numpy as np
import matplotlib.pyplot as plt

class Graph_plotting:
	
	def __init__(self, loaded):
		self.payments = loaded.payments
		self.keyset = loaded.keyset
		self.connections = loaded.payments_list
		
	def height_payment_salary_perc(self):
		all_amounts = set()
		percentages = []
		for k, v in self.connections.items():
			for p in v.amounts:
				if p < 160000 and v.salary_perc > 0:
					if p not in all_amounts:
						percentages.append(v.salary_perc)
					all_amounts.add(p)
		all_amounts_sorted = sorted(all_amounts)
		plt.figure(figsize=(13,6))
		plt.plot(all_amounts_sorted, percentages, 'o')
		plt.title('Probability of payment in given sum being a salary')
		plt.show()
		plt.close()
        
gg = Graph_plotting(l)
gg.height_payment_salary_perc()

# %% [markdown]
# ### 8.3 Percentuálne rozdelenie výšky platieb

# %%
import numpy as np
import matplotlib.pyplot as plt

class Graph_plotting:
	
	def __init__(self, loaded):
		self.payments = loaded.payments
		self.keyset = loaded.keyset
		self.connections = loaded.payments_list
	def payment_grouped_issalary(self):
		cat_range = 10000
		max_r = 120000
		amounts = range(0, max_r, cat_range)
		amounts_dict = {}
		for am in amounts:
			amounts_dict[am] = 0
		for k, v in self.connections.items():
			for am in v.amounts:
				category = round(am / cat_range)*cat_range
				if category < max_r:
					amounts_dict[category] += 1
		for k,v in amounts_dict.items():
			amounts_dict[k] = (v / 427632)*100	#size of data, TODO: pass from loader file
		plt.figure(figsize=(13,6))
		plt.title('percentage from all payments vs. sum of payment, grouped by 10000')
		plt.xlabel('sum of transaction')
		plt.ylabel('percentage')
		plt.plot(list(amounts_dict.keys()), list(amounts_dict.values()), 'o')
		plt.show()
		plt.close()

gg = Graph_plotting(l)
gg.payment_grouped_issalary()

# %% [markdown]
# ### 8.4. Pravdepodobnosť, že platba je mzdou vs. výška platby

# %%
class Graph_plotting:
	
	def __init__(self, loaded):
		self.payments = loaded.payments
		self.keyset = loaded.keyset
		self.connections = loaded.payments_list
		
	def grouped_payment_perc_issalary(self):
		cat_range = 10000
		max_r = 120000
		percentage = {}
		perc2 = dict()
		for k, v in self.connections.items():
			if len(v.salaries) > 0:
				num_of_salaries = len(np.array(v.salaries)[:,1])
				for salary in np.array(v.salaries)[:,1]:
					category = round(salary / cat_range)*cat_range
					if category not in percentage.keys():
						percentage[category] = 0
						perc2[category] = 0
					if category < max_r:
						percentage[category] += v.salary_perc
						perc2[category] +=1
		for cat in range(10000, max_r, cat_range):
			if perc2[category] != 0:
				percentage[cat] = percentage[cat] / perc2[cat]
		to_plot = np.array(sorted(list(percentage.items())))
		plt.figure(figsize=(13,6))
		plt.title('probability of being salary vs. sum of payment')
		plt.ylabel('percentage')
		plt.xlabel('payment')
		plt.plot(to_plot[:,0], to_plot[:,1])
		plt.show()
		plt.close()
        
gg = Graph_plotting(l)
gg.grouped_payment_perc_issalary()

# %% [markdown]
# ### 9. Protiúčty
#
# Pre jednoduchosť v tejto kapitole zhrnieme využitie protiúčtov. Budeme sa spätne odkazovať na už upravený kód v predchádzajúcich kapitolách. Tento prístup takisto upravil graf v kapitole 8.4. ,kde sme stratili peak pre hodnotu okolo 110 000 nakoľko bola odfiltrovaná.
#
# ###### 9.1. Idea
#
# Nájsť pre účty odosielateľov parameter, hovoriaci koľkým unikátnym účtom odosielajú peniaze. Následne tento parameter vyhodnotiť na grafe a zakomponovať do vyhodnocovania výplat v kapitole 5. Ako mzdy chceme vyhodnocovať len platby prichadzajúce z účtov s váhou v rozmedzí 8-500.
#
# ###### 9.2. Implementácia
#
# Pri načítavaní dát sme pridali výpočet váh pre jednotlivé účty odosielateľov. Váhou účtu chápeme počet rôznych účtov na ktoré odosielateľ vykonal aspoň 1 platbu. Následne pred vyhodnotením platieb v funkci process3 nastavíme príslušné váhy jednotlivým platbám. Pri tvorbe grafu počítame počet účtov odosielateľou s danou váhou.
#
# ###### 9.3. Histogram váh
#
# Na os x sme zobrazili váhu účtu, na os y počet účtov s danou váhou. Z grafu je zrejmé, že najčastejšia váha je v rozmedzí 5-100. Hodnoty nad 500 môžu predstavovať účty veľkých spoločností, no z dôvodu, že sa jedná o reprezentatívnu vzorku to považujeme za účty, z ktorých sú vyplácané sociálne dávky, resp. dôchodky. V ďalšom kroku by sme sa pozreli na priemernú vyplácanú sumu z účtov s danou váhou. Čo by nám mohlo ďalej pomôcť s správnou klasifikáciou typu účtu a platby. Klasterizáciou sme chceli odlíšit jednotlivé skupiny váh platieb, v grafe sú znázornené odlišnými farbami.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
class Graph_plotting:
	
	def __init__(self, loaded):
		self.payments = loaded.payments
		self.keyset = loaded.keyset
		self.connections = loaded.payments_list
		self.weights = loaded.sender_weights

	def sender_weights_histogram(self):
		histo_weights = dict()
		colors = {0: "red", 1: "black", 2: "blue", 3:"gray"}
		paint = []
		for k, v in self.connections.items():
			for payment in v.payments:
				key_for_weights = k[:k.find('#')]
				if self.weights[key_for_weights] not in histo_weights.keys():
					histo_weights[self.weights[key_for_weights]] = 1
				else:
					histo_weights[self.weights[key_for_weights]] += 1
		
		x = []
		y = []
		weights_np = np.array(list(histo_weights.keys())).reshape(-1,1)
		#print(weights_np)
		kmeans = KMeans(n_clusters=4, random_state=0).fit(weights_np)
		for k,v in histo_weights.items():
			x.append(k)
			cluster = int(kmeans.predict(np.array(k).reshape(1, -1)))
			paint.append(colors[cluster])
			y.append(v)
			
		plt.xticks([i for i in range(0 ,max(x), 100)])
		plt.yticks([i for i in range(0,max(y), 5000)])
		plt.xlabel('number of transactions from account')
		plt.ylabel('num of accounts with given num of transactions')
		plt.scatter(x,y, c = paint)
		plt.show()

gg = Graph_plotting(l)
gg.sender_weights_histogram()

# %% [markdown]
# ### 10. Záver
#
# Klasifikovali sme, pri ktorých platbách sa s akou pravdepodobnosťou jedná o mzdu. Predostreli sme metódu klasterizácie na identifikáciu 2 skupín transakcií medzi 2 účtami. Stratili sme dodatočnú informáciu o reťazcoch platieb nepoužitím grafovej štruktúry, no pre príjmy fyzických osôb to nepovažujeme za kritický problém. Naše percentuálne vyhodnotenie pravdepodobnosti, či je platba mzdou považujeme za približne správne aj kvôli poslednému grafu.
# Vysoké percento pravdepodobnosti, že sa jedná o mzdu dostávame pri sumách, ktoré reálne môžu byť mzdou. Naše riešenie vykazuje možnú chybovosť pri nízkych hodnotách miezd, v okolí 15 000kč. Peak v okolí 110 000kč je buď zlá kategorizácia z našej strany alebo chyba simulácie.
# Možné pokračovanie v riešení sme rozvinuli v kapitole 3.
